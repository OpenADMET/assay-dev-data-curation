# %%
import pandas as pd
from rdkit import Chem
import seaborn as sns
from tqdm import tqdm
import numpy as np

# %% [markdown]
# # From here
# https://s3-us-west-2.amazonaws.com/drugbank/cite_this/attachments/files/000/001/580/original/cyp1a2.pdf?1537393556
#
# # Extended from here and processed with pubchem
# https://go.drugbank.com/categories/DBCAT002609

# %%
tqdm.pandas()

# %%
df = pd.read_csv("./drugbank/drugbank_1a2.csv")
df_extended = pd.read_csv("./drugbank/drugbank_extended_smiles.csv")

# %%
df
# Out:
#                                                SMILES    active  \
# 0   CC(=O)CC(c1ccc([N+](=O)[O-])cc1)c1c(O)c2ccccc2...      True
# 1   Cn1c(=O)c2[nH]cnc2n(C)c1=O.Cn1c(=O)c2[nH]cnc2n...      True
# 2                    CC(C)NCC(O)COc1ccc(CCOCC2CC2)cc1      True
# 3                          Cn1c(=O)c2c(ncn2C)n(C)c1=O  Caffeine
# 4                   CN(C)CCCN1c2ccccc2CCc2ccc(Cl)cc21      True
# 5               CN1CCN(C2=Nc3cc(Cl)ccc3Nc3ccccc32)CC1      True
# 6                     CN(C)CCC=C1c2ccccc2C=Cc2ccccc21      True
# 7                          CN(C)/N=N/c1[nH]cnc1C(N)=O      True
# 8                      CN(C)CCC=C1c2ccccc2COc2ccccc21      True
# 9                   CNCC[C@H](Oc1cccc2ccccc12)c1cccs1      True
# 10  C[C@]12CC[C@@H]3c4ccc(O)cc4CC[C@H]3[C@@H]1CC[C...      True
# 11  CC#C[C@]1(O)CC[C@H]2[C@@H]3CCc4cc(O)ccc4[C@H]3...      True
# 12   C[C@]12CC[C@@H]3c4ccc(O)cc4CC[C@H]3[C@@H]1CCC2=O      True
# 13  C1CNCCN1.C[C@]12CC[C@@H]3c4ccc(OS(=O)(=O)O)cc4...      True
# 14        CC(C)C(=O)Nc1ccc([N+](=O)[O-])c(C(F)(F)F)c1      True
# 15                COCCCC/C(=N\OCCN)c1ccc(C(F)(F)F)cc1      True
# 16                         N=C(N)N/N=C/c1c(Cl)cccc1Cl      True
# 17                                Cc1cccc(C)c1OCC(C)N      True
# 18                       CN1CCN2c3ncccc3Cc3ccccc3C2C1      True
# 19  O=c1[nH]c2ccccc2n1C1CCN(CCCC(c2ccc(F)cc2)c2ccc...      True
# 20                        CC(C)NCC(O)COc1cccc2ccccc12      True
# 21                          Nc1nc2ccc(OC(F)(F)F)cc2s1      True
# 22                       CCCN(CCC)CCc1cccc2c1CC(=O)N2      True
# 23                            Nc1c2c(nc3ccccc13)CCCC2      True
# 24                         Cn1c(=O)c2[nH]cnc2n(C)c1=O      True
# 25  CN1CCN(CC/C=C2/c3ccccc3Sc3ccc(S(=O)(=O)N(C)C)c...      True
# 26       CN1CCN(CCCN2c3ccccc3Sc3ccc(C(F)(F)F)cc32)CC1      True
#
#           common_name action_type
# 0       Acenocoumarol   substrate
# 1       Aminophylline   substrate
# 2           Betaxolol   substrate
# 3                True   substrate
# 4        Clomipramine   substrate
# 5           Clozapine   substrate
# 6     Cyclobenzaprine   substrate
# 7         Dacarbazine   substrate
# 8             Doxepin   substrate
# 9          Duloxetine   substrate
# 10          Estradiol  susbstrate
# 11           Estrogen   substrate
# 12            Estrone   substrate
# 13        Estropipate   substrate
# 14          Flutamide   substrate
# 15        Fluvoxamine   substrate
# 16          Guanabenz   substrate
# 17         Mexiletine   substrate
# 18        Mirtazapine   substrate
# 19           Pimozide   substrate
# 20         Propanolol   substrate
# 21           Riluzole   substrate
# 22         Ropinirole   substrate
# 23            Tacrine   substrate
# 24       Theophylline   substrate
# 25        Thiothixene   substrate
# 26  Trifluoroperazine   substrate

# %%
df_extended
# Out:
#                                                 SMILES
# 0    B([C@H](CC(C)C)NC(=O)CNC(=O)C1=C(C=CC(=C1)Cl)C...
# 1    B([C@H](CC(C)C)NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)...
# 2    C#CC1=CC(=CC=C1)NC2=NC=NC3=CC4=C(C=C32)OCCOCCO...
# 3                           C#CCN[C@@H]1CCC2=CC=CC=C12
# 4                               C(CCl)NC(=O)N(CCCl)N=O
# ..                                                 ...
# 212  C[C@]12CC[C@H]3[C@H]([C@@H]1CC[C@@H]2OC(=O)CCC...
# 213  C[C@]12CC[C@H]3[C@H]([C@@H]1CC[C@]2(C#C)O)CCC4...
# 214  C[C@]12CC[C@H]3[C@H]([C@@H]1CC[C@]2(C#C)O)CCC4...
# 215     C[N+]1(CCC(C1)OC(=O)C(C2CCCC2)(C3=CC=CC=C3)O)C
# 216  [2H]C([2H])([2H])OC1=C(C=C2[C@@H]3CC(=O)[C@H](...
#
# [217 rows x 1 columns]

# %%
from utils.utils import get_common_name
from rdkit.rdBase import BlockLogs
with BlockLogs():
    df_extended["common_name"] = df_extended["SMILES"].progress_apply(lambda x: get_common_name(x))
# Out:
# 100%|██████████| 217/217 [03:18<00:00,  1.09it/s]

# %%
df_combined = pd.concat([df, df_extended], axis=0)

# %%
from utils.utils import standardize_smiles
from rdkit.rdBase import BlockLogs
with BlockLogs():
    df_combined["CANONICAL_SMILES"] = df_combined["SMILES"].progress_apply(lambda x: standardize_smiles(x))
# Out:
# 100%|██████████| 244/244 [00:01<00:00, 184.92it/s]

# %%
from utils.utils import smi_to_inchikey
from rdkit.rdBase import BlockLogs
# compute inchikeys
with BlockLogs():
    df_combined["INCHIKEY"] = df_combined["CANONICAL_SMILES"].progress_apply(lambda x: smi_to_inchikey(x))
# Out:
# 100%|██████████| 244/244 [00:00<00:00, 5681.82it/s]

# %%
df_combined["dataset"] = "drugbank"
df_combined["action_type"] = "substrate"
df_combined["active"] = True
df_combined.to_csv("processed/drugbank.csv", index=False)
