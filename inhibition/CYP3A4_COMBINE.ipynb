# %%
import pandas as pd
from rdkit import Chem
import seaborn as sns
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Combining data
#
# We are going to combine data from the Novartis, NCATS, Carbon-Mangels, ChEMBL and Veith datasets to try and come up with a set of compounds to test

# %% [markdown]
# ## Novartis
#
# Novartis have both a real world dataset and some public compounds they have labelled with an in-house developed model (surrogates) do we want to include both?

# %%
novartis_combined = pd.read_csv("processed/novartis_2024_combined.csv")

# %%
novartis_combined.head()
# Out:
#                                               SMILES  log_kobs  pIC50_CYP3A4  \
# 0     CCCCc1nc2cc(/C=C/C(=O)NO)ccc2n1CCN(CC)CC.Cl.Cl    -2.131         4.957
# 1                              CCCCc1ccc(N/C=N/O)cc1    -2.300         4.597
# 2  C[C@H](Nc1cc(-c2sc(C3CCN(C)CC3)nc2-c2ccc(F)cc2...    -1.940         4.740
# 3  CC(C)c1nc(-c2ccc(F)cc2)c(-c2ccc3nc(N)n(S(=O)(=...    -2.151         4.453
# 4  CC(C)S(=O)(=O)n1c(N)nc2ccc(-c3[nH]c(C(C)(C)C)n...    -2.283         4.372
#
#    pIC50_CYP2C9  pIC50_CYP2D6  Source  \
# 0         4.733         4.823  ChEMBL
# 1         4.857         4.716  ChEMBL
# 2         4.686         4.883  ChEMBL
# 3         4.543         4.525  ChEMBL
# 4         4.432         4.463  ChEMBL
#
#                                     CANONICAL_SMILES  \
# 0           CCCCc1nc2cc(/C=C/C(O)=NO)ccc2n1CCN(CC)CC
# 1                                CCCCc1ccc(NC=NO)cc1
# 2  C[C@H](Nc1cc(-c2sc(C3CCN(C)CC3)nc2-c2ccc(F)cc2...
# 3  CC(C)c1nc(-c2ccc(F)cc2)c(-c2ccc3nc(N)n(S(=O)(=...
# 4  CC(C)S(=O)(=O)n1c(N)nc2ccc(-c3[nH]c(C(C)(C)C)n...
#
#                       INCHIKEY  split  data_type  kobs common_name  \
# 0  JHDKZFFAIZKUCU-ZRDIBKRKSA-N  train  surrogate   NaN         NaN
# 1  BQPCBRFOSWMALO-UHFFFAOYSA-N  train  surrogate   NaN         NaN
# 2  HJEPFPDXSFKWQH-IBGZPJMESA-N  train  surrogate   NaN         NaN
# 3  OBNKFIQHMAHNEE-UHFFFAOYSA-N  train  surrogate   NaN         NaN
# 4  ABAOSSRHMRVEJF-UHFFFAOYSA-N  train  surrogate   NaN         NaN
#
#          dataset activity_class action_type
# 0  novartis_2024       negative   inhibitor
# 1  novartis_2024       negative   inhibitor
# 2  novartis_2024  weak_positive   inhibitor
# 3  novartis_2024       negative   inhibitor
# 4  novartis_2024       negative   inhibitor

# %%
novartis_combined.data_type.value_counts()
# Out:
# data_type
# surrogate    16370
# assay          368
# Name: count, dtype: int64

# %%
# examine the distirbution of pIC50s over the activity binnings, these are generated with MODEL ie surrogate dataset
sns.histplot(data=novartis_combined, x="pIC50_CYP3A4", hue="activity_class")
# Out:
# <Axes: xlabel='pIC50_CYP3A4', ylabel='Count'>

# %%
# examine binning by activity class over full dataset
fig, ax = plt.subplots()
sns.histplot(data=novartis_combined, x="log_kobs", hue="activity_class", ax=ax)
ax.set_xlim(-4, 0)
# Out:
# (-4.0, 0.0)

# %%
# examine only the real data from public compounds, these were actually assayed

novartis_real = novartis_combined.query("data_type == 'assay'")

# %%
sns.countplot(data=novartis_real, x="activity_class")
# Out:
# <Axes: xlabel='activity_class', ylabel='count'>

# %%
fig, ax = plt.subplots()
sns.histplot(data=novartis_real, x="log_kobs", hue="activity_class")
ax.set_xlim(-4, 0)
# Out:
# (-4.0, 0.0)

# %% [markdown]
# # Decision?
#
# Lets start with including the surrogate dataset as there are only 50 points in positive class of "real" dataset, we will see if we can cross validate

# %%
# ok lets grab actives

novartis_actives = novartis_combined.query("activity_class == 'positive'")
# add a column we will use consistently
novartis_actives["active"] = True
# Out:
# /tmp/ipykernel_48886/815307204.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   novartis_actives["active"] = True

# %%
# drop the rest 
keep_cols_all = ["CANONICAL_SMILES", "INCHIKEY", "active", "dataset", "data_type", "common_name", "action_type"]
novartis_actives = novartis_actives[keep_cols_all]

# %%
novartis_actives
# Out:
#                                         CANONICAL_SMILES  \
# 5      O=[N+]([O-])c1cccc2[nH]c3c(N4CCN(CCc5ccc(F)c(F...
# 8       COc1ccc(C(O)c2c3cc(OC)cc(C)c3nc3[nH]nc(C)c23)cc1
# 9           NC(C(=O)N1CCC(Nc2ccc3[nH]ncc3c2)CC1)c1ccccc1
# 12     Cc1cc(C)cc(-c2[nH]c3ccc(C(C)(C)C(=O)N4CC5CCC4C...
# 19     O=[N+]([O-])c1ccc2[nH]c3c(N4CCN(CCc5ccc(F)c(F)...
# ...                                                  ...
# 16697   CCC1C(C)=NN=C(c2ccc(OC)c(OC)c2)c2cc(OC)c(OC)cc21
# 16721  Cc1c(C)c2c(c(C)c1O)CCC(C)(COc1ccc(Cc3sc(=O)[nH...
# 16722  CO[C@H]1C[C@H](O[C@@H]2C(C)C(=O)O[C@H](C)[C@H]...
# 16727  COc1ccc(CCN(C)CCCC(C#N)(c2ccc(OC)c(OC)c2)C(C)C...
# 16732  COc1cc(C(=O)NS(=O)(=O)c2ccccc2C)ccc1Cc1cn(C)c2...
#
#                           INCHIKEY  active        dataset  data_type  \
# 5      FOTDWYFVTJDSLW-UHFFFAOYSA-N    True  novartis_2024  surrogate
# 8      NJVOBGWGMQUPTG-UHFFFAOYSA-N    True  novartis_2024  surrogate
# 9      AGVLKBKXJWTFQT-UHFFFAOYSA-N    True  novartis_2024  surrogate
# 12     RMVSZBRIILAXIH-WUXOVTSDSA-N    True  novartis_2024  surrogate
# 19     RYGJKZCQNUAGKW-UHFFFAOYSA-N    True  novartis_2024  surrogate
# ...                            ...     ...            ...        ...
# 16697  RUJBDQSFYCKFAA-UHFFFAOYSA-N    True  novartis_2024      assay
# 16721  BJWJSFCBOIUATF-UHFFFAOYSA-N    True  novartis_2024      assay
# 16722  LQCLVBQBTUVCEQ-WXGPWXIXSA-N    True  novartis_2024      assay
# 16727  SGTNSNPWRIOYBX-UHFFFAOYSA-N    True  novartis_2024      assay
# 16732  YEEZWCHGZNKEEK-UHFFFAOYSA-N    True  novartis_2024      assay
#
#           common_name action_type
# 5                 NaN   inhibitor
# 8                 NaN   inhibitor
# 9                 NaN   inhibitor
# 12                NaN   inhibitor
# 19                NaN   inhibitor
# ...               ...         ...
# 16697       Tofisopam   inhibitor
# 16721    Troglitazone   inhibitor
# 16722  Troleandomycin   inhibitor
# 16727       Verapamil   inhibitor
# 16732     Zafirlukast   inhibitor
#
# [2639 rows x 7 columns]

# %% [markdown]
# # NCATS
# This is a pretty messy AID, but we will take what we can get, was also classified prior to pubchem upload

# %%
ncats = pd.read_csv("processed/ncats_adme_aid1645841.csv")

# %%
ncats.head()
# Out:
#                                     CANONICAL_SMILES  \
# 0           Cc1ccc2c(c1)c1c(n2CCc2ccc(C)nc2)CCN(C)C1
# 1           O=c1c(O)c(-c2ccc(O)cc2O)oc2cc(O)cc(O)c12
# 2  Cc1ccc(C(=O)NC2C(=O)NC(C(C)C)C(=O)N3CCCC3C(=O)...
# 3               O=c1cc(-c2ccc(O)cc2)oc2cc(O)cc(O)c12
# 4                          NC(Cc1ccc(O)c(O)c1)C(=O)O
#
#                       INCHIKEY PUBCHEM_ACTIVITY_OUTCOME  PUBCHEM_CID  \
# 0  JNODQFNWMXFMEV-UHFFFAOYSA-N                   Active       197033
# 1  YXOLAZRVSSWPPT-UHFFFAOYSA-N                 Inactive      5281670
# 2  GQBHKSFHNFMVES-TYWDLNKHSA-N             Inconclusive      6604832
# 3  KZNIFHPLKGYRTM-UHFFFAOYSA-N                   Active      5280443
# 4  WTDRDQBEARUVNC-UHFFFAOYSA-N                   Active          836
#
#                  dataset data_type  common_name action_type
# 0  ncats_adme_aid1645841     assay          NaN   inhibitor
# 1  ncats_adme_aid1645841     assay          NaN   inhibitor
# 2  ncats_adme_aid1645841     assay          NaN   inhibitor
# 3  ncats_adme_aid1645841     assay          NaN   inhibitor
# 4  ncats_adme_aid1645841     assay          NaN   inhibitor

# %%
sns.countplot(data=ncats, x="PUBCHEM_ACTIVITY_OUTCOME")
# Out:
# <Axes: xlabel='PUBCHEM_ACTIVITY_OUTCOME', ylabel='count'>

# %%
ncats_actives = ncats.query("PUBCHEM_ACTIVITY_OUTCOME == 'Active'")
ncats_actives["active"] = True
# Out:
# /tmp/ipykernel_48886/667201052.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ncats_actives["active"] = True

# %%
ncats_actives.head()
# Out:
#                                     CANONICAL_SMILES  \
# 0           Cc1ccc2c(c1)c1c(n2CCc2ccc(C)nc2)CCN(C)C1
# 3               O=c1cc(-c2ccc(O)cc2)oc2cc(O)cc(O)c12
# 4                          NC(Cc1ccc(O)c(O)c1)C(=O)O
# 6             CC1=NN=C(c2ccc(N)cc2)c2cc3c(cc2C1)OCO3
# 7  CC(=O)C1(O)C=C2C(=O)c3c(c(O)c4ccccc4c3O)C(=O)C...
#
#                       INCHIKEY PUBCHEM_ACTIVITY_OUTCOME  PUBCHEM_CID  \
# 0  JNODQFNWMXFMEV-UHFFFAOYSA-N                   Active       197033
# 3  KZNIFHPLKGYRTM-UHFFFAOYSA-N                   Active      5280443
# 4  WTDRDQBEARUVNC-UHFFFAOYSA-N                   Active          836
# 6  LFBZZHVSGAHQPP-UHFFFAOYSA-N                   Active         3538
# 7  SZWGDFGULWLMIP-UHFFFAOYSA-N                   Active         3685
#
#                  dataset data_type  common_name action_type  active
# 0  ncats_adme_aid1645841     assay          NaN   inhibitor    True
# 3  ncats_adme_aid1645841     assay          NaN   inhibitor    True
# 4  ncats_adme_aid1645841     assay          NaN   inhibitor    True
# 6  ncats_adme_aid1645841     assay          NaN   inhibitor    True
# 7  ncats_adme_aid1645841     assay          NaN   inhibitor    True

# %%
ncats_actives = ncats_actives[keep_cols_all]
ncats_actives
# Out:
#                                        CANONICAL_SMILES  \
# 0              Cc1ccc2c(c1)c1c(n2CCc2ccc(C)nc2)CCN(C)C1
# 3                  O=c1cc(-c2ccc(O)cc2)oc2cc(O)cc(O)c12
# 4                             NC(Cc1ccc(O)c(O)c1)C(=O)O
# 6                CC1=NN=C(c2ccc(N)cc2)c2cc3c(cc2C1)OCO3
# 7     CC(=O)C1(O)C=C2C(=O)c3c(c(O)c4ccccc4c3O)C(=O)C...
# ...                                                 ...
# 5223  Cc1cc(N)c2ccccc2[n+]1CCCCCCCCCC[n+]1c(C)cc(N)c...
# 5227  CC(C)CN(C[C@@H](O)[C@H](Cc1ccccc1)NC(=O)O[C@H]...
# 5228  O=C(Nc1cccc2c(=O)cc(-c3nn[nH]n3)oc12)c1ccc(OCC...
# 5232         CCCCCCCC/C=C\CCCCCCCC(=O)NCc1ccc(O)c(OC)c1
# 5235                   CCN(Cc1ccncc1)C(=O)C(CO)c1ccccc1
#
#                          INCHIKEY  active                dataset data_type  \
# 0     JNODQFNWMXFMEV-UHFFFAOYSA-N    True  ncats_adme_aid1645841     assay
# 3     KZNIFHPLKGYRTM-UHFFFAOYSA-N    True  ncats_adme_aid1645841     assay
# 4     WTDRDQBEARUVNC-UHFFFAOYSA-N    True  ncats_adme_aid1645841     assay
# 6     LFBZZHVSGAHQPP-UHFFFAOYSA-N    True  ncats_adme_aid1645841     assay
# 7     SZWGDFGULWLMIP-UHFFFAOYSA-N    True  ncats_adme_aid1645841     assay
# ...                           ...     ...                    ...       ...
# 5223  PCSWXVJAIHCTMO-UHFFFAOYSA-P    True  ncats_adme_aid1645841     assay
# 5227  CJBJHOAVZSMMDJ-HEXNFIEUSA-N    True  ncats_adme_aid1645841     assay
# 5228  NBQKINXMPLXUET-UHFFFAOYSA-N    True  ncats_adme_aid1645841     assay
# 5232  OPZKBPQVWDSATI-KHPPLWFESA-N    True  ncats_adme_aid1645841     assay
# 5235  BGDKAVGWHJFAGW-UHFFFAOYSA-N    True  ncats_adme_aid1645841     assay
#
#       common_name action_type
# 0             NaN   inhibitor
# 3             NaN   inhibitor
# 4             NaN   inhibitor
# 6             NaN   inhibitor
# 7             NaN   inhibitor
# ...           ...         ...
# 5223          NaN   inhibitor
# 5227          NaN   inhibitor
# 5228          NaN   inhibitor
# 5232          NaN   inhibitor
# 5235          NaN   inhibitor
#
# [2147 rows x 7 columns]

# %% [markdown]
# # Veith
#
# Assay data from veith et al

# %%
veith = pd.read_csv("processed/veith_2009.csv")
veith.head()
# Out:
#    PubChemCID                                             SMILES  Active  \
# 0   6602638.0             CCCC(=O)Nc1ccc(N2CCN(CC)CC2)c(Cl)c1.Cl       0
# 1    644510.0  O=c1[nH]c2cc3c(cc2cc1CN(CCCO)Cc1nnnn1Cc1ccc(F)...       1
# 2    644675.0         CC(=O)N(c1ccc2oc(=O)sc2c1)S(=O)(=O)c1cccs1       1
# 3    644890.0    COc1ccccc1C(c1nnnn1C(C)(C)C)N1CCN(Cc2ccncc2)CC1       1
# 4    645063.0      CC(=O)Nc1cccc(NC(=O)C2CCCN2C(=O)Nc2ccccc2C)c1       0
#
#                                     CANONICAL_SMILES  \
# 0                CCCC(=O)Nc1ccc(N2CCN(CC)CC2)c(Cl)c1
# 1  O=c1[nH]c2cc3c(cc2cc1CN(CCCO)Cc1nnnn1Cc1ccc(F)...
# 2         CC(=O)N(c1ccc2oc(=O)sc2c1)S(=O)(=O)c1cccs1
# 3    COc1ccccc1C(c1nnnn1C(C)(C)C)N1CCN(Cc2ccncc2)CC1
# 4      CC(=O)Nc1cccc(NC(=O)C2CCCN2C(=O)Nc2ccccc2C)c1
#
#                       INCHIKEY     dataset data_type  common_name action_type
# 0  ULLDFBZUOXJYID-UHFFFAOYSA-N  veith_2009     assay          NaN   inhibitor
# 1  VTLXYSNKFGEFDQ-UHFFFAOYSA-N  veith_2009     assay          NaN   inhibitor
# 2  GEUQHFHLRHDTPU-UHFFFAOYSA-N  veith_2009     assay          NaN   inhibitor
# 3  JGYZDKDCKPRYSN-UHFFFAOYSA-N  veith_2009     assay          NaN   inhibitor
# 4  SZEOGUBNOIXRLP-UHFFFAOYSA-N  veith_2009     assay          NaN   inhibitor

# %%
sns.countplot(data=veith, x="Active")
# Out:
# <Axes: xlabel='Active', ylabel='count'>

# %%
veith_actives = veith.query("Active == 1")
veith_actives["active"] = True
veith_actives = veith_actives[keep_cols_all]
# Out:
# /tmp/ipykernel_48886/1919675608.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   veith_actives["active"] = True

# %%
veith_actives
# Out:
#                                         CANONICAL_SMILES  \
# 1      O=c1[nH]c2cc3c(cc2cc1CN(CCCO)Cc1nnnn1Cc1ccc(F)...
# 2             CC(=O)N(c1ccc2oc(=O)sc2c1)S(=O)(=O)c1cccs1
# 3        COc1ccccc1C(c1nnnn1C(C)(C)C)N1CCN(Cc2ccncc2)CC1
# 5      CCC(c1nnnn1CC1CCCO1)N(CCN1CCOCC1)Cc1cc2cc(C)cc...
# 10             CCN(CC)C(=O)CSc1nnc(-c2cc3ccccc3cc2O)n1CC
# ...                                                  ...
# 12290  CC[C@@H](c1ccccc1)n1c(=O)n2n(c1=O)[C@H]1[C@H](...
# 12296  O=c1n(Cc2cc3c(cc2Cl)OCO3)c(=O)n2n1CC[C@H]1/C(=...
# 12297  CC(C)CO/N=C1/[C@H]2O[C@@H]2[C@@H](O)[C@H]2[C@H...
# 12299  O=c1n(Cc2cc3c(cc2Cl)OCO3)c(=O)n2n1CC[C@H]1/C(=...
# 12303  O=C1C2=CCc3c(c(O)n(Cc4ccc5c(c4)OCO5)c3O)[C@@H]...
#
#                           INCHIKEY  active     dataset data_type  common_name  \
# 1      VTLXYSNKFGEFDQ-UHFFFAOYSA-N    True  veith_2009     assay          NaN
# 2      GEUQHFHLRHDTPU-UHFFFAOYSA-N    True  veith_2009     assay          NaN
# 3      JGYZDKDCKPRYSN-UHFFFAOYSA-N    True  veith_2009     assay          NaN
# 5      NFTSIGQBJYZZLX-UHFFFAOYSA-N    True  veith_2009     assay          NaN
# 10     VVRVXVFZSWROHR-UHFFFAOYSA-N    True  veith_2009     assay          NaN
# ...                            ...     ...         ...       ...          ...
# 12290  ZLCSKEDISVLOJH-RWKWVPCPSA-N    True  veith_2009     assay          NaN
# 12296  OFANGNFUSNKWLW-ICBRJBJWSA-N    True  veith_2009     assay          NaN
# 12297  XQGYPVYSJBOIOQ-LXUUIWEGSA-N    True  veith_2009     assay          NaN
# 12299  DFKPBUZAUWTLJY-KVRHHBQGSA-N    True  veith_2009     assay          NaN
# 12303  DNVWSWBUBQYWLG-DXDGOQJESA-N    True  veith_2009     assay          NaN
#
#       action_type
# 1       inhibitor
# 2       inhibitor
# 3       inhibitor
# 5       inhibitor
# 10      inhibitor
# ...           ...
# 12290   inhibitor
# 12296   inhibitor
# 12297   inhibitor
# 12299   inhibitor
# 12303   inhibitor
#
# [5110 rows x 7 columns]

# %% [markdown]
# # Carbon-Mangels
#
# Composite dataset from Carbon-Mangels

# %%
carbon_mangels = pd.read_csv("processed/carbon-mangels_2011.csv")
carbon_mangels.head()
# Out:
#    common_name                                             SMILES  Active  \
# 0     abacavir      Nc1nc(NC2CC2)c2ncn([C@H]3C=C[C@@H](CO)C3)c2n1       0
# 1    abecarnil  COCc1c(C(=O)OC(C)C)ncc2[nH]c3ccc(OCc4ccccc4)cc...       0
# 2  abiraterone  C[C@]12CC[C@H]3[C@@H](CC=C4C[C@@H](O)CC[C@@]43...       0
# 3   acebutolol      CCCC(=O)Nc1ccc(OC[C@@H](O)CNC(C)C)c(C(C)=O)c1       0
# 4  aceclofenac              O=C(O)COC(=O)Cc1ccccc1Nc1c(Cl)cccc1Cl       0
#
#                                     CANONICAL_SMILES  \
# 0      Nc1nc(NC2CC2)c2ncn([C@H]3C=C[C@@H](CO)C3)c2n1
# 1  COCc1c(C(=O)OC(C)C)ncc2[nH]c3ccc(OCc4ccccc4)cc...
# 2  C[C@]12CC[C@H](O)CC1=CC[C@@H]1[C@@H]2CC[C@]2(C...
# 3      CCCC(=O)Nc1ccc(OC[C@@H](O)CNC(C)C)c(C(C)=O)c1
# 4              O=C(O)COC(=O)Cc1ccccc1Nc1c(Cl)cccc1Cl
#
#                       INCHIKEY              dataset data_type action_type
# 0  MCGSCOLBFJQGHM-SCZZXKLOSA-N  carbon-mangels_2011     assay   substrate
# 1  RLFKILXOLJVUNF-UHFFFAOYSA-N  carbon-mangels_2011     assay   substrate
# 2  GZOSMCIZMLWJML-VJLLXTKPSA-N  carbon-mangels_2011     assay   substrate
# 3  GOEMGAFJFRBGGG-HNNXBMFYSA-N  carbon-mangels_2011     assay   substrate
# 4  MNIPYSSQXLZQLJ-UHFFFAOYSA-N  carbon-mangels_2011     assay   substrate

# %%
sns.countplot(data=carbon_mangels, x="Active")
# Out:
# <Axes: xlabel='Active', ylabel='count'>

# %%
carbon_mangels_actives = carbon_mangels.query("Active == 1")

# %%
carbon_mangels_actives
# Out:
#        common_name                                             SMILES  Active  \
# 5    acenocoumarol  CC(=O)C[C@@H](c1ccc([N+](=O)[O-])cc1)c1c(O)c2c...       1
# 7    acetaminophen                                 CC(=O)Nc1ccc(O)cc1       1
# 11      adinazolam         CN(C)Cc1nnc2n1-c1ccc(Cl)cc1C(c1ccccc1)=NC2       1
# 13     albendazole                     CCCSc1ccc2nc(NC(=O)OC)[nH]c2c1       1
# 15      alfentanil   CCC(=O)N(c1ccccc1)C1(COC)CCN(CCn2nnn(CC)c2=O)CC1       1
# ..             ...                                                ...     ...
# 663    ziprasidone     O=C1Cc2cc(CCN3CCN(c4nsc5ccccc45)CC3)c(Cl)cc2N1       1
# 665       zolpidem            Cc1ccc(-c2nc3ccc(C)cn3c2CC(=O)N(C)C)cc1       1
# 666     zonisamide                           NS(=O)(=O)Cc1noc2ccccc12       1
# 667      zopiclone  CN1CCN(C(=O)O[C@H]2c3nccnc3C(=O)N2c2ccc(Cl)cn2...       1
# 668       zotepine                 CN(C)CCOC1=Cc2ccccc2Sc2ccc(Cl)cc21       1
#
#                                       CANONICAL_SMILES  \
# 5    CC(=O)C[C@@H](c1ccc([N+](=O)[O-])cc1)c1c(O)c2c...
# 7                                   CC(=O)Nc1ccc(O)cc1
# 11          CN(C)Cc1nnc2n1-c1ccc(Cl)cc1C(c1ccccc1)=NC2
# 13                      CCCSc1ccc2[nH]c(NC(=O)OC)nc2c1
# 15    CCC(=O)N(c1ccccc1)C1(COC)CCN(CCn2nnn(CC)c2=O)CC1
# ..                                                 ...
# 663   Oc1cc2cc(CCN3CCN(c4nsc5ccccc45)CC3)c(Cl)cc2[nH]1
# 665            Cc1ccc(-c2nc3ccc(C)cn3c2CC(=O)N(C)C)cc1
# 666                           NS(=O)(=O)Cc1noc2ccccc12
# 667  CN1CCN(C(=O)O[C@H]2c3nccnc3C(=O)N2c2ccc(Cl)cn2...
# 668                 CN(C)CCOC1=Cc2ccccc2Sc2ccc(Cl)cc21
#
#                         INCHIKEY              dataset data_type action_type
# 5    VABCILAOYCMVPS-HNNXBMFYSA-N  carbon-mangels_2011     assay   substrate
# 7    RZVAJINKPMORJF-UHFFFAOYSA-N  carbon-mangels_2011     assay   substrate
# 11   GJSLOMWRLALDCT-UHFFFAOYSA-N  carbon-mangels_2011     assay   substrate
# 13   HXHWSAZORRCQMX-UHFFFAOYSA-N  carbon-mangels_2011     assay   substrate
# 15   IDBPHNDTYPBSNI-UHFFFAOYSA-N  carbon-mangels_2011     assay   substrate
# ..                           ...                  ...       ...         ...
# 663  CARRCRVKWDEWCD-UHFFFAOYSA-N  carbon-mangels_2011     assay   substrate
# 665  ZAFYATHCZYHLPB-UHFFFAOYSA-N  carbon-mangels_2011     assay   substrate
# 666  UBQNRHZMVUUOMG-UHFFFAOYSA-N  carbon-mangels_2011     assay   substrate
# 667  GBBSUAFBMRNDJC-INIZCTEOSA-N  carbon-mangels_2011     assay   substrate
# 668  HDOZVRUNCMBHFH-UHFFFAOYSA-N  carbon-mangels_2011     assay   substrate
#
# [355 rows x 8 columns]

# %%
carbon_mangels_actives["active"] = True
carbon_mangels_actives = carbon_mangels_actives[keep_cols_all]
# Out:
# /tmp/ipykernel_48886/225345057.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   carbon_mangels_actives["active"] = True

# %%
carbon_mangels_actives
# Out:
#                                       CANONICAL_SMILES  \
# 5    CC(=O)C[C@@H](c1ccc([N+](=O)[O-])cc1)c1c(O)c2c...
# 7                                   CC(=O)Nc1ccc(O)cc1
# 11          CN(C)Cc1nnc2n1-c1ccc(Cl)cc1C(c1ccccc1)=NC2
# 13                      CCCSc1ccc2[nH]c(NC(=O)OC)nc2c1
# 15    CCC(=O)N(c1ccccc1)C1(COC)CCN(CCn2nnn(CC)c2=O)CC1
# ..                                                 ...
# 663   Oc1cc2cc(CCN3CCN(c4nsc5ccccc45)CC3)c(Cl)cc2[nH]1
# 665            Cc1ccc(-c2nc3ccc(C)cn3c2CC(=O)N(C)C)cc1
# 666                           NS(=O)(=O)Cc1noc2ccccc12
# 667  CN1CCN(C(=O)O[C@H]2c3nccnc3C(=O)N2c2ccc(Cl)cn2...
# 668                 CN(C)CCOC1=Cc2ccccc2Sc2ccc(Cl)cc21
#
#                         INCHIKEY  active              dataset data_type  \
# 5    VABCILAOYCMVPS-HNNXBMFYSA-N    True  carbon-mangels_2011     assay
# 7    RZVAJINKPMORJF-UHFFFAOYSA-N    True  carbon-mangels_2011     assay
# 11   GJSLOMWRLALDCT-UHFFFAOYSA-N    True  carbon-mangels_2011     assay
# 13   HXHWSAZORRCQMX-UHFFFAOYSA-N    True  carbon-mangels_2011     assay
# 15   IDBPHNDTYPBSNI-UHFFFAOYSA-N    True  carbon-mangels_2011     assay
# ..                           ...     ...                  ...       ...
# 663  CARRCRVKWDEWCD-UHFFFAOYSA-N    True  carbon-mangels_2011     assay
# 665  ZAFYATHCZYHLPB-UHFFFAOYSA-N    True  carbon-mangels_2011     assay
# 666  UBQNRHZMVUUOMG-UHFFFAOYSA-N    True  carbon-mangels_2011     assay
# 667  GBBSUAFBMRNDJC-INIZCTEOSA-N    True  carbon-mangels_2011     assay
# 668  HDOZVRUNCMBHFH-UHFFFAOYSA-N    True  carbon-mangels_2011     assay
#
#        common_name action_type
# 5    acenocoumarol   substrate
# 7    acetaminophen   substrate
# 11      adinazolam   substrate
# 13     albendazole   substrate
# 15      alfentanil   substrate
# ..             ...         ...
# 663    ziprasidone   substrate
# 665       zolpidem   substrate
# 666     zonisamide   substrate
# 667      zopiclone   substrate
# 668       zotepine   substrate
#
# [355 rows x 7 columns]

# %% [markdown]
# # Chembl
#
# The chembl data is an aggregation for CYP3A4  P08684
#
# Some postprocessing steps have been applied to select high quality actives from the range of assays available, defs not the only way to do this.
#
#
#
#
# * Select assays with IC50, AC50, pIC50, XC50, EC50, Ki or potency endpoints
# * Select assays in nM
# * Select assays with >=  N molecules (10)
# * Select compounds with mean pChembl > 5 accross all assays
# * Select compounds that appear in >= L of assays

# %%
chembl_actives = pd.read_csv("processed/chembl_active_selected.csv")
chembl_actives.head()
# Out:
#                                     CANONICAL_SMILES  \
# 0  CC(=O)N1CCN(c2ccc(OCC3COC(Cn4ccnc4)(c4ccc(Cl)c...
# 1                         CCC1C(=O)OC[C@H]1Cc1cncn1C
# 2             Clc1ccccc1C(c1ccccc1)(c1ccccc1)n1ccnc1
# 3                    CNCCCC12CCC(c3ccccc31)c1ccccc12
# 4        Clc1ccc(COC(Cn2ccnc2)c2ccc(Cl)cc2Cl)c(Cl)c1
#
#                       INCHIKEY  pChEMBL mean  pChEMBL std  \
# 0  XMAYWYJOQHXEEK-UHFFFAOYSA-N      7.013500     0.618796
# 1  QCHFTSOMWOSFHM-HNHGDDPOSA-N      5.052941     0.285302
# 2  VNFPBHJOKIVQEB-UHFFFAOYSA-N      7.237692     0.358798
# 3  QSLMDECMDJKHMQ-UHFFFAOYSA-N      5.473846     0.281470
# 4  BYBLEWFAAKGYCD-UHFFFAOYSA-N      6.060000     0.608590
#
#                  common_name  appears_in_N_ChEMBL_assays action_type  \
# 0               KETOCONAZOLE                          21         NaN
# 1                    SALAGEN                          17         NaN
# 2               CLOTRIMAZOLE                          14         NaN
# 3  MAPROTILINE HYDROCHLORIDE                          13         NaN
# 4         MICONAZOLE NITRATE                          12         NaN
#
#           dataset  active
# 0  ChEMBL_curated    True
# 1  ChEMBL_curated    True
# 2  ChEMBL_curated    True
# 3  ChEMBL_curated    True
# 4  ChEMBL_curated    True

# %% [markdown]
# # FDA approved
#
# Compounds the FDA really reccomends you try

# %%
fda = pd.read_csv("./processed/fda.csv")

# %% [markdown]
# # Combine everything
#
#
# ## NOTE
#
# common name being blank is not that these compounds do not have a common name, but that they need to be pulled from pubchem

# %%
combined_literature = pd.concat([novartis_actives, ncats_actives, veith_actives, carbon_mangels_actives, fda])
combined_literature
# Out:
#                                      CANONICAL_SMILES  \
# 5   O=[N+]([O-])c1cccc2[nH]c3c(N4CCN(CCc5ccc(F)c(F...
# 8    COc1ccc(C(O)c2c3cc(OC)cc(C)c3nc3[nH]nc(C)c23)cc1
# 9        NC(C(=O)N1CCC(Nc2ccc3[nH]ncc3c2)CC1)c1ccccc1
# 12  Cc1cc(C)cc(-c2[nH]c3ccc(C(C)(C)C(=O)N4CC5CCC4C...
# 19  O=[N+]([O-])c1ccc2[nH]c3c(N4CCN(CCc5ccc(F)c(F)...
# ..                                                ...
# 6   COc1ccc(CCN(C)CCCC(C#N)(c2ccc(OC)c(OC)c2)C(C)C...
# 7   CO[C@H]1C[C@H](O[C@@H]2C(C)C(=O)O[C@H](C)[C@H]...
# 8              Cc1ncc2n1-c1ccc(Cl)cc1C(c1ccccc1F)=NC2
# 9             Cc1nnc2n1-c1ccc(Cl)cc1C(c1ccccc1Cl)=NC2
# 10  C[C@]12CC[C@H]3[C@@H](CC=C4CC(=O)CC[C@@]43C)[C...
#
#                        INCHIKEY active        dataset  data_type  \
# 5   FOTDWYFVTJDSLW-UHFFFAOYSA-N   True  novartis_2024  surrogate
# 8   NJVOBGWGMQUPTG-UHFFFAOYSA-N   True  novartis_2024  surrogate
# 9   AGVLKBKXJWTFQT-UHFFFAOYSA-N   True  novartis_2024  surrogate
# 12  RMVSZBRIILAXIH-WUXOVTSDSA-N   True  novartis_2024  surrogate
# 19  RYGJKZCQNUAGKW-UHFFFAOYSA-N   True  novartis_2024  surrogate
# ..                          ...    ...            ...        ...
# 6   SGTNSNPWRIOYBX-UHFFFAOYSA-N   True            FDA        NaN
# 7   LQCLVBQBTUVCEQ-WXGPWXIXSA-N   True            FDA        NaN
# 8   DDLIGBOFAVUZHB-UHFFFAOYSA-N   True            FDA        NaN
# 9   JOFWLTCLBGQGBO-UHFFFAOYSA-N   True            FDA        NaN
# 10  SEDRVEWTPRTLOZ-DYKIIFRCSA-N   True            FDA        NaN
#
#         common_name action_type  \
# 5               NaN   inhibitor
# 8               NaN   inhibitor
# 9               NaN   inhibitor
# 12              NaN   inhibitor
# 19              NaN   inhibitor
# ..              ...         ...
# 6         verapamil   inhibitor
# 7    troleandomycin   inhibitor
# 8         midazolam   substrate
# 9         triazolam   substrate
# 10     testosterone   substrate
#
#                                                SMILES FDA_recommended
# 5                                                 NaN             NaN
# 8                                                 NaN             NaN
# 9                                                 NaN             NaN
# 12                                                NaN             NaN
# 19                                                NaN             NaN
# ..                                                ...             ...
# 6   COc1ccc(CCN(C)CCCC(C#N)(c2ccc(OC)c(OC)c2)C(C)C...            True
# 7   CO[C@H]1C[C@H](O[C@H]2[C@H](C)[C@@H](O[C@@H]3O...            True
# 8              Cc1ncc2n1-c1ccc(Cl)cc1C(c1ccccc1F)=NC2            True
# 9             Cc1nnc2n1-c1ccc(Cl)cc1C(c1ccccc1Cl)=NC2            True
# 10  C[C@]12CC[C@H]3[C@@H](CCC4=CC(=O)CC[C@@]43C)[C...            True
#
# [10262 rows x 9 columns]

# %%
combined_literature["FDA_recommended"] = combined_literature["FDA_recommended"].fillna(False)

# %%
combined_literature.INCHIKEY.duplicated().sum()  # close same result with SMILES
# Out:
# 980

# %%
combined_literature.dropna(subset="INCHIKEY", inplace=True)

# %%
combined_literature_chembl = pd.concat([combined_literature, chembl_actives])

# %%
combined_literature_chembl
# Out:
#                                        CANONICAL_SMILES  \
# 5     O=[N+]([O-])c1cccc2[nH]c3c(N4CCN(CCc5ccc(F)c(F...
# 8      COc1ccc(C(O)c2c3cc(OC)cc(C)c3nc3[nH]nc(C)c23)cc1
# 9          NC(C(=O)N1CCC(Nc2ccc3[nH]ncc3c2)CC1)c1ccccc1
# 12    Cc1cc(C)cc(-c2[nH]c3ccc(C(C)(C)C(=O)N4CC5CCC4C...
# 19    O=[N+]([O-])c1ccc2[nH]c3c(N4CCN(CCc5ccc(F)c(F)...
# ...                                                 ...
# 2691  CO[C@H]1COC(=O)C(C)NC(=O)C/C=C\[C@@H](C)[C@@H]...
# 2692                         c1cc(NC2CC2)nc(-c2ccoc2)n1
# 2693                   O=c1cc(O)cc(C=Cc2ccc(O)c(O)c2)o1
# 2694              Fc1ccc(Nc2ncncc2-c2ccccc2C(F)(F)F)cc1
# 2695       N#CCCn1c(=O)c(-c2cccs2)nc2cnc(Nc3ccccc3)nc21
#
#                          INCHIKEY active         dataset  data_type  \
# 5     FOTDWYFVTJDSLW-UHFFFAOYSA-N   True   novartis_2024  surrogate
# 8     NJVOBGWGMQUPTG-UHFFFAOYSA-N   True   novartis_2024  surrogate
# 9     AGVLKBKXJWTFQT-UHFFFAOYSA-N   True   novartis_2024  surrogate
# 12    RMVSZBRIILAXIH-WUXOVTSDSA-N   True   novartis_2024  surrogate
# 19    RYGJKZCQNUAGKW-UHFFFAOYSA-N   True   novartis_2024  surrogate
# ...                           ...    ...             ...        ...
# 2691  YMMZNHJLDTYKIO-IRNQRVLXSA-N   True  ChEMBL_curated        NaN
# 2692  ITBQVUHQAISPBQ-UHFFFAOYSA-N   True  ChEMBL_curated        NaN
# 2693  SGJNQVTUYXCBKH-UHFFFAOYSA-N   True  ChEMBL_curated        NaN
# 2694  KGLWGKSRHOVICM-UHFFFAOYSA-N   True  ChEMBL_curated        NaN
# 2695  YRCOSBMXMACOQI-UHFFFAOYSA-N   True  ChEMBL_curated        NaN
#
#      common_name action_type SMILES FDA_recommended  pChEMBL mean  \
# 5            NaN   inhibitor    NaN           False           NaN
# 8            NaN   inhibitor    NaN           False           NaN
# 9            NaN   inhibitor    NaN           False           NaN
# 12           NaN   inhibitor    NaN           False           NaN
# 19           NaN   inhibitor    NaN           False           NaN
# ...          ...         ...    ...             ...           ...
# 2691         NaN         NaN    NaN             NaN           5.4
# 2692         NaN         NaN    NaN             NaN           5.3
# 2693         NaN         NaN    NaN             NaN           5.5
# 2694         NaN         NaN    NaN             NaN           6.4
# 2695         NaN         NaN    NaN             NaN           5.3
#
#       pChEMBL std  appears_in_N_ChEMBL_assays
# 5             NaN                         NaN
# 8             NaN                         NaN
# 9             NaN                         NaN
# 12            NaN                         NaN
# 19            NaN                         NaN
# ...           ...                         ...
# 2691          0.0                         3.0
# 2692          0.0                         3.0
# 2693          0.0                         3.0
# 2694          0.0                         3.0
# 2695          0.0                         3.0
#
# [12957 rows x 12 columns]

# %%
combined_literature_chembl.FDA_recommended.value_counts()
# Out:
# FDA_recommended
# False    10250
#  True       11
# Name: count, dtype: int64

# %%
combined_literature_chembl.dataset.value_counts()
# Out:
# dataset
# veith_2009               5110
# ChEMBL_curated           2696
# novartis_2024            2639
# ncats_adme_aid1645841    2146
# carbon-mangels_2011       355
# FDA                        11
# Name: count, dtype: int64

# %%
combined_literature_chembl.INCHIKEY.duplicated().sum()
# Out:
# 2890

# %%
combined_literature_chembl.INCHIKEY.isna().sum()
# Out:
# 0

# %%
combined_literature_chembl
# Out:
#                                        CANONICAL_SMILES  \
# 5     O=[N+]([O-])c1cccc2[nH]c3c(N4CCN(CCc5ccc(F)c(F...
# 8      COc1ccc(C(O)c2c3cc(OC)cc(C)c3nc3[nH]nc(C)c23)cc1
# 9          NC(C(=O)N1CCC(Nc2ccc3[nH]ncc3c2)CC1)c1ccccc1
# 12    Cc1cc(C)cc(-c2[nH]c3ccc(C(C)(C)C(=O)N4CC5CCC4C...
# 19    O=[N+]([O-])c1ccc2[nH]c3c(N4CCN(CCc5ccc(F)c(F)...
# ...                                                 ...
# 2691  CO[C@H]1COC(=O)C(C)NC(=O)C/C=C\[C@@H](C)[C@@H]...
# 2692                         c1cc(NC2CC2)nc(-c2ccoc2)n1
# 2693                   O=c1cc(O)cc(C=Cc2ccc(O)c(O)c2)o1
# 2694              Fc1ccc(Nc2ncncc2-c2ccccc2C(F)(F)F)cc1
# 2695       N#CCCn1c(=O)c(-c2cccs2)nc2cnc(Nc3ccccc3)nc21
#
#                          INCHIKEY active         dataset  data_type  \
# 5     FOTDWYFVTJDSLW-UHFFFAOYSA-N   True   novartis_2024  surrogate
# 8     NJVOBGWGMQUPTG-UHFFFAOYSA-N   True   novartis_2024  surrogate
# 9     AGVLKBKXJWTFQT-UHFFFAOYSA-N   True   novartis_2024  surrogate
# 12    RMVSZBRIILAXIH-WUXOVTSDSA-N   True   novartis_2024  surrogate
# 19    RYGJKZCQNUAGKW-UHFFFAOYSA-N   True   novartis_2024  surrogate
# ...                           ...    ...             ...        ...
# 2691  YMMZNHJLDTYKIO-IRNQRVLXSA-N   True  ChEMBL_curated        NaN
# 2692  ITBQVUHQAISPBQ-UHFFFAOYSA-N   True  ChEMBL_curated        NaN
# 2693  SGJNQVTUYXCBKH-UHFFFAOYSA-N   True  ChEMBL_curated        NaN
# 2694  KGLWGKSRHOVICM-UHFFFAOYSA-N   True  ChEMBL_curated        NaN
# 2695  YRCOSBMXMACOQI-UHFFFAOYSA-N   True  ChEMBL_curated        NaN
#
#      common_name action_type SMILES FDA_recommended  pChEMBL mean  \
# 5            NaN   inhibitor    NaN           False           NaN
# 8            NaN   inhibitor    NaN           False           NaN
# 9            NaN   inhibitor    NaN           False           NaN
# 12           NaN   inhibitor    NaN           False           NaN
# 19           NaN   inhibitor    NaN           False           NaN
# ...          ...         ...    ...             ...           ...
# 2691         NaN         NaN    NaN             NaN           5.4
# 2692         NaN         NaN    NaN             NaN           5.3
# 2693         NaN         NaN    NaN             NaN           5.5
# 2694         NaN         NaN    NaN             NaN           6.4
# 2695         NaN         NaN    NaN             NaN           5.3
#
#       pChEMBL std  appears_in_N_ChEMBL_assays
# 5             NaN                         NaN
# 8             NaN                         NaN
# 9             NaN                         NaN
# 12            NaN                         NaN
# 19            NaN                         NaN
# ...           ...                         ...
# 2691          0.0                         3.0
# 2692          0.0                         3.0
# 2693          0.0                         3.0
# 2694          0.0                         3.0
# 2695          0.0                         3.0
#
# [12957 rows x 12 columns]

# %%
appears = combined_literature_chembl.groupby("INCHIKEY")["dataset"].nunique().reset_index(name="appears_in_N_datasets")
appears.set_index("INCHIKEY")
# Out:
#                              appears_in_N_datasets
# INCHIKEY
# AABFWJDLCCDJJN-UHFFFAOYSA-N                      1
# AABYLPRACHMDSN-BIWBPYCESA-N                      3
# AABYLPRACHMDSN-REETXPBOSA-N                      3
# AAEXTICMMYDGTO-UHFFFAOYSA-N                      1
# AAGIFVFWIBEXDH-UHFFFAOYSA-N                      2
# ...                                            ...
# ZZQYLRUTULGFDB-OHJDGCPNSA-N                      2
# ZZUUFZGULQUYPH-UHFFFAOYSA-N                      1
# ZZVAYOCXKRUKNH-UHFFFAOYSA-N                      3
# ZZVGLDBDDYESAB-UHFFFAOYSA-N                      1
# ZZVQBBBPXVEEIS-UHFFFAOYSA-N                      1
#
# [10067 rows x 1 columns]

# %%
appears.isna().sum()
# Out:
# INCHIKEY                 0
# appears_in_N_datasets    0
# dtype: int64

# %%
sns.countplot(data=appears, x="appears_in_N_datasets")
# Out:
# <Axes: xlabel='appears_in_N_datasets', ylabel='count'>

# %%
combined_literature_chembl_w_counts = combined_literature_chembl.merge(appears, on="INCHIKEY")
combined_literature_chembl_w_counts
# Out:
#                                         CANONICAL_SMILES  \
# 0      O=[N+]([O-])c1cccc2[nH]c3c(N4CCN(CCc5ccc(F)c(F...
# 1       COc1ccc(C(O)c2c3cc(OC)cc(C)c3nc3[nH]nc(C)c23)cc1
# 2           NC(C(=O)N1CCC(Nc2ccc3[nH]ncc3c2)CC1)c1ccccc1
# 3      Cc1cc(C)cc(-c2[nH]c3ccc(C(C)(C)C(=O)N4CC5CCC4C...
# 4      O=[N+]([O-])c1ccc2[nH]c3c(N4CCN(CCc5ccc(F)c(F)...
# ...                                                  ...
# 12952  CO[C@H]1COC(=O)C(C)NC(=O)C/C=C\[C@@H](C)[C@@H]...
# 12953                         c1cc(NC2CC2)nc(-c2ccoc2)n1
# 12954                   O=c1cc(O)cc(C=Cc2ccc(O)c(O)c2)o1
# 12955              Fc1ccc(Nc2ncncc2-c2ccccc2C(F)(F)F)cc1
# 12956       N#CCCn1c(=O)c(-c2cccs2)nc2cnc(Nc3ccccc3)nc21
#
#                           INCHIKEY active         dataset  data_type  \
# 0      FOTDWYFVTJDSLW-UHFFFAOYSA-N   True   novartis_2024  surrogate
# 1      NJVOBGWGMQUPTG-UHFFFAOYSA-N   True   novartis_2024  surrogate
# 2      AGVLKBKXJWTFQT-UHFFFAOYSA-N   True   novartis_2024  surrogate
# 3      RMVSZBRIILAXIH-WUXOVTSDSA-N   True   novartis_2024  surrogate
# 4      RYGJKZCQNUAGKW-UHFFFAOYSA-N   True   novartis_2024  surrogate
# ...                            ...    ...             ...        ...
# 12952  YMMZNHJLDTYKIO-IRNQRVLXSA-N   True  ChEMBL_curated        NaN
# 12953  ITBQVUHQAISPBQ-UHFFFAOYSA-N   True  ChEMBL_curated        NaN
# 12954  SGJNQVTUYXCBKH-UHFFFAOYSA-N   True  ChEMBL_curated        NaN
# 12955  KGLWGKSRHOVICM-UHFFFAOYSA-N   True  ChEMBL_curated        NaN
# 12956  YRCOSBMXMACOQI-UHFFFAOYSA-N   True  ChEMBL_curated        NaN
#
#       common_name action_type SMILES FDA_recommended  pChEMBL mean  \
# 0             NaN   inhibitor    NaN           False           NaN
# 1             NaN   inhibitor    NaN           False           NaN
# 2             NaN   inhibitor    NaN           False           NaN
# 3             NaN   inhibitor    NaN           False           NaN
# 4             NaN   inhibitor    NaN           False           NaN
# ...           ...         ...    ...             ...           ...
# 12952         NaN         NaN    NaN             NaN           5.4
# 12953         NaN         NaN    NaN             NaN           5.3
# 12954         NaN         NaN    NaN             NaN           5.5
# 12955         NaN         NaN    NaN             NaN           6.4
# 12956         NaN         NaN    NaN             NaN           5.3
#
#        pChEMBL std  appears_in_N_ChEMBL_assays  appears_in_N_datasets
# 0              NaN                         NaN                      1
# 1              NaN                         NaN                      1
# 2              NaN                         NaN                      1
# 3              NaN                         NaN                      1
# 4              NaN                         NaN                      1
# ...            ...                         ...                    ...
# 12952          0.0                         3.0                      2
# 12953          0.0                         3.0                      2
# 12954          0.0                         3.0                      1
# 12955          0.0                         3.0                      2
# 12956          0.0                         3.0                      2
#
# [12957 rows x 13 columns]

# %%
df_dummies = pd.get_dummies(combined_literature_chembl_w_counts['dataset'], prefix='dataset').join(combined_literature_chembl_w_counts["INCHIKEY"])
df_dummies
# Out:
#        dataset_ChEMBL_curated  dataset_FDA  dataset_carbon-mangels_2011  \
# 0                       False        False                        False
# 1                       False        False                        False
# 2                       False        False                        False
# 3                       False        False                        False
# 4                       False        False                        False
# ...                       ...          ...                          ...
# 12952                    True        False                        False
# 12953                    True        False                        False
# 12954                    True        False                        False
# 12955                    True        False                        False
# 12956                    True        False                        False
#
#        dataset_ncats_adme_aid1645841  dataset_novartis_2024  \
# 0                              False                   True
# 1                              False                   True
# 2                              False                   True
# 3                              False                   True
# 4                              False                   True
# ...                              ...                    ...
# 12952                          False                  False
# 12953                          False                  False
# 12954                          False                  False
# 12955                          False                  False
# 12956                          False                  False
#
#        dataset_veith_2009                     INCHIKEY
# 0                   False  FOTDWYFVTJDSLW-UHFFFAOYSA-N
# 1                   False  NJVOBGWGMQUPTG-UHFFFAOYSA-N
# 2                   False  AGVLKBKXJWTFQT-UHFFFAOYSA-N
# 3                   False  RMVSZBRIILAXIH-WUXOVTSDSA-N
# 4                   False  RYGJKZCQNUAGKW-UHFFFAOYSA-N
# ...                   ...                          ...
# 12952               False  YMMZNHJLDTYKIO-IRNQRVLXSA-N
# 12953               False  ITBQVUHQAISPBQ-UHFFFAOYSA-N
# 12954               False  SGJNQVTUYXCBKH-UHFFFAOYSA-N
# 12955               False  KGLWGKSRHOVICM-UHFFFAOYSA-N
# 12956               False  YRCOSBMXMACOQI-UHFFFAOYSA-N
#
# [12957 rows x 7 columns]

# %%
df_result = df_dummies.groupby('INCHIKEY').max().reset_index()
df_result = df_result.set_index("INCHIKEY")

# %%
# cat_dataname = combined_literature_chembl.groupby("INCHIKEY")["dataset"].apply(lambda x: "_+_".join(x)).reset_index(name="dataset_comb").set_index("INCHIKEY")
# cat_dataname

# %%
combined_literature_chembl_w_counts = combined_literature_chembl_w_counts.merge(df_result, on="INCHIKEY")
combined_literature_chembl_w_counts
# Out:
#                                         CANONICAL_SMILES  \
# 0      O=[N+]([O-])c1cccc2[nH]c3c(N4CCN(CCc5ccc(F)c(F...
# 1       COc1ccc(C(O)c2c3cc(OC)cc(C)c3nc3[nH]nc(C)c23)cc1
# 2           NC(C(=O)N1CCC(Nc2ccc3[nH]ncc3c2)CC1)c1ccccc1
# 3      Cc1cc(C)cc(-c2[nH]c3ccc(C(C)(C)C(=O)N4CC5CCC4C...
# 4      O=[N+]([O-])c1ccc2[nH]c3c(N4CCN(CCc5ccc(F)c(F)...
# ...                                                  ...
# 12952  CO[C@H]1COC(=O)C(C)NC(=O)C/C=C\[C@@H](C)[C@@H]...
# 12953                         c1cc(NC2CC2)nc(-c2ccoc2)n1
# 12954                   O=c1cc(O)cc(C=Cc2ccc(O)c(O)c2)o1
# 12955              Fc1ccc(Nc2ncncc2-c2ccccc2C(F)(F)F)cc1
# 12956       N#CCCn1c(=O)c(-c2cccs2)nc2cnc(Nc3ccccc3)nc21
#
#                           INCHIKEY active         dataset  data_type  \
# 0      FOTDWYFVTJDSLW-UHFFFAOYSA-N   True   novartis_2024  surrogate
# 1      NJVOBGWGMQUPTG-UHFFFAOYSA-N   True   novartis_2024  surrogate
# 2      AGVLKBKXJWTFQT-UHFFFAOYSA-N   True   novartis_2024  surrogate
# 3      RMVSZBRIILAXIH-WUXOVTSDSA-N   True   novartis_2024  surrogate
# 4      RYGJKZCQNUAGKW-UHFFFAOYSA-N   True   novartis_2024  surrogate
# ...                            ...    ...             ...        ...
# 12952  YMMZNHJLDTYKIO-IRNQRVLXSA-N   True  ChEMBL_curated        NaN
# 12953  ITBQVUHQAISPBQ-UHFFFAOYSA-N   True  ChEMBL_curated        NaN
# 12954  SGJNQVTUYXCBKH-UHFFFAOYSA-N   True  ChEMBL_curated        NaN
# 12955  KGLWGKSRHOVICM-UHFFFAOYSA-N   True  ChEMBL_curated        NaN
# 12956  YRCOSBMXMACOQI-UHFFFAOYSA-N   True  ChEMBL_curated        NaN
#
#       common_name action_type SMILES FDA_recommended  pChEMBL mean  \
# 0             NaN   inhibitor    NaN           False           NaN
# 1             NaN   inhibitor    NaN           False           NaN
# 2             NaN   inhibitor    NaN           False           NaN
# 3             NaN   inhibitor    NaN           False           NaN
# 4             NaN   inhibitor    NaN           False           NaN
# ...           ...         ...    ...             ...           ...
# 12952         NaN         NaN    NaN             NaN           5.4
# 12953         NaN         NaN    NaN             NaN           5.3
# 12954         NaN         NaN    NaN             NaN           5.5
# 12955         NaN         NaN    NaN             NaN           6.4
# 12956         NaN         NaN    NaN             NaN           5.3
#
#        pChEMBL std  appears_in_N_ChEMBL_assays  appears_in_N_datasets  \
# 0              NaN                         NaN                      1
# 1              NaN                         NaN                      1
# 2              NaN                         NaN                      1
# 3              NaN                         NaN                      1
# 4              NaN                         NaN                      1
# ...            ...                         ...                    ...
# 12952          0.0                         3.0                      2
# 12953          0.0                         3.0                      2
# 12954          0.0                         3.0                      1
# 12955          0.0                         3.0                      2
# 12956          0.0                         3.0                      2
#
#        dataset_ChEMBL_curated  dataset_FDA  dataset_carbon-mangels_2011  \
# 0                       False        False                        False
# 1                       False        False                        False
# 2                       False        False                        False
# 3                       False        False                        False
# 4                       False        False                        False
# ...                       ...          ...                          ...
# 12952                    True        False                        False
# 12953                    True        False                        False
# 12954                    True        False                        False
# 12955                    True        False                        False
# 12956                    True        False                        False
#
#        dataset_ncats_adme_aid1645841  dataset_novartis_2024  \
# 0                              False                   True
# 1                              False                   True
# 2                              False                   True
# 3                              False                   True
# 4                              False                   True
# ...                              ...                    ...
# 12952                          False                  False
# 12953                          False                  False
# 12954                          False                  False
# 12955                          False                  False
# 12956                          False                   True
#
#        dataset_veith_2009
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ...                   ...
# 12952                True
# 12953                True
# 12954               False
# 12955                True
# 12956               False
#
# [12957 rows x 19 columns]

# %%
combined_literature_chembl_w_counts.action_type.value_counts()
# Out:
# action_type
# inhibitor     9896
# substrate      355
#  inhibitor       8
#  substrate       3
# Name: count, dtype: int64

# %%
combined_literature_chembl_w_counts.INCHIKEY.nunique()
# Out:
# 10067

# %%
combined_literature_chembl_w_counts['common_name'].isna().sum()
# Out:
# 12306

# %%
# we can just sort by appears_in_N_ChEMBL_assays to get all the chembl data at the top, then uniquify on INCHIKEY

combined_literature_chembl_w_counts.sort_values(["appears_in_N_ChEMBL_assays", "appears_in_N_datasets"], ascending=[False,False],  inplace=True)

# %%
# fill common name from gropupby 
combined_literature_chembl_w_counts['common_name'] = combined_literature_chembl_w_counts.groupby('INCHIKEY')['common_name'].transform(lambda x: x.fillna(method='ffill').fillna(method='bfill'))
# Out:
# /tmp/ipykernel_48886/1877288904.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_literature_chembl_w_counts['common_name'] = combined_literature_chembl_w_counts.groupby('INCHIKEY')['common_name'].transform(lambda x: x.fillna(method='ffill').fillna(method='bfill'))
# /tmp/ipykernel_48886/1877288904.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   combined_literature_chembl_w_counts['common_name'] = combined_literature_chembl_w_counts.groupby('INCHIKEY')['common_name'].transform(lambda x: x.fillna(method='ffill').fillna(method='bfill'))

# %%
combined_literature_chembl_w_counts['common_name'].isna().sum()
# Out:
# 11977

# %%
combined_literature_chembl_w_counts.drop(columns=["dataset","data_type"], inplace=True)

# %%
combined_literature_chembl_w_counts.head()
# Out:
#                                         CANONICAL_SMILES  \
# 10261  CC(=O)N1CCN(c2ccc(OCC3COC(Cn4ccnc4)(c4ccc(Cl)c...
# 10262                         CCC1C(=O)OC[C@H]1Cc1cncn1C
# 10263             Clc1ccccc1C(c1ccccc1)(c1ccccc1)n1ccnc1
# 10264                    CNCCCC12CCC(c3ccccc31)c1ccccc12
# 10265        Clc1ccc(COC(Cn2ccnc2)c2ccc(Cl)cc2Cl)c(Cl)c1
#
#                           INCHIKEY active                common_name  \
# 10261  XMAYWYJOQHXEEK-UHFFFAOYSA-N   True               KETOCONAZOLE
# 10262  QCHFTSOMWOSFHM-HNHGDDPOSA-N   True                    SALAGEN
# 10263  VNFPBHJOKIVQEB-UHFFFAOYSA-N   True               CLOTRIMAZOLE
# 10264  QSLMDECMDJKHMQ-UHFFFAOYSA-N   True  MAPROTILINE HYDROCHLORIDE
# 10265  BYBLEWFAAKGYCD-UHFFFAOYSA-N   True         MICONAZOLE NITRATE
#
#       action_type SMILES FDA_recommended  pChEMBL mean  pChEMBL std  \
# 10261         NaN    NaN             NaN      7.013500     0.618796
# 10262         NaN    NaN             NaN      5.052941     0.285302
# 10263         NaN    NaN             NaN      7.237692     0.358798
# 10264         NaN    NaN             NaN      5.473846     0.281470
# 10265         NaN    NaN             NaN      6.060000     0.608590
#
#        appears_in_N_ChEMBL_assays  appears_in_N_datasets  \
# 10261                        21.0                      2
# 10262                        17.0                      1
# 10263                        14.0                      3
# 10264                        13.0                      3
# 10265                        12.0                      3
#
#        dataset_ChEMBL_curated  dataset_FDA  dataset_carbon-mangels_2011  \
# 10261                    True         True                        False
# 10262                    True        False                        False
# 10263                    True        False                         True
# 10264                    True        False                        False
# 10265                    True        False                        False
#
#        dataset_ncats_adme_aid1645841  dataset_novartis_2024  \
# 10261                          False                  False
# 10262                          False                  False
# 10263                           True                  False
# 10264                           True                  False
# 10265                           True                  False
#
#        dataset_veith_2009
# 10261               False
# 10262               False
# 10263               False
# 10264                True
# 10265                True

# %%
fda_reccomends_mask = combined_literature_chembl_w_counts.INCHIKEY.isin(fda.INCHIKEY)

fda_reccomends_mask
# Out:
# 10261     True
# 10262    False
# 10263    False
# 10264    False
# 10265    False
#          ...
# 3493     False
# 3492     False
# 3491     False
# 3490     False
# 3504     False
# Name: INCHIKEY, Length: 10067, dtype: bool

# %%
combined_literature_chembl_w_counts["FDA_recommended"][fda_reccomends_mask] = True
# Out:
# /tmp/ipykernel_48886/383759248.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_literature_chembl_w_counts["FDA_recommended"][fda_reccomends_mask] = True

# %%
combined_literature_chembl_w_counts.drop_duplicates(subset="INCHIKEY", inplace=True)

# %%
combined_literature_chembl_w_counts["action_type"] = combined_literature_chembl_w_counts["action_type"].fillna("unknown")

# %%
combined_literature_chembl_w_counts["inclusion_score"] = combined_literature_chembl_w_counts["appears_in_N_ChEMBL_assays"].fillna(0) + combined_literature_chembl_w_counts["appears_in_N_datasets"].fillna(0)

# %%
combined_literature_chembl_w_counts.sort_values("inclusion_score", ascending=False, inplace=True)

# %%
combined_literature_chembl_w_counts.to_csv("final/actives_final.csv", index=False)

# %%
combined_literature_chembl_w_counts
# Out:
#                                         CANONICAL_SMILES  \
# 10261  CC(=O)N1CCN(c2ccc(OCC3COC(Cn4ccnc4)(c4ccc(Cl)c...
# 10262                         CCC1C(=O)OC[C@H]1Cc1cncn1C
# 10263             Clc1ccccc1C(c1ccccc1)(c1ccccc1)n1ccnc1
# 10264                    CNCCCC12CCC(c3ccccc31)c1ccccc12
# 10265        Clc1ccc(COC(Cn2ccnc2)c2ccc(Cl)cc2Cl)c(Cl)c1
# ...                                                  ...
# 10141                       c1ccc(C2(N3CCCCC3)CCCCC2)cc1
# 10142      COc1ccc(-c2nc3cc(C4=NNC(=O)CC4C)ccc3[nH]2)cc1
# 10145          CCc1ccc(CCOc2ccc(Cc3sc(=O)[nH]c3O)cc2)nc1
# 10146  COC(=O)C1=C(C)N=C(C)C(C(=O)OC/C=C/c2ccccc2)[C@...
# 10203               CN(C/C=C/C#CC(C)(C)C)Cc1cccc2ccccc12
#
#                           INCHIKEY active                common_name  \
# 10261  XMAYWYJOQHXEEK-UHFFFAOYSA-N   True               KETOCONAZOLE
# 10262  QCHFTSOMWOSFHM-HNHGDDPOSA-N   True                    SALAGEN
# 10263  VNFPBHJOKIVQEB-UHFFFAOYSA-N   True               CLOTRIMAZOLE
# 10264  QSLMDECMDJKHMQ-UHFFFAOYSA-N   True  MAPROTILINE HYDROCHLORIDE
# 10265  BYBLEWFAAKGYCD-UHFFFAOYSA-N   True         MICONAZOLE NITRATE
# ...                            ...    ...                        ...
# 10141  JTJMJGYZQZDUJJ-UHFFFAOYSA-N   True              phencyclidine
# 10142  GLBJJMFZWDBELO-UHFFFAOYSA-N   True                 pimobendan
# 10145  IYYGBZJXHJSLEV-UHFFFAOYSA-N   True               pioglitazone
# 10146  ISBYPYUIOMMYGS-RRWAONMYSA-N   True                pranidipine
# 10203  DOMXUEMWDBAQBQ-WEVVVXLNSA-N   True                terbinafine
#
#       action_type SMILES FDA_recommended  pChEMBL mean  pChEMBL std  \
# 10261     unknown    NaN            True      7.013500     0.618796
# 10262     unknown    NaN             NaN      5.052941     0.285302
# 10263     unknown    NaN             NaN      7.237692     0.358798
# 10264     unknown    NaN             NaN      5.473846     0.281470
# 10265     unknown    NaN             NaN      6.060000     0.608590
# ...           ...    ...             ...           ...          ...
# 10141   substrate    NaN           False           NaN          NaN
# 10142   substrate    NaN           False           NaN          NaN
# 10145   substrate    NaN           False           NaN          NaN
# 10146   substrate    NaN           False           NaN          NaN
# 10203   substrate    NaN           False           NaN          NaN
#
#        appears_in_N_ChEMBL_assays  appears_in_N_datasets  \
# 10261                        21.0                      2
# 10262                        17.0                      1
# 10263                        14.0                      3
# 10264                        13.0                      3
# 10265                        12.0                      3
# ...                           ...                    ...
# 10141                         NaN                      1
# 10142                         NaN                      1
# 10145                         NaN                      1
# 10146                         NaN                      1
# 10203                         NaN                      1
#
#        dataset_ChEMBL_curated  dataset_FDA  dataset_carbon-mangels_2011  \
# 10261                    True         True                        False
# 10262                    True        False                        False
# 10263                    True        False                         True
# 10264                    True        False                        False
# 10265                    True        False                        False
# ...                       ...          ...                          ...
# 10141                   False        False                         True
# 10142                   False        False                         True
# 10145                   False        False                         True
# 10146                   False        False                         True
# 10203                   False        False                         True
#
#        dataset_ncats_adme_aid1645841  dataset_novartis_2024  \
# 10261                          False                  False
# 10262                          False                  False
# 10263                           True                  False
# 10264                           True                  False
# 10265                           True                  False
# ...                              ...                    ...
# 10141                          False                  False
# 10142                          False                  False
# 10145                          False                  False
# 10146                          False                  False
# 10203                          False                  False
#
#        dataset_veith_2009  inclusion_score
# 10261               False             23.0
# 10262               False             18.0
# 10263               False             17.0
# 10264                True             16.0
# 10265                True             15.0
# ...                   ...              ...
# 10141               False              1.0
# 10142               False              1.0
# 10145               False              1.0
# 10146               False              1.0
# 10203               False              1.0
#
# [10067 rows x 18 columns]
