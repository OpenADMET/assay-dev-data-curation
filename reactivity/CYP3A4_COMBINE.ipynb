# %%
import pandas as pd
from rdkit import Chem
import seaborn as sns
from tqdm import tqdm
import numpy as np

# %%
! ls processed/
# Out:
# aid_589039_clinically_relevant.csv  drugbank_processed.csv
# carbon-mangels_2011.csv		    flockheart.csv
# CHEMBL1142817.csv		    xin_xu_ncats_adme.csv

# %%
aid_589 = pd.read_csv("./processed/aid_589039_clinically_relevant.csv")
aid_589.head(2)
# Out:
#    PUBCHEM_RESULT_TAG  PUBCHEM_SID  PUBCHEM_CID  \
# 0                   1  103164548.0    5284616.0
# 1                   2  103164549.0     445643.0
#
#                        PUBCHEM_EXT_DATASOURCE_SMILES PUBCHEM_ACTIVITY_OUTCOME  \
# 0  C[C@@H]1CC[C@H]2C[C@@H](/C(=C/C=C/C=C/[C@H](C[...              Unspecified
# 1  C[C@@H]1C[C@@H]([C@@H]2[C@H](C[C@H]([C@@](O2)(...              Unspecified
#
#    PUBCHEM_ACTIVITY_SCORE  PUBCHEM_ACTIVITY_URL PUBCHEM_ASSAYDATA_COMMENT  \
# 0                     NaN                   NaN    Potential missing data
# 1                     NaN                   NaN    Potential missing data
#
#   Standard Type Activity Comment  \
# 0      Activity        Substrate
# 1      Activity        Substrate
#
#                                     CANONICAL_SMILES  \
# 0  COC1C(=O)C(C)C[C@H](C)/C=C/C=C/C=C(\C)[C@@H](O...
# 1  C=CCC1=CC(C)C[C@H](C)C[C@H](OC)[C@H]2O[C@@](O)...
#
#                       INCHIKEY                         dataset data_type  \
# 0  DVSZTYJRXBBIFA-FBAQEZMUSA-N  aid_589039_clinically_relevant     assay
# 1  SLUYGGAVUSVJOT-VZCWQGFJSA-N  aid_589039_clinically_relevant     assay
#
#   action_type
# 0   substrate
# 1   substrate

# %%
carbon_mangels = pd.read_csv("./processed/carbon-mangels_2011.csv")
carbon_mangels.head(2)
# Out:
#   common_name                                             SMILES  Active  \
# 0    abacavir      Nc1nc(NC2CC2)c2ncn([C@H]3C=C[C@@H](CO)C3)c2n1       0
# 1   abecarnil  COCc1c(C(=O)OC(C)C)ncc2[nH]c3ccc(OCc4ccccc4)cc...       0
#
#                                     CANONICAL_SMILES  \
# 0      Nc1nc(NC2CC2)c2ncn([C@H]3C=C[C@@H](CO)C3)c2n1
# 1  COCc1c(C(=O)OC(C)C)ncc2[nH]c3ccc(OCc4ccccc4)cc...
#
#                       INCHIKEY              dataset data_type action_type
# 0  MCGSCOLBFJQGHM-SCZZXKLOSA-N  carbon-mangels_2011     assay   substrate
# 1  RLFKILXOLJVUNF-UHFFFAOYSA-N  carbon-mangels_2011     assay   substrate

# %%
chembl_clin = pd.read_csv("./processed/CHEMBL1142817.csv")
chembl_clin.head(2)
# Out:
#   Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight  \
# 0          CHEMBL839     CARTEOLOL                 4.0            292.38
# 1         CHEMBL1423      PIMOZIDE                 4.0            461.56
#
#    #RO5 Violations  AlogP Compound Key  \
# 0              0.0   1.70    Carteolol
# 1              1.0   5.86  SID56422165
#
#                                               Smiles Standard Type  \
# 0                 CC(C)(C)NCC(O)COc1cccc2c1CCC(=O)N2      Log 1/Km
# 1  O=c1[nH]c2ccccc2n1C1CCN(CCCC(c2ccc(F)cc2)c2ccc...      Log 1/Km
#
#   Standard Relation  ...  Document Year  Cell ChEMBL ID  Properties  \
# 0               '='  ...           2005             NaN         NaN
# 1               '='  ...           2005             NaN         NaN
#
#    Action Type  Standard Text Value  \
# 0          NaN                  NaN
# 1          NaN                  NaN
#
#                                     CANONICAL_SMILES  \
# 0                 CC(C)(C)NCC(O)COc1cccc2c1CCC(=O)N2
# 1  O=c1[nH]c2ccccc2n1C1CCN(CCCC(c2ccc(F)cc2)c2ccc...
#
#                       INCHIKEY        dataset  data_type  action_type
# 0  LWAFSWPYPHEXKX-UHFFFAOYSA-N  CHEMBL1142817      assay    substrate
# 1  YVUQSNJEYSNKRX-UHFFFAOYSA-N  CHEMBL1142817      assay    substrate
#
# [2 rows x 52 columns]

# %%
drugbank = pd.read_csv("./processed/drugbank_processed.csv")
drugbank.head(2)
# Out:
#   common_name                                             SMILES  \
# 0   Indinavir  CC(C)(C)NC(=O)[C@@H]1CN(CCN1C[C@H](C[C@@H](CC2...
# 1  Lovastatin  CC[C@H](C)C(=O)O[C@H]1C[C@H](C=C2[C@H]1[C@H]([...
#
#                                     CANONICAL_SMILES  \
# 0  CC(C)(C)NC(=O)C1CN(Cc2cccnc2)CCN1C[C@@H](O)CC(...
# 1  CCC(C)C(=O)O[C@H]1C[C@@H](C)C=C2C=C[C@H](C)[C@...
#
#                       INCHIKEY   dataset action_type  active
# 0  CBVCZFGXHXORBI-IXVTTXLYSA-N  drugbank   substrate    True
# 1  PCZOHLXUXFIOCF-SGFUJYLFSA-N  drugbank   substrate    True

# %%
flockheart = pd.read_csv("./processed/flockheart.csv")
flockheart.head(2)
# Out:
#           Drug                                             SMILES  \
# 0  abemaciclib  CCN1CCN(CC1)CC2=CN=C(C=C2)NC3=NC=C(C(=N3)C4=CC...
# 1  abiraterone  C[C@]12CC[C@@H](CC1=CC[C@@H]3[C@@H]2CC[C@]4([C...
#
#                                     CANONICAL_SMILES  \
# 0  CCN1CCN(Cc2ccc(Nc3ncc(F)c(-c4cc(F)c5nc(C)n(C(C...
# 1  C[C@]12CC[C@H](O)CC1=CC[C@@H]1[C@@H]2CC[C@]2(C...
#
#                       INCHIKEY     dataset action_type  active
# 0  UZWDCWONPYILKI-UHFFFAOYSA-N  flockheart   substrate    True
# 1  GZOSMCIZMLWJML-VJLLXTKPSA-N  flockheart   substrate    True

# %%
xin = pd.read_csv("./processed/xin_xu_ncats_adme.csv")
xin.head(2)
# Out:
#                        SMILES  CYP2C9 Substrate Class  CYP2D6 Substrate Class  \
# 0   CC(C)(C)C1=C(O)C=CC(O)=C1                     0.0                     0.0
# 1  OC(=O)C\C(=C/C(O)=O)C(O)=O                     NaN                     0.0
#
#    CYP3A4 Substrate Class  CYP2C9 Activity Class  CYP2D6 Activity Class  \
# 0                     0.0                    0.0                    0.0
# 1                     NaN                    0.0                    0.0
#
#    CYP3A4 Activity Class CYP2C9 Inhibitor Class CYP2D6 Inhibitor Class  \
# 0                    1.0                      0                      0
# 1                    0.0                    NaN                      0
#
#   CYP3A4_ Inhibitor Class          CANONICAL_SMILES  \
# 0                       1      CC(C)(C)c1cc(O)ccc1O
# 1                     NaN  O=C(O)C=C(CC(=O)O)C(=O)O
#
#                       INCHIKEY               dataset data_type action_type
# 0  BGNXCDMCOKJUMV-UHFFFAOYSA-N  XinXu_NCATS_ADME_raw     assay   substrate
# 1  GTZCVFVGUGFEME-UHFFFAOYSA-N  XinXu_NCATS_ADME_raw     assay   substrate

# %%
combined_literature = pd.concat([aid_589, carbon_mangels, chembl_clin, drugbank, flockheart, xin])
combined_literature
# Out:
#       PUBCHEM_RESULT_TAG  PUBCHEM_SID  PUBCHEM_CID  \
# 0                    1.0  103164548.0    5284616.0
# 1                    2.0  103164549.0     445643.0
# 2                    3.0  103166970.0       2477.0
# 3                    4.0  103169851.0     123619.0
# 4                    5.0  103172458.0      53232.0
# ...                  ...          ...          ...
# 4297                 NaN          NaN          NaN
# 4298                 NaN          NaN          NaN
# 4299                 NaN          NaN          NaN
# 4300                 NaN          NaN          NaN
# 4301                 NaN          NaN          NaN
#
#                           PUBCHEM_EXT_DATASOURCE_SMILES  \
# 0     C[C@@H]1CC[C@H]2C[C@@H](/C(=C/C=C/C=C/[C@H](C[...
# 1     C[C@@H]1C[C@@H]([C@@H]2[C@H](C[C@H]([C@@](O2)(...
# 2     C1CCC2(C1)CC(=O)N(C(=O)C2)CCCCN3CCN(CC3)C4=NC=...
# 3     CC1=NC=C(C=C1)C2=C(C=C(C=N2)Cl)C3=CC=C(C=C3)S(...
# 4     CC[C@H](C)C(=O)O[C@H]1C[C@H](C=C2[C@H]1[C@H]([...
# ...                                                 ...
# 4297                                                NaN
# 4298                                                NaN
# 4299                                                NaN
# 4300                                                NaN
# 4301                                                NaN
#
#      PUBCHEM_ACTIVITY_OUTCOME  PUBCHEM_ACTIVITY_SCORE  PUBCHEM_ACTIVITY_URL  \
# 0                 Unspecified                     NaN                   NaN
# 1                 Unspecified                     NaN                   NaN
# 2                 Unspecified                     NaN                   NaN
# 3                 Unspecified                     NaN                   NaN
# 4                 Unspecified                     NaN                   NaN
# ...                       ...                     ...                   ...
# 4297                      NaN                     NaN                   NaN
# 4298                      NaN                     NaN                   NaN
# 4299                      NaN                     NaN                   NaN
# 4300                      NaN                     NaN                   NaN
# 4301                      NaN                     NaN                   NaN
#
#      PUBCHEM_ASSAYDATA_COMMENT Standard Type Activity Comment  ... Drug  \
# 0       Potential missing data      Activity        Substrate  ...  NaN
# 1       Potential missing data      Activity        Substrate  ...  NaN
# 2       Potential missing data      Activity        Substrate  ...  NaN
# 3       Potential missing data      Activity        Substrate  ...  NaN
# 4       Potential missing data      Activity        Substrate  ...  NaN
# ...                        ...           ...              ...  ...  ...
# 4297                       NaN           NaN              NaN  ...  NaN
# 4298                       NaN           NaN              NaN  ...  NaN
# 4299                       NaN           NaN              NaN  ...  NaN
# 4300                       NaN           NaN              NaN  ...  NaN
# 4301                       NaN           NaN              NaN  ...  NaN
#
#      CYP2C9 Substrate Class CYP2D6 Substrate Class CYP3A4 Substrate Class  \
# 0                       NaN                    NaN                    NaN
# 1                       NaN                    NaN                    NaN
# 2                       NaN                    NaN                    NaN
# 3                       NaN                    NaN                    NaN
# 4                       NaN                    NaN                    NaN
# ...                     ...                    ...                    ...
# 4297                    0.0                    1.0                    1.0
# 4298                    1.0                    NaN                    1.0
# 4299                    0.0                    0.0                    1.0
# 4300                    NaN                    0.0                    NaN
# 4301                    NaN                    1.0                    NaN
#
#      CYP2C9 Activity Class CYP2D6 Activity Class CYP3A4 Activity Class  \
# 0                      NaN                   NaN                   NaN
# 1                      NaN                   NaN                   NaN
# 2                      NaN                   NaN                   NaN
# 3                      NaN                   NaN                   NaN
# 4                      NaN                   NaN                   NaN
# ...                    ...                   ...                   ...
# 4297                   0.0                   1.0                   1.0
# 4298                   1.0                   0.0                   1.0
# 4299                   0.0                   0.0                   1.0
# 4300                   0.0                   0.0                   0.0
# 4301                   0.0                   0.0                   0.0
#
#       CYP2C9 Inhibitor Class CYP2D6 Inhibitor Class CYP3A4_ Inhibitor Class
# 0                        NaN                    NaN                     NaN
# 1                        NaN                    NaN                     NaN
# 2                        NaN                    NaN                     NaN
# 3                        NaN                    NaN                     NaN
# 4                        NaN                    NaN                     NaN
# ...                      ...                    ...                     ...
# 4297                       0             subs/inhib              subs/inhib
# 4298              subs/inhib                    NaN              subs/inhib
# 4299                       0                      0              subs/inhib
# 4300                     NaN                      0                     NaN
# 4301                     NaN                      0                     NaN
#
# [6186 rows x 75 columns]

# %%
combined_literature.INCHIKEY.isna().sum()
# Out:
# 22

# %%
combined_literature.dropna(subset="INCHIKEY", inplace=True)

# %%
# clean up a bit

# %%
cols = combined_literature.columns

# %%
keepcols = ["CANONICAL_SMILES", "INCHIKEY", "dataset", "action_type", "active", "common_name"]

# %%
combined_literature_clean = combined_literature[keepcols]

# %%
combined_literature_clean["active"] = True
# Out:
# /tmp/ipykernel_275873/1528387074.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_literature_clean["active"] = True

# %%
combined_literature_clean
# Out:
#                                        CANONICAL_SMILES  \
# 0     COC1C(=O)C(C)C[C@H](C)/C=C/C=C/C=C(\C)[C@@H](O...
# 1     C=CCC1=CC(C)C[C@H](C)C[C@H](OC)[C@H]2O[C@@](O)...
# 2          O=C1CC2(CCCC2)CC(=O)N1CCCCN1CCN(c2ncccn2)CC1
# 3         Cc1ccc(-c2ncc(Cl)cc2-c2ccc(S(C)(=O)=O)cc2)cn1
# 4     CCC(C)C(=O)O[C@H]1C[C@@H](C)C=C2C=C[C@H](C)[C@...
# ...                                                 ...
# 4297      CCOC(=O)CSc1nc2c(sc3ccccc32)c(=O)n1CCCN1CCCC1
# 4298       CCc1ccc(-c2nc(CSCC(=O)NCCc3ccccc3)c(C)o2)cc1
# 4299  CC(C)[C@@H](c1ccc(C(F)(F)F)cc1CN(Cc1cc(C(F)(F)...
# 4300    COCCOc1nc(N)c2[nH]c(=O)n(Cc3ccc(C(=O)O)cc3)c2n1
# 4301  O=C(COCC(=O)N1CCN(C(c2ccccc2)c2ccccc2)CC1)Nc1c...
#
#                          INCHIKEY                         dataset action_type  \
# 0     DVSZTYJRXBBIFA-FBAQEZMUSA-N  aid_589039_clinically_relevant   substrate
# 1     SLUYGGAVUSVJOT-VZCWQGFJSA-N  aid_589039_clinically_relevant   substrate
# 2     QWCRAEMEVRGPNT-UHFFFAOYSA-N  aid_589039_clinically_relevant   substrate
# 3     MNJVRJDLRVPLFE-UHFFFAOYSA-N  aid_589039_clinically_relevant   substrate
# 4     PCZOHLXUXFIOCF-SGFUJYLFSA-N  aid_589039_clinically_relevant   substrate
# ...                           ...                             ...         ...
# 4297  SKDRHRAYBYQVNU-UHFFFAOYSA-N            XinXu_NCATS_ADME_raw   substrate
# 4298  QTDYVSIBWGVBKU-UHFFFAOYSA-N            XinXu_NCATS_ADME_raw   substrate
# 4299  DZNFADLAFQEDJQ-DEOSSOPVSA-N            XinXu_NCATS_ADME_raw   substrate
# 4300  ATISKRYGYNSRNP-UHFFFAOYSA-N            XinXu_NCATS_ADME_raw   substrate
# 4301  NYFQDUPIZKZQAX-UHFFFAOYSA-N            XinXu_NCATS_ADME_raw   substrate
#
#       active common_name
# 0       True         NaN
# 1       True         NaN
# 2       True         NaN
# 3       True         NaN
# 4       True         NaN
# ...      ...         ...
# 4297    True         NaN
# 4298    True         NaN
# 4299    True         NaN
# 4300    True         NaN
# 4301    True         NaN
#
# [6164 rows x 6 columns]

# %%
combined_literature_clean.INCHIKEY.duplicated().sum()
# Out:
# 1074

# %%
combined_literature_clean
# Out:
#                                        CANONICAL_SMILES  \
# 0     COC1C(=O)C(C)C[C@H](C)/C=C/C=C/C=C(\C)[C@@H](O...
# 1     C=CCC1=CC(C)C[C@H](C)C[C@H](OC)[C@H]2O[C@@](O)...
# 2          O=C1CC2(CCCC2)CC(=O)N1CCCCN1CCN(c2ncccn2)CC1
# 3         Cc1ccc(-c2ncc(Cl)cc2-c2ccc(S(C)(=O)=O)cc2)cn1
# 4     CCC(C)C(=O)O[C@H]1C[C@@H](C)C=C2C=C[C@H](C)[C@...
# ...                                                 ...
# 4297      CCOC(=O)CSc1nc2c(sc3ccccc32)c(=O)n1CCCN1CCCC1
# 4298       CCc1ccc(-c2nc(CSCC(=O)NCCc3ccccc3)c(C)o2)cc1
# 4299  CC(C)[C@@H](c1ccc(C(F)(F)F)cc1CN(Cc1cc(C(F)(F)...
# 4300    COCCOc1nc(N)c2[nH]c(=O)n(Cc3ccc(C(=O)O)cc3)c2n1
# 4301  O=C(COCC(=O)N1CCN(C(c2ccccc2)c2ccccc2)CC1)Nc1c...
#
#                          INCHIKEY                         dataset action_type  \
# 0     DVSZTYJRXBBIFA-FBAQEZMUSA-N  aid_589039_clinically_relevant   substrate
# 1     SLUYGGAVUSVJOT-VZCWQGFJSA-N  aid_589039_clinically_relevant   substrate
# 2     QWCRAEMEVRGPNT-UHFFFAOYSA-N  aid_589039_clinically_relevant   substrate
# 3     MNJVRJDLRVPLFE-UHFFFAOYSA-N  aid_589039_clinically_relevant   substrate
# 4     PCZOHLXUXFIOCF-SGFUJYLFSA-N  aid_589039_clinically_relevant   substrate
# ...                           ...                             ...         ...
# 4297  SKDRHRAYBYQVNU-UHFFFAOYSA-N            XinXu_NCATS_ADME_raw   substrate
# 4298  QTDYVSIBWGVBKU-UHFFFAOYSA-N            XinXu_NCATS_ADME_raw   substrate
# 4299  DZNFADLAFQEDJQ-DEOSSOPVSA-N            XinXu_NCATS_ADME_raw   substrate
# 4300  ATISKRYGYNSRNP-UHFFFAOYSA-N            XinXu_NCATS_ADME_raw   substrate
# 4301  NYFQDUPIZKZQAX-UHFFFAOYSA-N            XinXu_NCATS_ADME_raw   substrate
#
#       active common_name
# 0       True         NaN
# 1       True         NaN
# 2       True         NaN
# 3       True         NaN
# 4       True         NaN
# ...      ...         ...
# 4297    True         NaN
# 4298    True         NaN
# 4299    True         NaN
# 4300    True         NaN
# 4301    True         NaN
#
# [6164 rows x 6 columns]

# %%
appears = combined_literature_clean.groupby("INCHIKEY")["dataset"].nunique().reset_index(name="appears_in_N_datasets")
appears.set_index("INCHIKEY")
# Out:
#                              appears_in_N_datasets
# INCHIKEY
# AAAQFGUYHFJNHI-GOSISDBHSA-N                      1
# AAAQFGUYHFJNHI-SFHVURJKSA-N                      1
# AABFWJDLCCDJJN-UHFFFAOYSA-N                      1
# AADCDMQTJNYOSS-LBPRGKRZSA-N                      1
# AADVZSXPNRLYLV-IQCVEUMDSA-N                      1
# ...                                            ...
# ZZUKALQMHNSWTK-UHFFFAOYSA-N                      1
# ZZVGLDBDDYESAB-UHFFFAOYSA-N                      1
# ZZVUWRFHKOJYTH-UHFFFAOYSA-N                      2
# ZZZQXCUPAJFVBN-UHFFFAOYSA-N                      1
# ZZZRUAITSXLWBH-YLLKXDJQSA-N                      1
#
# [5090 rows x 1 columns]

# %%
appears.isna().sum()
# Out:
# INCHIKEY                 0
# appears_in_N_datasets    0
# dtype: int64

# %%
sns.countplot(data=appears, x="appears_in_N_datasets")
# Out:
# <Axes: xlabel='appears_in_N_datasets', ylabel='count'>

# %%
combined_literature_clean_w_counts = combined_literature_clean.merge(appears, on="INCHIKEY")

# %%
combined_literature_clean_w_counts.sort_values("appears_in_N_datasets", ascending=False)
# Out:
#                                        CANONICAL_SMILES  \
# 790   O=c1[nH]c2ccccc2n1C1CCN(CCCC(c2ccc(F)cc2)c2ccc...
# 791   CC(C)(C)NC(=O)C1C[C@@H]2CCCC[C@@H]2CN1C[C@@H](...
# 794                        NC(=O)N1c2ccccc2C=Cc2ccccc21
# 2060  O=c1[nH]c2ccccc2n1C1CCN(CCCC(c2ccc(F)cc2)c2ccc...
# 591   O=c1[nH]c2ccccc2n1C1CCN(CCCC(c2ccc(F)cc2)c2ccc...
# ...                                                 ...
# 3119                 CCN(CC)CCSC(=O)C(c1ccccc1)c1ccccc1
# 3118                            COc1ccc(/C=C/C(=O)O)cc1
# 442   CCOC(=O)C1=C(C)N=C(C)C(C(=O)OCC)C1c1ccccc1/C=C...
# 3116                    CCCCNC(=O)NS(=O)(=O)c1ccc(N)cc1
# 438                        CN[C@@]1(c2ccccc2Cl)CCCCC1=O
#
#                          INCHIKEY               dataset action_type  active  \
# 790   YVUQSNJEYSNKRX-UHFFFAOYSA-N         CHEMBL1142817   substrate    True
# 791   QWAXKHKRTORLEM-PVCXOJBVSA-N         CHEMBL1142817   substrate    True
# 794   FFGPTBGBLSHEPO-UHFFFAOYSA-N         CHEMBL1142817   substrate    True
# 2060  YVUQSNJEYSNKRX-UHFFFAOYSA-N  XinXu_NCATS_ADME_raw   substrate    True
# 591   YVUQSNJEYSNKRX-UHFFFAOYSA-N   carbon-mangels_2011   substrate    True
# ...                           ...                   ...         ...     ...
# 3119  WHLUQAYNVOGZST-UHFFFAOYSA-N  XinXu_NCATS_ADME_raw   substrate    True
# 3118  AFDXODALSZRGIH-QPJJXVBHSA-N  XinXu_NCATS_ADME_raw   substrate    True
# 442   BGYJFSXPRMOZJK-PFONDFGASA-N   carbon-mangels_2011   substrate    True
# 3116  VDTNNGKXZGSZIP-UHFFFAOYSA-N  XinXu_NCATS_ADME_raw   substrate    True
# 438   YQEZLKZALYSWHR-CYBMUJFWSA-N   carbon-mangels_2011   substrate    True
#
#      common_name  appears_in_N_datasets
# 790          NaN                      6
# 791          NaN                      6
# 794          NaN                      6
# 2060         NaN                      6
# 591     pimozide                      6
# ...          ...                    ...
# 3119         NaN                      1
# 3118         NaN                      1
# 442   lacidipine                      1
# 3116         NaN                      1
# 438     ketamine                      1
#
# [6164 rows x 7 columns]

# %%
df_dummies = pd.get_dummies(combined_literature_clean_w_counts['dataset'], prefix='dataset').join(combined_literature_clean_w_counts["INCHIKEY"])
df_dummies
# Out:
#       dataset_CHEMBL1142817  dataset_XinXu_NCATS_ADME_raw  \
# 0                     False                         False
# 1                     False                         False
# 2                     False                         False
# 3                     False                         False
# 4                     False                         False
# ...                     ...                           ...
# 6159                  False                          True
# 6160                  False                          True
# 6161                  False                          True
# 6162                  False                          True
# 6163                  False                          True
#
#       dataset_aid_589039_clinically_relevant  dataset_carbon-mangels_2011  \
# 0                                       True                        False
# 1                                       True                        False
# 2                                       True                        False
# 3                                       True                        False
# 4                                       True                        False
# ...                                      ...                          ...
# 6159                                   False                        False
# 6160                                   False                        False
# 6161                                   False                        False
# 6162                                   False                        False
# 6163                                   False                        False
#
#       dataset_drugbank  dataset_flockheart                     INCHIKEY
# 0                False               False  DVSZTYJRXBBIFA-FBAQEZMUSA-N
# 1                False               False  SLUYGGAVUSVJOT-VZCWQGFJSA-N
# 2                False               False  QWCRAEMEVRGPNT-UHFFFAOYSA-N
# 3                False               False  MNJVRJDLRVPLFE-UHFFFAOYSA-N
# 4                False               False  PCZOHLXUXFIOCF-SGFUJYLFSA-N
# ...                ...                 ...                          ...
# 6159             False               False  SKDRHRAYBYQVNU-UHFFFAOYSA-N
# 6160             False               False  QTDYVSIBWGVBKU-UHFFFAOYSA-N
# 6161             False               False  DZNFADLAFQEDJQ-DEOSSOPVSA-N
# 6162             False               False  ATISKRYGYNSRNP-UHFFFAOYSA-N
# 6163             False               False  NYFQDUPIZKZQAX-UHFFFAOYSA-N
#
# [6164 rows x 7 columns]

# %%
df_result = df_dummies.groupby('INCHIKEY').max().reset_index()
df_result = df_result.set_index("INCHIKEY")

# %%
combined_literature_clean_w_counts = combined_literature_clean_w_counts.merge(df_result, on="INCHIKEY")

# %%
combined_literature_clean_w_counts.sort_values("appears_in_N_datasets", ascending=False, inplace=True)
combined_literature_clean_w_counts
# Out:
#                                        CANONICAL_SMILES  \
# 790   O=c1[nH]c2ccccc2n1C1CCN(CCCC(c2ccc(F)cc2)c2ccc...
# 791   CC(C)(C)NC(=O)C1C[C@@H]2CCCC[C@@H]2CN1C[C@@H](...
# 794                        NC(=O)N1c2ccccc2C=Cc2ccccc21
# 2060  O=c1[nH]c2ccccc2n1C1CCN(CCCC(c2ccc(F)cc2)c2ccc...
# 591   O=c1[nH]c2ccccc2n1C1CCN(CCCC(c2ccc(F)cc2)c2ccc...
# ...                                                 ...
# 3119                 CCN(CC)CCSC(=O)C(c1ccccc1)c1ccccc1
# 3118                            COc1ccc(/C=C/C(=O)O)cc1
# 442   CCOC(=O)C1=C(C)N=C(C)C(C(=O)OCC)C1c1ccccc1/C=C...
# 3116                    CCCCNC(=O)NS(=O)(=O)c1ccc(N)cc1
# 438                        CN[C@@]1(c2ccccc2Cl)CCCCC1=O
#
#                          INCHIKEY               dataset action_type  active  \
# 790   YVUQSNJEYSNKRX-UHFFFAOYSA-N         CHEMBL1142817   substrate    True
# 791   QWAXKHKRTORLEM-PVCXOJBVSA-N         CHEMBL1142817   substrate    True
# 794   FFGPTBGBLSHEPO-UHFFFAOYSA-N         CHEMBL1142817   substrate    True
# 2060  YVUQSNJEYSNKRX-UHFFFAOYSA-N  XinXu_NCATS_ADME_raw   substrate    True
# 591   YVUQSNJEYSNKRX-UHFFFAOYSA-N   carbon-mangels_2011   substrate    True
# ...                           ...                   ...         ...     ...
# 3119  WHLUQAYNVOGZST-UHFFFAOYSA-N  XinXu_NCATS_ADME_raw   substrate    True
# 3118  AFDXODALSZRGIH-QPJJXVBHSA-N  XinXu_NCATS_ADME_raw   substrate    True
# 442   BGYJFSXPRMOZJK-PFONDFGASA-N   carbon-mangels_2011   substrate    True
# 3116  VDTNNGKXZGSZIP-UHFFFAOYSA-N  XinXu_NCATS_ADME_raw   substrate    True
# 438   YQEZLKZALYSWHR-CYBMUJFWSA-N   carbon-mangels_2011   substrate    True
#
#      common_name  appears_in_N_datasets  dataset_CHEMBL1142817  \
# 790          NaN                      6                   True
# 791          NaN                      6                   True
# 794          NaN                      6                   True
# 2060         NaN                      6                   True
# 591     pimozide                      6                   True
# ...          ...                    ...                    ...
# 3119         NaN                      1                  False
# 3118         NaN                      1                  False
# 442   lacidipine                      1                  False
# 3116         NaN                      1                  False
# 438     ketamine                      1                  False
#
#       dataset_XinXu_NCATS_ADME_raw  dataset_aid_589039_clinically_relevant  \
# 790                           True                                    True
# 791                           True                                    True
# 794                           True                                    True
# 2060                          True                                    True
# 591                           True                                    True
# ...                            ...                                     ...
# 3119                          True                                   False
# 3118                          True                                   False
# 442                          False                                   False
# 3116                          True                                   False
# 438                          False                                   False
#
#       dataset_carbon-mangels_2011  dataset_drugbank  dataset_flockheart
# 790                          True              True                True
# 791                          True              True                True
# 794                          True              True                True
# 2060                         True              True                True
# 591                          True              True                True
# ...                           ...               ...                 ...
# 3119                        False             False               False
# 3118                        False             False               False
# 442                          True             False               False
# 3116                        False             False               False
# 438                          True             False               False
#
# [6164 rows x 13 columns]

# %%
# could crossref with ChEMBL assays


unique_inchikeys = combined_literature_clean_w_counts.INCHIKEY.unique()
unique_inchikeys
# Out:
# array(['YVUQSNJEYSNKRX-UHFFFAOYSA-N', 'QWAXKHKRTORLEM-PVCXOJBVSA-N',
#        'FFGPTBGBLSHEPO-UHFFFAOYSA-N', ..., 'BGYJFSXPRMOZJK-PFONDFGASA-N',
#        'VDTNNGKXZGSZIP-UHFFFAOYSA-N', 'YQEZLKZALYSWHR-CYBMUJFWSA-N'],
#       dtype=object)

# %%
# read chembl to append assay numbers from chembl

# %%
chembl_assay_counts = pd.read_csv("./ChEMBL/chembl_processed.csv")
chembl_xref = chembl_assay_counts[["INCHIKEY", "assay_count", "pChEMBL mean"]]
chembl_xref.set_index("INCHIKEY", inplace=True)
chembl_xref
# Out:
#                              assay_count  pChEMBL mean
# INCHIKEY
# XMAYWYJOQHXEEK-UHFFFAOYSA-N           21      7.013500
# QCHFTSOMWOSFHM-HNHGDDPOSA-N           17      5.052941
# RTHCYVBBDHJXIQ-INIZCTEOSA-N           15      4.980000
# VNFPBHJOKIVQEB-UHFFFAOYSA-N           14      7.237692
# NKANXQFJJICGDU-QPLCGJKRSA-N           14      4.846154
# ...                                  ...           ...
# ALVMYTXDIDVNBL-UHFFFAOYSA-N            3      4.600000
# UYIDFVMWICIANY-UHFFFAOYSA-N            3      4.700000
# CXLBXWWEDULTDH-UHFFFAOYSA-N            3      5.500000
# BTMMETYTWLLSPR-UHFFFAOYSA-N            3      4.500000
# LSVGMBFOSQBBSG-UHFFFAOYSA-N            3      5.200000
#
# [4303 rows x 2 columns]

# %%
chembl_assay_counts
# Out:
#      Molecule ChEMBL ID      Molecule Name  Molecule Max Phase  \
# 0          CHEMBL157101       KETOCONAZOLE                 4.0
# 1         CHEMBL1474730                NaN                 NaN
# 2         CHEMBL1169388                NaN                 NaN
# 3             CHEMBL104       CLOTRIMAZOLE                 4.0
# 4             CHEMBL786  TAMOXIFEN CITRATE                 4.0
# ...                 ...                ...                 ...
# 4298      CHEMBL1477492                NaN                 NaN
# 4299      CHEMBL1496243                NaN                 NaN
# 4300      CHEMBL1597037                NaN                 NaN
# 4301      CHEMBL1370480                NaN                 NaN
# 4302      CHEMBL1611646                NaN                 NaN
#
#       Molecular Weight  #RO5 Violations  AlogP  Compound Key  \
# 0               531.44              1.0   4.21  ketoconazole
# 1               271.27              0.0   1.16   SID26748206
# 2               309.33              0.0   4.44   SID11112803
# 3               344.85              1.0   5.38  Clotrimazole
# 4               563.65              1.0   6.00   SID17389724
# ...                ...              ...    ...           ...
# 4298            351.45              0.0   3.96    SID4238869
# 4299            356.82              0.0   1.45    SID4240267
# 4300            275.36              0.0   4.18    SID4237758
# 4301            309.37              0.0   1.94    SID4239072
# 4302            326.39              0.0   2.26    SID4239101
#
#                                                  Smiles Standard Type  \
# 0     CC(=O)N1CCN(c2ccc(OCC3COC(Cn4ccnc4)(c4ccc(Cl)c...          IC50
# 1              CCC1C(=O)OC[C@H]1Cc1cncn1C.O=[N+]([O-])O       Potency
# 2                CNCC[C@H](Oc1ccc(C(F)(F)F)cc1)c1ccccc1       Potency
# 3                Clc1ccccc1C(c1ccccc1)(c1ccccc1)n1ccnc1          IC50
# 4     CC/C(=C(\c1ccccc1)c1ccc(OCCN(C)C)cc1)c1ccccc1....          AC50
# ...                                                 ...           ...
# 4298          O=C(Oc1ccccc1)N1CCC2(CCCN(c3ccccn3)C2)CC1          AC50
# 4299       Cn1c(=O)c(-c2ccc(Cl)cc2)nc2cnc(N3CCNCC3)nc21          AC50
# 4300                   Cc1ccccc1-c1ccc2ncnc(NC3CC3)c2c1       Potency
# 4301               CCNc1ncc2nc(CCc3ccccc3)c(=O)n(C)c2n1          AC50
# 4302             CCNc1ncc2nc(-c3cccs3)c(=O)n(CCC#N)c2n1       Potency
#
#      Standard Relation  ...  Cell ChEMBL ID Properties  Action Type  \
# 0                  '='  ...             NaN        NaN          NaN
# 1                  '='  ...             NaN        NaN          NaN
# 2                  '='  ...             NaN        NaN          NaN
# 3                  '='  ...             NaN        NaN          NaN
# 4                  '='  ...             NaN        NaN          NaN
# ...                ...  ...             ...        ...          ...
# 4298               '='  ...             NaN        NaN          NaN
# 4299               '='  ...             NaN        NaN          NaN
# 4300               '='  ...             NaN        NaN          NaN
# 4301               '='  ...             NaN        NaN          NaN
# 4302               '='  ...             NaN        NaN          NaN
#
#      Standard Text Value                                   CANONICAL_SMILES  \
# 0                    NaN  CC(=O)N1CCN(c2ccc(OCC3COC(Cn4ccnc4)(c4ccc(Cl)c...
# 1                    NaN                         CCC1C(=O)OC[C@H]1Cc1cncn1C
# 2                    NaN             CNCC[C@H](Oc1ccc(C(F)(F)F)cc1)c1ccccc1
# 3                    NaN             Clc1ccccc1C(c1ccccc1)(c1ccccc1)n1ccnc1
# 4                    NaN      CC/C(=C(\c1ccccc1)c1ccc(OCCN(C)C)cc1)c1ccccc1
# ...                  ...                                                ...
# 4298                 NaN          O=C(Oc1ccccc1)N1CCC2(CCCN(c3ccccn3)C2)CC1
# 4299                 NaN       Cn1c(=O)c(-c2ccc(Cl)cc2)nc2cnc(N3CCNCC3)nc21
# 4300                 NaN                   Cc1ccccc1-c1ccc2ncnc(NC3CC3)c2c1
# 4301                 NaN               CCNc1ncc2nc(CCc3ccccc3)c(=O)n(C)c2n1
# 4302                 NaN             CCNc1ncc2nc(-c3cccs3)c(=O)n(CCC#N)c2n1
#
#                          INCHIKEY  molecule_count  assay_count  pChEMBL mean  \
# 0     XMAYWYJOQHXEEK-UHFFFAOYSA-N              28           21      7.013500
# 1     QCHFTSOMWOSFHM-HNHGDDPOSA-N            6472           17      5.052941
# 2     RTHCYVBBDHJXIQ-INIZCTEOSA-N            6472           15      4.980000
# 3     VNFPBHJOKIVQEB-UHFFFAOYSA-N              28           14      7.237692
# 4     NKANXQFJJICGDU-QPLCGJKRSA-N            8635           14      4.846154
# ...                           ...             ...          ...           ...
# 4298  ALVMYTXDIDVNBL-UHFFFAOYSA-N            8635            3      4.600000
# 4299  UYIDFVMWICIANY-UHFFFAOYSA-N            8635            3      4.700000
# 4300  CXLBXWWEDULTDH-UHFFFAOYSA-N            6472            3      5.500000
# 4301  BTMMETYTWLLSPR-UHFFFAOYSA-N            8635            3      4.500000
# 4302  LSVGMBFOSQBBSG-UHFFFAOYSA-N            6472            3      5.200000
#
#       pChEMBL std
# 0        0.618796
# 1        0.285302
# 2        0.248424
# 3        0.358798
# 4        0.357341
# ...           ...
# 4298     0.000000
# 4299     0.000000
# 4300     0.000000
# 4301     0.000000
# 4302     0.000000
#
# [4303 rows x 53 columns]

# %%
# now join
combined_literature_clean_w_counts = combined_literature_clean_w_counts.join(chembl_xref, on="INCHIKEY")

# %%
combined_literature_clean_w_counts['common_name'] = combined_literature_clean_w_counts.groupby('INCHIKEY')['common_name'].transform(lambda x: x.fillna(method='ffill').fillna(method='bfill'))
# Out:
# /tmp/ipykernel_275873/2133095029.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_literature_clean_w_counts['common_name'] = combined_literature_clean_w_counts.groupby('INCHIKEY')['common_name'].transform(lambda x: x.fillna(method='ffill').fillna(method='bfill'))
# /tmp/ipykernel_275873/2133095029.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   combined_literature_clean_w_counts['common_name'] = combined_literature_clean_w_counts.groupby('INCHIKEY')['common_name'].transform(lambda x: x.fillna(method='ffill').fillna(method='bfill'))

# %%
combined_literature_clean_w_counts["assay_count"] = combined_literature_clean_w_counts["assay_count"]

# %%
combined_literature_clean_w_counts.assay_count.value_counts()
# Out:
# assay_count
# 3.0     207
# 5.0      80
# 4.0      74
# 6.0      53
# 8.0      25
# 7.0      12
# 9.0      10
# 10.0      9
# 11.0      6
# 14.0      6
# 13.0      2
# 12.0      1
# Name: count, dtype: int64

# %%
combined_literature_clean_w_counts
# Out:
#                                        CANONICAL_SMILES  \
# 790   O=c1[nH]c2ccccc2n1C1CCN(CCCC(c2ccc(F)cc2)c2ccc...
# 791   CC(C)(C)NC(=O)C1C[C@@H]2CCCC[C@@H]2CN1C[C@@H](...
# 794                        NC(=O)N1c2ccccc2C=Cc2ccccc21
# 2060  O=c1[nH]c2ccccc2n1C1CCN(CCCC(c2ccc(F)cc2)c2ccc...
# 591   O=c1[nH]c2ccccc2n1C1CCN(CCCC(c2ccc(F)cc2)c2ccc...
# ...                                                 ...
# 3119                 CCN(CC)CCSC(=O)C(c1ccccc1)c1ccccc1
# 3118                            COc1ccc(/C=C/C(=O)O)cc1
# 442   CCOC(=O)C1=C(C)N=C(C)C(C(=O)OCC)C1c1ccccc1/C=C...
# 3116                    CCCCNC(=O)NS(=O)(=O)c1ccc(N)cc1
# 438                        CN[C@@]1(c2ccccc2Cl)CCCCC1=O
#
#                          INCHIKEY               dataset action_type  active  \
# 790   YVUQSNJEYSNKRX-UHFFFAOYSA-N         CHEMBL1142817   substrate    True
# 791   QWAXKHKRTORLEM-PVCXOJBVSA-N         CHEMBL1142817   substrate    True
# 794   FFGPTBGBLSHEPO-UHFFFAOYSA-N         CHEMBL1142817   substrate    True
# 2060  YVUQSNJEYSNKRX-UHFFFAOYSA-N  XinXu_NCATS_ADME_raw   substrate    True
# 591   YVUQSNJEYSNKRX-UHFFFAOYSA-N   carbon-mangels_2011   substrate    True
# ...                           ...                   ...         ...     ...
# 3119  WHLUQAYNVOGZST-UHFFFAOYSA-N  XinXu_NCATS_ADME_raw   substrate    True
# 3118  AFDXODALSZRGIH-QPJJXVBHSA-N  XinXu_NCATS_ADME_raw   substrate    True
# 442   BGYJFSXPRMOZJK-PFONDFGASA-N   carbon-mangels_2011   substrate    True
# 3116  VDTNNGKXZGSZIP-UHFFFAOYSA-N  XinXu_NCATS_ADME_raw   substrate    True
# 438   YQEZLKZALYSWHR-CYBMUJFWSA-N   carbon-mangels_2011   substrate    True
#
#         common_name  appears_in_N_datasets  dataset_CHEMBL1142817  \
# 790        pimozide                      6                   True
# 791      saquinavir                      6                   True
# 794   carbamazepine                      6                   True
# 2060       pimozide                      6                   True
# 591        pimozide                      6                   True
# ...             ...                    ...                    ...
# 3119            NaN                      1                  False
# 3118            NaN                      1                  False
# 442      lacidipine                      1                  False
# 3116            NaN                      1                  False
# 438        ketamine                      1                  False
#
#       dataset_XinXu_NCATS_ADME_raw  dataset_aid_589039_clinically_relevant  \
# 790                           True                                    True
# 791                           True                                    True
# 794                           True                                    True
# 2060                          True                                    True
# 591                           True                                    True
# ...                            ...                                     ...
# 3119                          True                                   False
# 3118                          True                                   False
# 442                          False                                   False
# 3116                          True                                   False
# 438                          False                                   False
#
#       dataset_carbon-mangels_2011  dataset_drugbank  dataset_flockheart  \
# 790                          True              True                True
# 791                          True              True                True
# 794                          True              True                True
# 2060                         True              True                True
# 591                          True              True                True
# ...                           ...               ...                 ...
# 3119                        False             False               False
# 3118                        False             False               False
# 442                          True             False               False
# 3116                        False             False               False
# 438                          True             False               False
#
#       assay_count  pChEMBL mean
# 790           6.0         5.322
# 791           3.0         5.540
# 794           NaN           NaN
# 2060          6.0         5.322
# 591           6.0         5.322
# ...           ...           ...
# 3119          NaN           NaN
# 3118          NaN           NaN
# 442           NaN           NaN
# 3116          NaN           NaN
# 438           NaN           NaN
#
# [6164 rows x 15 columns]

# %%
combined_literature_clean_w_counts["inclusion_score"] = combined_literature_clean_w_counts["appears_in_N_datasets"] + combined_literature_clean_w_counts["assay_count"]

# %%
combined_literature_clean_w_counts
# Out:
#                                        CANONICAL_SMILES  \
# 790   O=c1[nH]c2ccccc2n1C1CCN(CCCC(c2ccc(F)cc2)c2ccc...
# 791   CC(C)(C)NC(=O)C1C[C@@H]2CCCC[C@@H]2CN1C[C@@H](...
# 794                        NC(=O)N1c2ccccc2C=Cc2ccccc21
# 2060  O=c1[nH]c2ccccc2n1C1CCN(CCCC(c2ccc(F)cc2)c2ccc...
# 591   O=c1[nH]c2ccccc2n1C1CCN(CCCC(c2ccc(F)cc2)c2ccc...
# ...                                                 ...
# 3119                 CCN(CC)CCSC(=O)C(c1ccccc1)c1ccccc1
# 3118                            COc1ccc(/C=C/C(=O)O)cc1
# 442   CCOC(=O)C1=C(C)N=C(C)C(C(=O)OCC)C1c1ccccc1/C=C...
# 3116                    CCCCNC(=O)NS(=O)(=O)c1ccc(N)cc1
# 438                        CN[C@@]1(c2ccccc2Cl)CCCCC1=O
#
#                          INCHIKEY               dataset action_type  active  \
# 790   YVUQSNJEYSNKRX-UHFFFAOYSA-N         CHEMBL1142817   substrate    True
# 791   QWAXKHKRTORLEM-PVCXOJBVSA-N         CHEMBL1142817   substrate    True
# 794   FFGPTBGBLSHEPO-UHFFFAOYSA-N         CHEMBL1142817   substrate    True
# 2060  YVUQSNJEYSNKRX-UHFFFAOYSA-N  XinXu_NCATS_ADME_raw   substrate    True
# 591   YVUQSNJEYSNKRX-UHFFFAOYSA-N   carbon-mangels_2011   substrate    True
# ...                           ...                   ...         ...     ...
# 3119  WHLUQAYNVOGZST-UHFFFAOYSA-N  XinXu_NCATS_ADME_raw   substrate    True
# 3118  AFDXODALSZRGIH-QPJJXVBHSA-N  XinXu_NCATS_ADME_raw   substrate    True
# 442   BGYJFSXPRMOZJK-PFONDFGASA-N   carbon-mangels_2011   substrate    True
# 3116  VDTNNGKXZGSZIP-UHFFFAOYSA-N  XinXu_NCATS_ADME_raw   substrate    True
# 438   YQEZLKZALYSWHR-CYBMUJFWSA-N   carbon-mangels_2011   substrate    True
#
#         common_name  appears_in_N_datasets  dataset_CHEMBL1142817  \
# 790        pimozide                      6                   True
# 791      saquinavir                      6                   True
# 794   carbamazepine                      6                   True
# 2060       pimozide                      6                   True
# 591        pimozide                      6                   True
# ...             ...                    ...                    ...
# 3119            NaN                      1                  False
# 3118            NaN                      1                  False
# 442      lacidipine                      1                  False
# 3116            NaN                      1                  False
# 438        ketamine                      1                  False
#
#       dataset_XinXu_NCATS_ADME_raw  dataset_aid_589039_clinically_relevant  \
# 790                           True                                    True
# 791                           True                                    True
# 794                           True                                    True
# 2060                          True                                    True
# 591                           True                                    True
# ...                            ...                                     ...
# 3119                          True                                   False
# 3118                          True                                   False
# 442                          False                                   False
# 3116                          True                                   False
# 438                          False                                   False
#
#       dataset_carbon-mangels_2011  dataset_drugbank  dataset_flockheart  \
# 790                          True              True                True
# 791                          True              True                True
# 794                          True              True                True
# 2060                         True              True                True
# 591                          True              True                True
# ...                           ...               ...                 ...
# 3119                        False             False               False
# 3118                        False             False               False
# 442                          True             False               False
# 3116                        False             False               False
# 438                          True             False               False
#
#       assay_count  pChEMBL mean  inclusion_score
# 790           6.0         5.322             12.0
# 791           3.0         5.540              9.0
# 794           NaN           NaN              NaN
# 2060          6.0         5.322             12.0
# 591           6.0         5.322             12.0
# ...           ...           ...              ...
# 3119          NaN           NaN              NaN
# 3118          NaN           NaN              NaN
# 442           NaN           NaN              NaN
# 3116          NaN           NaN              NaN
# 438           NaN           NaN              NaN
#
# [6164 rows x 16 columns]

# %%
combined_literature_clean_w_counts.sort_values("inclusion_score")
# Out:
#                                        CANONICAL_SMILES  \
# 1981                  CCOC(=O)Nc1ccc(NCc2ccc(F)cc2)nc1N
# 1980                 Oc1ccc(C2CNCCc3c2cc(O)c(O)c3Cl)cc1
# 1977                               CCCCc1ccc(C(=O)O)nc1
# 763                                     CCCC(CCC)C(=O)O
# 2112         Cc1scc2c1N(C(=O)CN1CCN(C)CC1)c1ccccc1NC2=O
# ...                                                 ...
# 3119                 CCN(CC)CCSC(=O)C(c1ccccc1)c1ccccc1
# 3118                            COc1ccc(/C=C/C(=O)O)cc1
# 442   CCOC(=O)C1=C(C)N=C(C)C(C(=O)OCC)C1c1ccccc1/C=C...
# 3116                    CCCCNC(=O)NS(=O)(=O)c1ccc(N)cc1
# 438                        CN[C@@]1(c2ccccc2Cl)CCCCC1=O
#
#                          INCHIKEY               dataset action_type  active  \
# 1981  JUUFBMODXQKSTD-UHFFFAOYSA-N  XinXu_NCATS_ADME_raw   substrate    True
# 1980  TVURRHSHRRELCG-UHFFFAOYSA-N  XinXu_NCATS_ADME_raw   substrate    True
# 1977  DGMPVYSXXIOGJY-UHFFFAOYSA-N  XinXu_NCATS_ADME_raw   substrate    True
# 763   NIJJYAXOARWZEE-UHFFFAOYSA-N   carbon-mangels_2011   substrate    True
# 2112  VSWPGAIWKHPTKX-UHFFFAOYSA-N  XinXu_NCATS_ADME_raw   substrate    True
# ...                           ...                   ...         ...     ...
# 3119  WHLUQAYNVOGZST-UHFFFAOYSA-N  XinXu_NCATS_ADME_raw   substrate    True
# 3118  AFDXODALSZRGIH-QPJJXVBHSA-N  XinXu_NCATS_ADME_raw   substrate    True
# 442   BGYJFSXPRMOZJK-PFONDFGASA-N   carbon-mangels_2011   substrate    True
# 3116  VDTNNGKXZGSZIP-UHFFFAOYSA-N  XinXu_NCATS_ADME_raw   substrate    True
# 438   YQEZLKZALYSWHR-CYBMUJFWSA-N   carbon-mangels_2011   substrate    True
#
#         common_name  appears_in_N_datasets  dataset_CHEMBL1142817  \
# 1981            NaN                      1                  False
# 1980            NaN                      1                  False
# 1977            NaN                      1                  False
# 763   valproic-acid                      1                  False
# 2112            NaN                      1                  False
# ...             ...                    ...                    ...
# 3119            NaN                      1                  False
# 3118            NaN                      1                  False
# 442      lacidipine                      1                  False
# 3116            NaN                      1                  False
# 438        ketamine                      1                  False
#
#       dataset_XinXu_NCATS_ADME_raw  dataset_aid_589039_clinically_relevant  \
# 1981                          True                                   False
# 1980                          True                                   False
# 1977                          True                                   False
# 763                          False                                   False
# 2112                          True                                   False
# ...                            ...                                     ...
# 3119                          True                                   False
# 3118                          True                                   False
# 442                          False                                   False
# 3116                          True                                   False
# 438                          False                                   False
#
#       dataset_carbon-mangels_2011  dataset_drugbank  dataset_flockheart  \
# 1981                        False             False               False
# 1980                        False             False               False
# 1977                        False             False               False
# 763                          True             False               False
# 2112                        False             False               False
# ...                           ...               ...                 ...
# 3119                        False             False               False
# 3118                        False             False               False
# 442                          True             False               False
# 3116                        False             False               False
# 438                          True             False               False
#
#       assay_count  pChEMBL mean  inclusion_score
# 1981          3.0           5.1              4.0
# 1980          3.0           4.8              4.0
# 1977          3.0           4.6              4.0
# 763           3.0           5.8              4.0
# 2112          3.0           5.9              4.0
# ...           ...           ...              ...
# 3119          NaN           NaN              NaN
# 3118          NaN           NaN              NaN
# 442           NaN           NaN              NaN
# 3116          NaN           NaN              NaN
# 438           NaN           NaN              NaN
#
# [6164 rows x 16 columns]

# %%
sns.pairplot(combined_literature_clean_w_counts[["assay_count", "appears_in_N_datasets"]])

# %%
combined_literature_clean_w_counts.drop(columns=["dataset"], inplace=True)

# %%
combined_literature_clean_w_counts
# Out:
#                                        CANONICAL_SMILES  \
# 790   O=c1[nH]c2ccccc2n1C1CCN(CCCC(c2ccc(F)cc2)c2ccc...
# 791   CC(C)(C)NC(=O)C1C[C@@H]2CCCC[C@@H]2CN1C[C@@H](...
# 794                        NC(=O)N1c2ccccc2C=Cc2ccccc21
# 2060  O=c1[nH]c2ccccc2n1C1CCN(CCCC(c2ccc(F)cc2)c2ccc...
# 591   O=c1[nH]c2ccccc2n1C1CCN(CCCC(c2ccc(F)cc2)c2ccc...
# ...                                                 ...
# 3119                 CCN(CC)CCSC(=O)C(c1ccccc1)c1ccccc1
# 3118                            COc1ccc(/C=C/C(=O)O)cc1
# 442   CCOC(=O)C1=C(C)N=C(C)C(C(=O)OCC)C1c1ccccc1/C=C...
# 3116                    CCCCNC(=O)NS(=O)(=O)c1ccc(N)cc1
# 438                        CN[C@@]1(c2ccccc2Cl)CCCCC1=O
#
#                          INCHIKEY action_type  active    common_name  \
# 790   YVUQSNJEYSNKRX-UHFFFAOYSA-N   substrate    True       pimozide
# 791   QWAXKHKRTORLEM-PVCXOJBVSA-N   substrate    True     saquinavir
# 794   FFGPTBGBLSHEPO-UHFFFAOYSA-N   substrate    True  carbamazepine
# 2060  YVUQSNJEYSNKRX-UHFFFAOYSA-N   substrate    True       pimozide
# 591   YVUQSNJEYSNKRX-UHFFFAOYSA-N   substrate    True       pimozide
# ...                           ...         ...     ...            ...
# 3119  WHLUQAYNVOGZST-UHFFFAOYSA-N   substrate    True            NaN
# 3118  AFDXODALSZRGIH-QPJJXVBHSA-N   substrate    True            NaN
# 442   BGYJFSXPRMOZJK-PFONDFGASA-N   substrate    True     lacidipine
# 3116  VDTNNGKXZGSZIP-UHFFFAOYSA-N   substrate    True            NaN
# 438   YQEZLKZALYSWHR-CYBMUJFWSA-N   substrate    True       ketamine
#
#       appears_in_N_datasets  dataset_CHEMBL1142817  \
# 790                       6                   True
# 791                       6                   True
# 794                       6                   True
# 2060                      6                   True
# 591                       6                   True
# ...                     ...                    ...
# 3119                      1                  False
# 3118                      1                  False
# 442                       1                  False
# 3116                      1                  False
# 438                       1                  False
#
#       dataset_XinXu_NCATS_ADME_raw  dataset_aid_589039_clinically_relevant  \
# 790                           True                                    True
# 791                           True                                    True
# 794                           True                                    True
# 2060                          True                                    True
# 591                           True                                    True
# ...                            ...                                     ...
# 3119                          True                                   False
# 3118                          True                                   False
# 442                          False                                   False
# 3116                          True                                   False
# 438                          False                                   False
#
#       dataset_carbon-mangels_2011  dataset_drugbank  dataset_flockheart  \
# 790                          True              True                True
# 791                          True              True                True
# 794                          True              True                True
# 2060                         True              True                True
# 591                          True              True                True
# ...                           ...               ...                 ...
# 3119                        False             False               False
# 3118                        False             False               False
# 442                          True             False               False
# 3116                        False             False               False
# 438                          True             False               False
#
#       assay_count  pChEMBL mean  inclusion_score
# 790           6.0         5.322             12.0
# 791           3.0         5.540              9.0
# 794           NaN           NaN              NaN
# 2060          6.0         5.322             12.0
# 591           6.0         5.322             12.0
# ...           ...           ...              ...
# 3119          NaN           NaN              NaN
# 3118          NaN           NaN              NaN
# 442           NaN           NaN              NaN
# 3116          NaN           NaN              NaN
# 438           NaN           NaN              NaN
#
# [6164 rows x 15 columns]

# %%
from matplotlib import pyplot as plt
plt.title("CYP3A4 Inhibtion set pChEMBL mean")
sns.histplot(combined_literature_clean_w_counts, x="pChEMBL mean")
plt.savefig("inhibition_set_pchembl.png")

# %%
sns.histplot(combined_literature_clean_w_counts, x="inclusion_score")
# Out:
# <Axes: xlabel='inclusion_score', ylabel='Count'>

# %%
combined_literature_clean_w_counts["pChEMBL mean"].notna().sum()
# Out:
# 485

# %%
combined_literature_clean_w_counts.drop_duplicates(subset="INCHIKEY", inplace=True)

# %%
combined_literature_clean_w_counts.sort_values("inclusion_score", inplace=True, ascending=False)

# %%
combined_literature_clean_w_counts.head(20)
# Out:
#                                        CANONICAL_SMILES  \
# 1813      CC/C(=C(\c1ccccc1)c1ccc(OCCN(C)C)cc1)c1ccccc1
# 1501             Clc1ccccc1C(c1ccccc1)(c1ccccc1)n1ccnc1
# 2035                    CNCCCC12CCC(c3ccccc31)c1ccccc12
# 1940                  CN(C)CCCN1c2ccccc2CCc2ccc(Cl)cc21
# 82    COC(=O)C1=C(C)N=C(C)C(C(=O)OC)C1c1ccccc1[N+](=...
# 2395        Clc1ccc(COC(Cn2ccnc2)c2ccc(Cl)cc2Cl)c(Cl)c1
# 886   COc1ccc(CCN(C)CCCC(C#N)(c2ccc(OC)c(OC)c2)C(C)C...
# 2674  Cc1cc(N)c2ccccc2[n+]1CCCCCCCCCC[n+]1c(C)cc(N)c...
# 2336                       Oc1ccc(C=Cc2cc(O)cc(O)c2)cc1
# 2062              COc1ccc(Cc2nccc3cc(OC)c(OC)cc23)cc1OC
# 790   O=c1[nH]c2ccccc2n1C1CCN(CCCC(c2ccc(F)cc2)c2ccc...
# 2473                CCN(CC)CCOCCOC(=O)C1(c2ccccc2)CCCC1
# 2620                         CN=C(NC#N)NCCSCc1[nH]cnc1C
# 407        O=C(CCCN1CCC(O)(c2ccc(Cl)cc2)CC1)c1ccc(F)cc1
# 1879                        CNCCC=C1c2ccccc2CCc2ccccc21
# 2117                         CCN(CC)C(=S)SSC(=S)N(CC)CC
# 1678       O=C1CC2(CCCC2)CC(=O)N1CCCCN1CCN(c2ncccn2)CC1
# 2271      CN1CCC[C@@H]1CCO[C@](C)(c1ccccc1)c1ccc(Cl)cc1
# 2276  COc1cc(C(=O)OCCCN2CCCN(CCCOC(=O)c3cc(OC)c(OC)c...
# 241              O=C1CCc2cc(OCCCCc3nnnn3C3CCCCC3)ccc2N1
#
#                          INCHIKEY action_type  active    common_name  \
# 1813  NKANXQFJJICGDU-QPLCGJKRSA-N   substrate    True      Tamoxifen
# 1501  VNFPBHJOKIVQEB-UHFFFAOYSA-N   substrate    True   Clotrimazole
# 2035  QSLMDECMDJKHMQ-UHFFFAOYSA-N   substrate    True    maprotiline
# 1940  GDLIGKIOYRNHDA-UHFFFAOYSA-N   substrate    True   Clomipramine
# 82    OSUCQKNXQBPLDG-UHFFFAOYSA-N   substrate    True     Nifedipine
# 2395  BYBLEWFAAKGYCD-UHFFFAOYSA-N   substrate    True            NaN
# 886   SGTNSNPWRIOYBX-UHFFFAOYSA-N   substrate    True      Verapamil
# 2674  PCSWXVJAIHCTMO-UHFFFAOYSA-P   substrate    True            NaN
# 2336  LUKBXSAWLPMMSZ-UHFFFAOYSA-N   substrate    True            NaN
# 2062  XQYZDYMELSJDRZ-UHFFFAOYSA-N   substrate    True     papaverine
# 790   YVUQSNJEYSNKRX-UHFFFAOYSA-N   substrate    True       pimozide
# 2473  CFJMRBQWBDQYMK-UHFFFAOYSA-N   substrate    True            NaN
# 2620  AQIXAKUUQRKLND-UHFFFAOYSA-N   substrate    True     cimetidine
# 407   LNEPOXFFQSENCJ-UHFFFAOYSA-N   substrate    True    haloperidol
# 1879  PHVGLTMQBUFIQQ-UHFFFAOYSA-N   substrate    True  Nortriptyline
# 2117  AUZONCFQVSMFAP-UHFFFAOYSA-N   substrate    True     Disulfiram
# 1678  QWCRAEMEVRGPNT-UHFFFAOYSA-N   substrate    True      buspirone
# 2271  YNNUSGIPVFPVBX-NHCUHLMSSA-N   substrate    True     clemastine
# 2276  QVZCXCJXTMIDME-UHFFFAOYSA-N   substrate    True            NaN
# 241   RRGUKTPIGVIEKM-UHFFFAOYSA-N   substrate    True     cilostazol
#
#       appears_in_N_datasets  dataset_CHEMBL1142817  \
# 1813                      4                   True
# 1501                      2                  False
# 2035                      2                  False
# 1940                      3                  False
# 82                        4                  False
# 2395                      1                  False
# 886                       3                  False
# 2674                      1                  False
# 2336                      1                  False
# 2062                      2                  False
# 790                       6                   True
# 2473                      1                  False
# 2620                      2                  False
# 407                       5                   True
# 1879                      3                  False
# 2117                      3                  False
# 1678                      5                  False
# 2271                      2                  False
# 2276                      1                  False
# 241                       5                  False
#
#       dataset_XinXu_NCATS_ADME_raw  dataset_aid_589039_clinically_relevant  \
# 1813                          True                                   False
# 1501                         False                                   False
# 2035                          True                                   False
# 1940                          True                                   False
# 82                           False                                    True
# 2395                          True                                   False
# 886                           True                                   False
# 2674                          True                                   False
# 2336                          True                                   False
# 2062                          True                                   False
# 790                           True                                    True
# 2473                          True                                   False
# 2620                          True                                   False
# 407                           True                                   False
# 1879                          True                                   False
# 2117                          True                                   False
# 1678                          True                                    True
# 2271                          True                                   False
# 2276                          True                                   False
# 241                           True                                    True
#
#       dataset_carbon-mangels_2011  dataset_drugbank  dataset_flockheart  \
# 1813                        False              True                True
# 1501                         True              True               False
# 2035                         True             False               False
# 1940                         True              True               False
# 82                           True              True                True
# 2395                        False             False               False
# 886                         False              True                True
# 2674                        False             False               False
# 2336                        False             False               False
# 2062                         True             False               False
# 790                          True              True                True
# 2473                        False             False               False
# 2620                         True             False               False
# 407                          True              True                True
# 1879                         True              True               False
# 2117                         True              True               False
# 1678                         True              True                True
# 2271                         True             False               False
# 2276                        False             False               False
# 241                          True              True                True
#
#       assay_count  pChEMBL mean  inclusion_score
# 1813         14.0      4.846154             18.0
# 1501         14.0      7.237692             16.0
# 2035         13.0      5.473846             15.0
# 1940         11.0      4.645455             14.0
# 82           10.0      4.888000             14.0
# 2395         12.0      6.060000             13.0
# 886          10.0      5.392000             13.0
# 2674         11.0      5.372727             12.0
# 2336         11.0      5.556364             12.0
# 2062         10.0      5.690000             12.0
# 790           6.0      5.322000             12.0
# 2473         11.0      5.145455             12.0
# 2620          9.0      4.736667             11.0
# 407           6.0      5.195000             11.0
# 1879          8.0      4.787500             11.0
# 2117          8.0      5.025000             11.0
# 1678          6.0      4.850000             11.0
# 2271          9.0      5.400000             11.0
# 2276          9.0      5.033333             10.0
# 241           5.0      4.940000             10.0

# %%
combined_literature_clean_w_counts.to_csv("./final/actives_final.csv", index=False)
