# %%
import pandas as pd
from rdkit import Chem
import seaborn as sns
from tqdm import tqdm
import numpy as np

# %%
tqdm.pandas()

# %%
df = pd.read_csv("./Flockheart/2704859600940388722.txt", sep="\t")

# %%
df
# Out:
#         common_name                                             SMILES
# 0         adagrasib  CN1CCC[C@H]1COC2=NC3=C(CCN(C3)C4=CC=CC5=C4C(=C...
# 1        amlodipine  CCOC(=O)C1=C(NC(=C(C1C2=CC=CC=C2Cl)C(=O)OC)C)C...
# 2        aprepitant  C[C@H](C1=CC(=CC(=C1)C(F)(F)F)C(F)(F)F)O[C@@H]...
# 3       atomoxetine                CC1=CC=CC=C1O[C@H](CCNC)C2=CC=CC=C2
# 4        boceprevir  CC1([C@@H]2[C@H]1[C@H](N(C2)C(=O)[C@H](C(C)(C)...
# 5         ceritinib  CC1=CC(=C(C=C1C2CCNCC2)OC(C)C)NC3=NC=C(C(=N3)N...
# 6   chloramphenicol  C1=CC(=CC=C1[C@H]([C@@H](CO)NC(=O)C(Cl)Cl)O)[N...
# 7        cimetidine                        CC1=C(N=CN1)CSCCNC(=NC)NC#N
# 8     ciprofloxacin   C1CC1N2C=C(C(=O)C3=CC(=C(C=C32)N4CCNCC4)F)C(=O)O
# 9    clarithromycin  CC[C@@H]1[C@@]([C@@H]([C@H](C(=O)[C@@H](C[C@@]...
# 10       crizotinib  C[C@H](C1=C(C=CC(=C1Cl)F)Cl)OC2=C(N=CC(=C2)C3=...
# 11      delavirdine  CC(C)NC1=C(N=CC=C1)N2CCN(CC2)C(=O)C3=CC4=C(N3)...
# 12        diltiazem  CC(=O)O[C@@H]1[C@@H](SC2=CC=CC=C2N(C1=O)CCN(C)...
# 13      entrectinib   CN1CCN(CC1)C2=CC(=C(C=C2)C(=O)NC3=NNC4=C3C=C(...
# 14     erythromycin  CC[C@@H]1[C@@]([C@@H]([C@H](C(=O)[C@@H](C[C@@]...
# 15     esomeprazole  CC1=CN=C(C(=C1OC)C)C[S@](=O)C2=NC3=C(N2)C=C(C=...
# 16      fluconazole        C1=CC(=C(C=C1F)F)C(CN2C=NC=N2)(CN3C=NC=N3)O
# 17       idelalisib  CC[C@@H](C1=NC2=C(C(=CC=C2)F)C(=O)N1C3=CC=CC=C...
# 18         imatinib  CC1=C(C=C(C=C1)NC(=O)C2=CC=C(C=C2)CN3CCN(CC3)C...
# 19        indinavir  CC(C)(C)NC(=O)[C@@H]1CN(CCN1C[C@H](C[C@@H](CC2...
# 20     itraconazole  CCC(C)N1C(=O)N(C=N1)C2=CC=C(C=C2)N3CCN(CC3)C4=...
# 21        ivacaftor  CC(C)(C)C1=CC(=C(C=C1NC(=O)C2=CNC3=CC=CC=C3C2=...
# 22     ketoconazole  CC(=O)N1CCN(CC1)C2=CC=C(C=C2)OC[C@H]3CO[C@](O3...
# 23        lesinurad    C1CC1C2=CC=C(C3=CC=CC=C23)N4C(=NN=C4Br)SCC(=O)O
# 24       letermovir  COC1=C(C=C(C=C1)C(F)(F)F)N2[C@H](C3=C(C(=CC=C3...
# 25       mibefradil  CC(C)[C@H]1C2=C(CC[C@@]1(CCN(C)CCCC3=NC4=CC=CC...
# 26     mifepristone  CC#C[C@@]1(CC[C@@H]2[C@@]1(C[C@@H](C3=C4CCC(=O...
# 27       nefazodone  CCC1=NN(C(=O)N1CCOC2=CC=CC=C2)CCCN3CCN(CC3)C4=...
# 28       nelfinavir  CC1=C(C=CC=C1O)C(=O)N[C@@H](CSC2=CC=CC=C2)[C@@...
# 29       netupitant  CC1=CC=CC=C1C2=CC(=NC=C2N(C)C(=O)C(C)(C)C3=CC(...
# 30       omeprazole   CC1=CN=C(C(=C1OC)C)CS(=O)C2=NC3=C(N2)C=C(C=C3)OC
# 31       quercetine  C1=CC(=C(C=C1C2=C(C(=O)C3=C(C=C(C=C3O2)O)O)O)O...
# 32       ribociclib  CN(C)C(=O)C1=CC2=CN=C(N=C2N1C3CCCC3)NC4=NC=C(C...
# 33        ritonavir  CC(C)C1=NC(=CS1)CN(C)C(=O)N[C@@H](C(C)C)C(=O)N...
# 34        rucaparib   CNCC1=CC=C(C=C1)C2=C3CCNC(=O)C4=C3C(=CC(=C4)F)N2
# 35       saquinavir  CC(C)(C)NC(=O)[C@@H]1C[C@@H]2CCCC[C@@H]2CN1C[C...
# 36       simeprevir  CC1=C(C=CC2=C1N=C(C=C2O[C@@H]3C[C@@H]4[C@@H](C...
# 37    telithromycin  CC[C@@H]1[C@@]2([C@@H]([C@H](C(=O)[C@@H](C[C@@...
# 38        tucatinib  CC1=C(C=CC(=C1)NC2=NC=NC3=C2C=C(C=C3)NC4=NC(CO...
# 39        verapamil  CC(C)C(CCCN(C)CCC1=CC(=C(C=C1)OC)OC)(C#N)C2=CC...
# 40     voriconazole  C[C@@H](C1=NC=NC=C1F)[C@](CN2C=NC=N2)(C3=C(C=C...

# %%
# standardisation of SMILES
from rdkit import Chem
from rdkit.Chem.MolStandardize import rdMolStandardize
from rdkit.rdBase import BlockLogs
import mols2grid

# %%
# from Pat Walters method
def standardize_smiles(smiles):
    try:
        # follows the steps in
        # https://github.com/greglandrum/RSC_OpenScience_Standardization_202104/blob/main/MolStandardize%20pieces.ipynb
        # as described **excellently** (by Greg) in
        # https://www.youtube.com/watch?v=eWTApNX8dJQ
        mol = Chem.MolFromSmiles(smiles)
    
        # removeHs, disconnect metal atoms, normalize the molecule, reionize the molecule
        clean_mol = rdMolStandardize.Cleanup(mol)
    
        # if many fragments, get the "parent" (the actual mol we are interested in) 
        parent_clean_mol = rdMolStandardize.FragmentParent(clean_mol)
    
        # try to neutralize molecule
        uncharger = rdMolStandardize.Uncharger()  # annoying, but necessary as no convenience method exists
        uncharged_parent_clean_mol = uncharger.uncharge(parent_clean_mol)
    
        # note that no attempt is made at reionization at this step
        # nor at ionization at some pH (rdkit has no pKa caculator)
        # the main aim to represent all molecules from different sources
        # in a (single) standard way, for use in ML, catalogue, etc.
    
        te = rdMolStandardize.TautomerEnumerator()  # idem
        taut_uncharged_parent_clean_mol = te.Canonicalize(uncharged_parent_clean_mol)
    
        return Chem.MolToSmiles(taut_uncharged_parent_clean_mol)
    except:
        return pd.NA

# %%
def smi_to_inchikey(smiles):
    try:
        mol = Chem.MolFromSmiles(smiles)
        return Chem.MolToInchiKey(mol)
    except:
        return pd.NA

# %%
with BlockLogs():
    df["CANONICAL_SMILES"] = df["SMILES"].progress_apply(lambda x: standardize_smiles(x))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 41/41 [00:00<00:00, 42.40it/s]

# %%
# compute inchikeys
with BlockLogs():
    df["INCHIKEY"] = df["CANONICAL_SMILES"].progress_apply(lambda x: smi_to_inchikey(x))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 41/41 [00:00<00:00, 2910.69it/s]

# %%
df["dataset"] = "flockheart"
df["action_type"] = "inhibitor"
df["active"] = True
df.drop(columns="SMILES")
# Out:
#         common_name                                   CANONICAL_SMILES  \
# 0         adagrasib  C=C(F)C(=O)N1CCN(c2nc(OC[C@@H]3CCCN3C)nc3c2CCN...
# 1        amlodipine    CCOC(=O)C1=C(COCCN)N=C(C)C(C(=O)OC)C1c1ccccc1Cl
# 2        aprepitant  C[C@@H](O[C@H]1OCCN(Cc2n[nH]c(=O)[nH]2)[C@H]1c...
# 3       atomoxetine                     CNCC[C@@H](Oc1ccccc1C)c1ccccc1
# 4        boceprevir  CC(C)(C)NC(=O)NC(C(=O)N1C[C@H]2C(C1C(=O)NC(CC1...
# 5         ceritinib  Cc1cc(Nc2ncc(Cl)c(Nc3ccccc3S(=O)(=O)C(C)C)n2)c...
# 6   chloramphenicol  O=C(N[C@H](CO)[C@H](O)c1ccc([N+](=O)[O-])cc1)C...
# 7        cimetidine                         CN=C(NC#N)NCCSCc1[nH]cnc1C
# 8     ciprofloxacin         O=C(O)c1cn(C2CC2)c2cc(N3CCNCC3)c(F)cc2c1=O
# 9    clarithromycin  CC[C@H]1OC(=O)C(C)[C@@H](O[C@H]2C[C@@](C)(OC)[...
# 10       crizotinib  C[C@@H](Oc1cc(-c2cnn(C3CCNCC3)c2)cnc1N)c1c(Cl)...
# 11      delavirdine  CC(C)Nc1cccnc1N1CCN(C(=O)c2cc3cc(NS(C)(=O)=O)c...
# 12        diltiazem  COc1ccc([C@@H]2Sc3ccccc3N(CCN(C)C)C(=O)C2OC(C)...
# 13      entrectinib  CN1CCN(c2ccc(C(=O)Nc3[nH]nc4ccc(Cc5cc(F)cc(F)c...
# 14     erythromycin  CC[C@H]1OC(=O)C(C)[C@@H](O[C@H]2C[C@@](C)(OC)[...
# 15     esomeprazole  COc1ccc2[nH]c([S@@+]([O-])Cc3ncc(C)c(OC)c3C)nc2c1
# 16      fluconazole                 OC(Cn1cncn1)(Cn1cncn1)c1ccc(F)cc1F
# 17       idelalisib  CC[C@H](Nc1ncnc2[nH]cnc12)c1nc2cccc(F)c2c(=O)n...
# 18         imatinib  Cc1ccc(NC(=O)c2ccc(CN3CCN(C)CC3)cc2)cc1Nc1nccc...
# 19        indinavir  CC(C)(C)NC(=O)C1CN(Cc2cccnc2)CCN1C[C@@H](O)CC(...
# 20     itraconazole  CCC(C)n1ncn(-c2ccc(N3CCN(c4ccc(OC[C@H]5CO[C@](...
# 21        ivacaftor  CC(C)(C)c1cc(C(C)(C)C)c(NC(=O)c2c[nH]c3ccccc3c...
# 22     ketoconazole  CC(=O)N1CCN(c2ccc(OC[C@H]3CO[C@](Cn4ccnc4)(c4c...
# 23        lesinurad          O=C(O)CSc1nnc(Br)n1-c1ccc(C2CC2)c2ccccc12
# 24       letermovir  COc1cccc(N2CCN(C3=Nc4c(F)cccc4[C@H](CC(=O)O)N3...
# 25       mibefradil  COCC(=O)O[C@]1(CCN(C)CCCc2nc3ccccc3[nH]2)CCc2c...
# 26     mifepristone  CC#C[C@]1(O)CC[C@H]2C3=C(C4=C(CC3)CC(=O)CC4)C(...
# 27       nefazodone  CCc1nn(CCCN2CCN(c3cccc(Cl)c3)CC2)c(=O)n1CCOc1c...
# 28       nelfinavir  Cc1c(O)cccc1C(=O)N[C@@H](CSc1ccccc1)[C@H](O)CN...
# 29       netupitant  Cc1ccccc1-c1cc(N2CCN(C)CC2)ncc1N(C)C(=O)C(C)(C...
# 30       omeprazole    COc1ccc2[nH]c([S+]([O-])Cc3ncc(C)c(OC)c3C)nc2c1
# 31       quercetine         O=c1c(O)c(-c2ccc(O)c(O)c2)oc2cc(O)cc(O)c12
# 32       ribociclib  CN(C)C(=O)c1cc2cnc(Nc3ccc(N4CCNCC4)cn3)nc2n1C1...
# 33        ritonavir  CC(C)c1nc(CN(C)C(=O)NC(C(=O)N[C@@H](Cc2ccccc2)...
# 34        rucaparib          CNCc1ccc(-c2[nH]c3cc(F)cc4c3c2CCNC4=O)cc1
# 35       saquinavir  CC(C)(C)NC(=O)C1C[C@@H]2CCCC[C@@H]2CN1C[C@@H](...
# 36       simeprevir  Cc1c(O)ccc2c(O[C@@H]3CC4C(=O)N[C@]5(C(=O)NS(=O...
# 37    telithromycin  CC[C@H]1OC(=O)C(C)C(=O)C(C)[C@@H](O[C@@H]2O[C@...
# 38        tucatinib  Cc1cc(Nc2ncnc3ccc(N=C4NC(C)(C)CO4)cc23)ccc1Oc1...
# 39        verapamil  COc1ccc(CCN(C)CCCC(C#N)(c2ccc(OC)c(OC)c2)C(C)C...
# 40     voriconazole         CC(c1ncncc1F)[C@](O)(Cn1cncn1)c1ccc(F)cc1F
#
#                        INCHIKEY     dataset action_type  active
# 0   PEMUGDMSUDYLHU-ZEQRLZLVSA-N  flockheart   inhibitor    True
# 1   YMDXSGBNCBQYGC-UHFFFAOYSA-N  flockheart   inhibitor    True
# 2   ATALOFNDEOCMKK-OITMNORJSA-N  flockheart   inhibitor    True
# 3   VHGCDTVCOLNTBX-QGZVFWFLSA-N  flockheart   inhibitor    True
# 4   LHHCSNFAOIFYRV-CCLIWJKGSA-N  flockheart   inhibitor    True
# 5   VERWOWGGCGHDQE-UHFFFAOYSA-N  flockheart   inhibitor    True
# 6   WIIZWVCIJKGZOK-RKDXNWHRSA-N  flockheart   inhibitor    True
# 7   AQIXAKUUQRKLND-UHFFFAOYSA-N  flockheart   inhibitor    True
# 8   MYSWGUAQZAJSOK-UHFFFAOYSA-N  flockheart   inhibitor    True
# 9   AGOYDEPGAOXOCK-WLLSWQJKSA-N  flockheart   inhibitor    True
# 10  KTEIFNKAUNYNJU-GFCCVEGCSA-N  flockheart   inhibitor    True
# 11  WHBIGIKBNXZKFE-UHFFFAOYSA-N  flockheart   inhibitor    True
# 12  HSUGRBWQSSZJOP-LBAQZLPGSA-N  flockheart   inhibitor    True
# 13  HAYYBYPASCDWEQ-UHFFFAOYSA-N  flockheart   inhibitor    True
# 14  ULGZDMOVFRHVEP-ZWLFKSPASA-N  flockheart   inhibitor    True
# 15  SUBDBMMJDZJVOS-DEOSSOPVSA-N  flockheart   inhibitor    True
# 16  RFHAOTPXVQNOHP-UHFFFAOYSA-N  flockheart   inhibitor    True
# 17  IFSDAJWBUCMOAH-HNNXBMFYSA-N  flockheart   inhibitor    True
# 18  KTUFNOKKBVMGRW-UHFFFAOYSA-N  flockheart   inhibitor    True
# 19  CBVCZFGXHXORBI-IXVTTXLYSA-N  flockheart   inhibitor    True
# 20  VHVPQPYKVGDNFY-ZPGVKDDISA-N  flockheart   inhibitor    True
# 21  PURKAOJPTOLRMP-UHFFFAOYSA-N  flockheart   inhibitor    True
# 22  XMAYWYJOQHXEEK-OZXSUGGESA-N  flockheart   inhibitor    True
# 23  FGQFOYHRJSUHMR-UHFFFAOYSA-N  flockheart   inhibitor    True
# 24  FWYSMLBETOMXAG-QHCPKHFHSA-N  flockheart   inhibitor    True
# 25  HBNPJJILLOYFJU-VMPREFPWSA-N  flockheart   inhibitor    True
# 26  BHZCGCMWEVHUBA-ZLMDOPAYSA-N  flockheart   inhibitor    True
# 27  VRBKIVRKKCLPHA-UHFFFAOYSA-N  flockheart   inhibitor    True
# 28  QAGYKUNXZHXKMR-RHMILFQJSA-N  flockheart   inhibitor    True
# 29  WAXQNWCZJDTGBU-UHFFFAOYSA-N  flockheart   inhibitor    True
# 30  SUBDBMMJDZJVOS-UHFFFAOYSA-N  flockheart   inhibitor    True
# 31  REFJWTPEDVJJIY-UHFFFAOYSA-N  flockheart   inhibitor    True
# 32  RHXHGRAEPCAFML-UHFFFAOYSA-N  flockheart   inhibitor    True
# 33  NCDNCNXCDXHOMX-BWGGSIGWSA-N  flockheart   inhibitor    True
# 34  HMABYWSNWIZPAG-UHFFFAOYSA-N  flockheart   inhibitor    True
# 35  QWAXKHKRTORLEM-PVCXOJBVSA-N  flockheart   inhibitor    True
# 36  XSOSJEWXWPYOIL-URBUVVPISA-N  flockheart   inhibitor    True
# 37  LJVAJPDWBABPEJ-HZQJCNAYSA-N  flockheart   inhibitor    True
# 38  SDEAXTCZPQIFQM-UHFFFAOYSA-N  flockheart   inhibitor    True
# 39  SGTNSNPWRIOYBX-UHFFFAOYSA-N  flockheart   inhibitor    True
# 40  BCEHBSKCWLPMDN-YRQZNCJOSA-N  flockheart   inhibitor    True

# %%
df.to_csv("processed/flockheart.csv", index=False)
