# %%
import pandas as pd
from rdkit import Chem
import seaborn as sns
from tqdm import tqdm
import numpy as np

# %%
tqdm.pandas()

# %%
chembl = pd.read_csv("ChEMBL/ChEMBL_P08684_activities.csv", sep=";")
# Out:
# /tmp/ipykernel_263338/51894694.py:1: DtypeWarning: Columns (32,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   chembl = pd.read_csv("ChEMBL/ChEMBL_P08684_activities.csv", sep=";")

# %%
chembl
# Out:
#       Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight  \
# 0             CHEMBL1405       ESTRONE                 4.0            270.37
# 1           CHEMBL404811     DIGITONIN                 NaN           1229.32
# 2           CHEMBL288857           NaN                 NaN            474.55
# 3           CHEMBL168471           NaN                 NaN            372.46
# 4           CHEMBL168471           NaN                 NaN            372.46
# ...                  ...           ...                 ...               ...
# 53854      CHEMBL4847873           NaN                 NaN            421.38
# 53855      CHEMBL4868703           NaN                 NaN            419.57
# 53856       CHEMBL254316   RALTEGRAVIR                 4.0            444.42
# 53857      CHEMBL5183579           NaN                 NaN            557.65
# 53858       CHEMBL376488   BEDAQUILINE                 4.0            555.52
#
#        #RO5 Violations  AlogP Compound Key  \
# 0                  0.0   3.82      ESTRONE
# 1                  NaN    NaN    DIGITONIN
# 2                  1.0   5.37          18a
# 3                  0.0   1.86            8
# 4                  0.0   1.86            8
# ...                ...    ...          ...
# 53854              0.0   3.70         11mR
# 53855              0.0   4.00          11r
# 53856              0.0   0.91           53
# 53857              2.0   5.05           37
# 53858              2.0   7.13  Bedaquiline
#
#                                                   Smiles      Standard Type  \
# 0       C[C@]12CC[C@@H]3c4ccc(O)cc4CC[C@H]3[C@@H]1CCC2=O               IC50
# 1      C[C@@H]1CC[C@@]2(OC1)O[C@H]1[C@@H](O)[C@H]3[C@...                 Ki
# 2      CCCCCO/C(O)=C1\C(C)=NC(C)=C(C(=O)OCCOCCC)C1c1c...  Rate of oxidation
# 3      CC(C)C[C@H](C=O)NC(=O)[C@@H](NS(=O)(=O)c1ccc(F...               IC50
# 4      CC(C)C[C@H](C=O)NC(=O)[C@@H](NS(=O)(=O)c1ccc(F...               IC50
# ...                                                  ...                ...
# 53854  CCC[C@H](c1nc2ccc(Br)cc2c(=O)n1CC)N1C[C@@H](C)...         Inhibition
# 53855  CCCC(c1nc2cc(-c3ccncc3)ccc2c(=O)n1CC)N1C[C@@H]...         Inhibition
# 53856  Cc1nnc(C(=O)NC(C)(C)c2nc(C(=O)NCc3ccc(F)cc3)c(...           Activity
# 53857  N#Cc1ccc(CN2CCC(NC(=O)c3ccc(C(=O)N4CCC(C(F)c5c...               IC50
# 53858  COc1nc2ccc(Br)cc2cc1[C@@H](c1ccccc1)[C@@](O)(C...               IC50
#
#       Standard Relation  ...     Target Type Document ChEMBL ID  Source ID  \
# 0                   NaN  ...  SINGLE PROTEIN      CHEMBL1909046         15
# 1                   NaN  ...  SINGLE PROTEIN      CHEMBL1909046         15
# 2                   '='  ...  SINGLE PROTEIN      CHEMBL1123360          1
# 3                   '='  ...  SINGLE PROTEIN      CHEMBL1145779          1
# 4                   '='  ...  SINGLE PROTEIN      CHEMBL1145779          1
# ...                 ...  ...             ...                ...        ...
# 53854               '='  ...  SINGLE PROTEIN      CHEMBL4823330          1
# 53855               '='  ...  SINGLE PROTEIN      CHEMBL4823330          1
# 53856               '='  ...  SINGLE PROTEIN      CHEMBL5244274          1
# 53857               NaN  ...  SINGLE PROTEIN      CHEMBL5108030          1
# 53858               '>'  ...  SINGLE PROTEIN      CHEMBL5113423          1
#
#           Source Description      Document Journal Document Year  \
# 0                 DrugMatrix                   NaN           NaN
# 1                 DrugMatrix                   NaN           NaN
# 2      Scientific Literature            J Med Chem        1986.0
# 3      Scientific Literature            J Med Chem        2003.0
# 4      Scientific Literature            J Med Chem        2003.0
# ...                      ...                   ...           ...
# 53854  Scientific Literature     ACS Med Chem Lett        2021.0
# 53855  Scientific Literature     ACS Med Chem Lett        2021.0
# 53856  Scientific Literature            J Med Chem        2021.0
# 53857  Scientific Literature       Bioorg Med Chem        2022.0
# 53858  Scientific Literature  Bioorg Med Chem Lett        2022.0
#
#        Cell ChEMBL ID                         Properties  Action Type  \
# 0       CHEMBL3833782                                NaN          NaN
# 1       CHEMBL3833782                                NaN          NaN
# 2                 NaN                                NaN          NaN
# 3                 NaN                                NaN          NaN
# 4                 NaN                                NaN          NaN
# ...               ...                                ...          ...
# 53854             NaN  Dose = 1.0 microM | TIME = 0.5 hr    INHIBITOR
# 53855             NaN  Dose = 1.0 microM | TIME = 0.5 hr    INHIBITOR
# 53856             NaN                                NaN    ACTIVATOR
# 53857             NaN                                NaN          NaN
# 53858             NaN                                NaN          NaN
#
#        Standard Text Value
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 53854                  NaN
# 53855                  NaN
# 53856                  NaN
# 53857                  NaN
# 53858                  NaN
#
# [53859 rows x 47 columns]

# %%
chembl.columns
# Out:
# Index(['Molecule ChEMBL ID', 'Molecule Name', 'Molecule Max Phase',
#        'Molecular Weight', '#RO5 Violations', 'AlogP', 'Compound Key',
#        'Smiles', 'Standard Type', 'Standard Relation', 'Standard Value',
#        'Standard Units', 'pChEMBL Value', 'Data Validity Comment', 'Comment',
#        'Uo Units', 'Ligand Efficiency BEI', 'Ligand Efficiency LE',
#        'Ligand Efficiency LLE', 'Ligand Efficiency SEI', 'Potential Duplicate',
#        'Assay ChEMBL ID', 'Assay Description', 'Assay Type', 'BAO Format ID',
#        'BAO Label', 'Assay Organism', 'Assay Tissue ChEMBL ID',
#        'Assay Tissue Name', 'Assay Cell Type', 'Assay Subcellular Fraction',
#        'Assay Parameters', 'Assay Variant Accession', 'Assay Variant Mutation',
#        'Target ChEMBL ID', 'Target Name', 'Target Organism', 'Target Type',
#        'Document ChEMBL ID', 'Source ID', 'Source Description',
#        'Document Journal', 'Document Year', 'Cell ChEMBL ID', 'Properties',
#        'Action Type', 'Standard Text Value'],
#       dtype='object')

# %%
chembl["Data Validity Comment"].value_counts()
# Out:
# Data Validity Comment
# Outside typical range            273
# Potential missing data             7
# Potential transcription error      5
# Name: count, dtype: int64

# %%
chembl["Action Type"].value_counts()
# Out:
# Action Type
# INHIBITOR        1152
# SUBSTRATE         119
# ACTIVATOR          73
# DEGRADER            9
# BINDING AGENT       7
# ANTAGONIST          3
# Name: count, dtype: int64

# %%
chembl["Standard Units"].value_counts()
# Out:
# Standard Units
# nM               33691
# %                 6351
# uM                 720
# /min               145
# hr                  70
# min-1               56
# /s                  42
# /uM/min             26
# degrees C           24
# pmol/min            24
# mL.min-1.g-1        18
# nmol/min            16
# min                 15
# 10^-4/min           13
# mM                  13
# %/min               12
# uL/min              11
# L/min/umol           9
# nm                   9
# uL/min/pmol          8
# 10'-4/min            6
# /min/nM              4
# pmol/hr              4
# %/min/pmol           4
# ml/min/nmol          3
# nmol/min/mg          3
# ug/L                 3
# ug.mL-1              3
# /min/microM          3
# ml/min/mg            3
# 10'3ml/min           3
# uL/min/nmol          2
# /nM.min              2
# uL/min.mg            2
# pmol/min/pmol        2
# pmol/mg.min          2
# uL/mg/min            2
# ml/min/uL            2
# ml/min/umol          1
# ng/ml                1
# ul.min.nmol-1        1
# /hr                  1
# mol/min              1
# /min/mM              1
# pmol.min.mg-1        1
# Name: count, dtype: int64

# %%
chembl["Standard Type"].value_counts()
# Out:
# Standard Type
# AC50                          17143
# Potency                       13692
# IC50                          12205
# Inhibition                     4994
# Activity                       1704
# Ki                             1121
# Drug metabolism                 507
# INH                             496
# TDI                             412
# Ratio IC50                      263
# FC                              237
# Stability                       126
# Kinact                          111
# Ratio                            97
# K                                79
# Km                               71
# T1/2                             70
# Log 1/Km                         58
# Compound recovery                54
# CL                               54
# EC50                             45
# Kcat                             44
# mechanism based inhibition       34
# Ks                               31
# Vmax                             28
# Rate of oxidation                18
# Emax                             16
# Kd                               16
# Delta Tm                         16
# Vmax/Km                          14
# IC20                             13
# Retention_time                   12
# Inhibitory index                  9
# deltaA                            9
# Tm                                8
# IC90                              8
# IC                                7
# Fm                                6
# Partition ratio                   5
# t1/2                              4
# NOAEL                             4
# CL free                           3
# Vmax(app)                         2
# IC5                               2
# Control of P-450 marker           2
# Log IC50                          1
# Cmax                              1
# Selectivity ratio                 1
# pIC50                             1
# Imax                              1
# kinact                            1
# PPB                               1
# Drug uptake                       1
# Kdiss                             1
# Name: count, dtype: int64

# %%
sns.histplot(data=chembl, x="pChEMBL Value", hue="Assay Type")
# Out:
# <Axes: xlabel='pChEMBL Value', ylabel='Count'>

# %%
sns.countplot(data=chembl, x="Action Type")
# Out:
# <Axes: xlabel='Action Type', ylabel='count'>

# %%
chembl["Molecule ChEMBL ID"].nunique()
# Out:
# 33986

# %%
chembl["Assay ChEMBL ID"].nunique()
# Out:
# 4931

# %% [markdown]
# 33986 unique molecules
# 4931 unique assays

# %%
# from Pat Walters method
def standardize_smiles(smiles):
    try:
        # follows the steps in
        # https://github.com/greglandrum/RSC_OpenScience_Standardization_202104/blob/main/MolStandardize%20pieces.ipynb
        # as described **excellently** (by Greg) in
        # https://www.youtube.com/watch?v=eWTApNX8dJQ
        mol = Chem.MolFromSmiles(smiles)
    
        # removeHs, disconnect metal atoms, normalize the molecule, reionize the molecule
        clean_mol = rdMolStandardize.Cleanup(mol)
    
        # if many fragments, get the "parent" (the actual mol we are interested in) 
        parent_clean_mol = rdMolStandardize.FragmentParent(clean_mol)
    
        # try to neutralize molecule
        uncharger = rdMolStandardize.Uncharger()  # annoying, but necessary as no convenience method exists
        uncharged_parent_clean_mol = uncharger.uncharge(parent_clean_mol)
    
        # note that no attempt is made at reionization at this step
        # nor at ionization at some pH (rdkit has no pKa caculator)
        # the main aim to represent all molecules from different sources
        # in a (single) standard way, for use in ML, catalogue, etc.
    
        te = rdMolStandardize.TautomerEnumerator()  # idem
        taut_uncharged_parent_clean_mol = te.Canonicalize(uncharged_parent_clean_mol)
    
        return Chem.MolToSmiles(taut_uncharged_parent_clean_mol)
    except:
        return pd.NA

# %%
# standardisation of SMILES
from rdkit import Chem
from rdkit.Chem.MolStandardize import rdMolStandardize
from rdkit.rdBase import BlockLogs
import mols2grid

# %%
with BlockLogs():
    chembl["CANONICAL_SMILES"] = chembl["Smiles"].progress_apply(lambda x: standardize_smiles(x))
# Out:
# 00%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 53859/53859 [06:20<00:00, 141.46it/s]

# %%
def smi_to_inchikey(smiles):
    try:
        mol = Chem.MolFromSmiles(smiles)
        return Chem.MolToInchiKey(mol)
    except:
        return pd.NA

# %%
# compute inchikeys
with BlockLogs():
    chembl["INCHIKEY"] = chembl["CANONICAL_SMILES"].progress_apply(lambda x: smi_to_inchikey(x))
# Out:
# 00%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 53859/53859 [00:14<00:00, 3777.10it/s]

# %%
chembl.INCHIKEY.nunique()
# Out:
# 33410

# %%
chembl.dropna(subset="INCHIKEY", inplace=True)

# %% [markdown]
# # select higher quality data
#
# See here for more detail
#
# https://greglandrum.github.io/rdkit-blog/posts/2023-06-12-overlapping-ic50-assays1.html
#
#
# ## What we will do
#
# * Select assays with IC50, AC50, pIC50, XC50, EC50, Ki or potency endpoints
# * Select assays in nM
# * Select assays with more then N molecules (20, 10?)
# * Select compounds that appear in more than L of these assays (2, 3 , 5)?

# %%
better_assay = chembl[
    (chembl['Standard Type'] == 'IC50') |
    (chembl['Standard Type'] == 'AC50') |
    (chembl['Standard Type'] == 'pIC50') |
    (chembl['Standard Type'] == 'XC50') |
    (chembl['Standard Type'] == 'EC50') | 
    (chembl['Standard Type'] == 'Ki') |
    (chembl['Standard Type'] == 'Potency')
]

# %%
better_assay
# Out:
#       Molecule ChEMBL ID   Molecule Name  Molecule Max Phase  \
# 0             CHEMBL1405         ESTRONE                 4.0
# 1           CHEMBL404811       DIGITONIN                 NaN
# 3           CHEMBL168471             NaN                 NaN
# 4           CHEMBL168471             NaN                 NaN
# 5             CHEMBL1109  SULFAPHENAZOLE                 4.0
# ...                  ...             ...                 ...
# 53851      CHEMBL5175220             NaN                 NaN
# 53852      CHEMBL5267910             NaN                 NaN
# 53853      CHEMBL4846941             NaN                 NaN
# 53857      CHEMBL5183579             NaN                 NaN
# 53858       CHEMBL376488     BEDAQUILINE                 4.0
#
#        Molecular Weight  #RO5 Violations  AlogP Compound Key  \
# 0                270.37              0.0   3.82      ESTRONE
# 1               1229.32              NaN    NaN    DIGITONIN
# 3                372.46              0.0   1.86            8
# 4                372.46              0.0   1.86            8
# 5                314.37              0.0   2.26  SID26747662
# ...                 ...              ...    ...          ...
# 53851            573.75              2.0   5.40           26
# 53852            483.59              0.0   4.56           42
# 53853            570.47              2.0   8.05            8
# 53857            557.65              2.0   5.05           37
# 53858            555.52              2.0   7.13  Bedaquiline
#
#                                                   Smiles Standard Type  \
# 0       C[C@]12CC[C@@H]3c4ccc(O)cc4CC[C@H]3[C@@H]1CCC2=O          IC50
# 1      C[C@@H]1CC[C@@]2(OC1)O[C@H]1[C@@H](O)[C@H]3[C@...            Ki
# 3      CC(C)C[C@H](C=O)NC(=O)[C@@H](NS(=O)(=O)c1ccc(F...          IC50
# 4      CC(C)C[C@H](C=O)NC(=O)[C@@H](NS(=O)(=O)c1ccc(F...          IC50
# 5                  Nc1ccc(S(=O)(=O)Nc2ccnn2-c2ccccc2)cc1       Potency
# ...                                                  ...           ...
# 53851  CC(=O)N1CCc2c(nc(C)n2[C@@H]2C[C@H]3CC[C@@H](C2...          IC50
# 53852  O=C(Nc1ccc(-c2ccc(F)cn2)cc1)c1cc2sc(NCCN3CCOCC...          IC50
# 53853  O=C(O)c1cc(F)c2nc(N3CCC4(C=C(c5c(-c6c(Cl)cccc6...          IC50
# 53857  N#Cc1ccc(CN2CCC(NC(=O)c3ccc(C(=O)N4CCC(C(F)c5c...          IC50
# 53858  COc1nc2ccc(Br)cc2cc1[C@@H](c1ccccc1)[C@@](O)(C...          IC50
#
#       Standard Relation  ...  Source ID     Source Description  \
# 0                   NaN  ...         15             DrugMatrix
# 1                   NaN  ...         15             DrugMatrix
# 3                   '='  ...          1  Scientific Literature
# 4                   '='  ...          1  Scientific Literature
# 5                   '='  ...          7      PubChem BioAssays
# ...                 ...  ...        ...                    ...
# 53851               '>'  ...          1  Scientific Literature
# 53852               '='  ...          1  Scientific Literature
# 53853               '='  ...          1  Scientific Literature
# 53857               NaN  ...          1  Scientific Literature
# 53858               '>'  ...          1  Scientific Literature
#
#            Document Journal Document Year Cell ChEMBL ID      Properties  \
# 0                       NaN           NaN  CHEMBL3833782             NaN
# 1                       NaN           NaN  CHEMBL3833782             NaN
# 3                J Med Chem        2003.0            NaN             NaN
# 4                J Med Chem        2003.0            NaN             NaN
# 5                       NaN           NaN            NaN             NaN
# ...                     ...           ...            ...             ...
# 53851            J Med Chem        2022.0            NaN             NaN
# 53852       Bioorg Med Chem        2020.0            NaN             NaN
# 53853     ACS Med Chem Lett        2021.0            NaN  TIME = 0.25 hr
# 53857       Bioorg Med Chem        2022.0            NaN             NaN
# 53858  Bioorg Med Chem Lett        2022.0            NaN             NaN
#
#        Action Type  Standard Text Value  \
# 0              NaN                  NaN
# 1              NaN                  NaN
# 3              NaN                  NaN
# 4              NaN                  NaN
# 5              NaN                  NaN
# ...            ...                  ...
# 53851          NaN                  NaN
# 53852    INHIBITOR                  NaN
# 53853    INHIBITOR                  NaN
# 53857          NaN                  NaN
# 53858          NaN                  NaN
#
#                                         CANONICAL_SMILES  \
# 0       C[C@]12CC[C@@H]3c4ccc(O)cc4CC[C@H]3[C@@H]1CCC2=O
# 1      C[C@@H]1CC[C@@]2(OC1)O[C@H]1[C@@H](O)[C@H]3[C@...
# 3        CC(C)CC(C=O)NC(=O)C(NS(=O)(=O)c1ccc(F)cc1)C(C)C
# 4        CC(C)CC(C=O)NC(=O)C(NS(=O)(=O)c1ccc(F)cc1)C(C)C
# 5                  Nc1ccc(S(=O)(=O)Nc2ccnn2-c2ccccc2)cc1
# ...                                                  ...
# 53851  CC(=O)N1CCc2c(nc(C)n2[C@@H]2C[C@H]3CC[C@@H](C2...
# 53852  O=C(Nc1ccc(-c2ccc(F)cn2)cc1)c1cc2sc(NCCN3CCOCC...
# 53853  O=C(O)c1cc(F)c2nc(N3CCC4(C=C(c5c(-c6c(Cl)cccc6...
# 53857  N#Cc1ccc(CN2CCC(NC(=O)c3ccc(C(=O)N4CCC(C(F)c5c...
# 53858  COc1nc2ccc(Br)cc2cc1[C@@H](c1ccccc1)[C@@](O)(C...
#
#                           INCHIKEY
# 0      DNXHEGUUPJUMQT-CBZIJGRNSA-N
# 1      UVYVLBIGDKGWPX-YCCXZQINSA-N
# 3      WSJWUIDLGZAXID-UHFFFAOYSA-N
# 4      WSJWUIDLGZAXID-UHFFFAOYSA-N
# 5      QWCJHSGMANYXCW-UHFFFAOYSA-N
# ...                            ...
# 53851  CHNHYOHQPDHUOP-QYOOZWMWSA-N
# 53852  RKMXNTQXGVOORY-UHFFFAOYSA-N
# 53853  HSWCABTYQVCNCT-UHFFFAOYSA-N
# 53857  FJNHSBVZTQFKEF-UHFFFAOYSA-N
# 53858  QUIJNHUBAXPXFS-XLJNKUFUSA-N
#
# [43977 rows x 49 columns]

# %%
better_units = better_assay[better_assay['Standard Units'] == "nM"]
better_units
# Out:
#       Molecule ChEMBL ID   Molecule Name  Molecule Max Phase  \
# 3           CHEMBL168471             NaN                 NaN
# 4           CHEMBL168471             NaN                 NaN
# 5             CHEMBL1109  SULFAPHENAZOLE                 4.0
# 6             CHEMBL8706      CLORGILINE                 2.0
# 7          CHEMBL1600586             NaN                 NaN
# ...                  ...             ...                 ...
# 53850      CHEMBL5287462             NaN                 NaN
# 53851      CHEMBL5175220             NaN                 NaN
# 53852      CHEMBL5267910             NaN                 NaN
# 53853      CHEMBL4846941             NaN                 NaN
# 53858       CHEMBL376488     BEDAQUILINE                 4.0
#
#        Molecular Weight  #RO5 Violations  AlogP Compound Key  \
# 3                372.46              0.0   1.86            8
# 4                372.46              0.0   1.86            8
# 5                314.37              0.0   2.26  SID26747662
# 6                272.18              0.0   3.33  SID11111452
# 7                417.46              0.0   0.36  SID26751076
# ...                 ...              ...    ...          ...
# 53850            458.62              0.0   4.62          12d
# 53851            573.75              2.0   5.40           26
# 53852            483.59              0.0   4.56           42
# 53853            570.47              2.0   8.05            8
# 53858            555.52              2.0   7.13  Bedaquiline
#
#                                                   Smiles Standard Type  \
# 3      CC(C)C[C@H](C=O)NC(=O)[C@@H](NS(=O)(=O)c1ccc(F...          IC50
# 4      CC(C)C[C@H](C=O)NC(=O)[C@@H](NS(=O)(=O)c1ccc(F...          IC50
# 5                  Nc1ccc(S(=O)(=O)Nc2ccnn2-c2ccccc2)cc1       Potency
# 6                             C#CCN(C)CCCOc1ccc(Cl)cc1Cl       Potency
# 7      COC(=O)C/C=C\[C@@H](C)[C@@H](/C=N\OC[C@@H](O)[...       Potency
# ...                                                  ...           ...
# 53850  CN1CCC[C@H](N(c2cc(C#CC(C)(C)C)sc2C(=O)O)C(=O)...          IC50
# 53851  CC(=O)N1CCc2c(nc(C)n2[C@@H]2C[C@H]3CC[C@@H](C2...          IC50
# 53852  O=C(Nc1ccc(-c2ccc(F)cn2)cc1)c1cc2sc(NCCN3CCOCC...          IC50
# 53853  O=C(O)c1cc(F)c2nc(N3CCC4(C=C(c5c(-c6c(Cl)cccc6...          IC50
# 53858  COc1nc2ccc(Br)cc2cc1[C@@H](c1ccccc1)[C@@](O)(C...          IC50
#
#       Standard Relation  ...  Source ID     Source Description  \
# 3                   '='  ...          1  Scientific Literature
# 4                   '='  ...          1  Scientific Literature
# 5                   '='  ...          7      PubChem BioAssays
# 6                   '='  ...          7      PubChem BioAssays
# 7                   '='  ...          7      PubChem BioAssays
# ...                 ...  ...        ...                    ...
# 53850               '>'  ...          1  Scientific Literature
# 53851               '>'  ...          1  Scientific Literature
# 53852               '='  ...          1  Scientific Literature
# 53853               '='  ...          1  Scientific Literature
# 53858               '>'  ...          1  Scientific Literature
#
#            Document Journal Document Year Cell ChEMBL ID        Properties  \
# 3                J Med Chem        2003.0            NaN               NaN
# 4                J Med Chem        2003.0            NaN               NaN
# 5                       NaN           NaN            NaN               NaN
# 6                       NaN           NaN            NaN               NaN
# 7                       NaN           NaN            NaN               NaN
# ...                     ...           ...            ...               ...
# 53850     ACS Med Chem Lett        2017.0            NaN  TIME = 0.1667 hr
# 53851            J Med Chem        2022.0            NaN               NaN
# 53852       Bioorg Med Chem        2020.0            NaN               NaN
# 53853     ACS Med Chem Lett        2021.0            NaN    TIME = 0.25 hr
# 53858  Bioorg Med Chem Lett        2022.0            NaN               NaN
#
#        Action Type  Standard Text Value  \
# 3              NaN                  NaN
# 4              NaN                  NaN
# 5              NaN                  NaN
# 6              NaN                  NaN
# 7              NaN                  NaN
# ...            ...                  ...
# 53850          NaN                  NaN
# 53851          NaN                  NaN
# 53852    INHIBITOR                  NaN
# 53853    INHIBITOR                  NaN
# 53858          NaN                  NaN
#
#                                         CANONICAL_SMILES  \
# 3        CC(C)CC(C=O)NC(=O)C(NS(=O)(=O)c1ccc(F)cc1)C(C)C
# 4        CC(C)CC(C=O)NC(=O)C(NS(=O)(=O)c1ccc(F)cc1)C(C)C
# 5                  Nc1ccc(S(=O)(=O)Nc2ccnn2-c2ccccc2)cc1
# 6                             C#CCN(C)CCCOc1ccc(Cl)cc1Cl
# 7      COC(=O)C/C=C\[C@@H](C)[C@@H](/C=N\OC[C@@H](O)[...
# ...                                                  ...
# 53850  CC1CCC(C(=O)N(c2cc(C#CC(C)(C)C)sc2C(=O)O)C2CCC...
# 53851  CC(=O)N1CCc2c(nc(C)n2[C@@H]2C[C@H]3CC[C@@H](C2...
# 53852  O=C(Nc1ccc(-c2ccc(F)cn2)cc1)c1cc2sc(NCCN3CCOCC...
# 53853  O=C(O)c1cc(F)c2nc(N3CCC4(C=C(c5c(-c6c(Cl)cccc6...
# 53858  COc1nc2ccc(Br)cc2cc1[C@@H](c1ccccc1)[C@@](O)(C...
#
#                           INCHIKEY
# 3      WSJWUIDLGZAXID-UHFFFAOYSA-N
# 4      WSJWUIDLGZAXID-UHFFFAOYSA-N
# 5      QWCJHSGMANYXCW-UHFFFAOYSA-N
# 6      BTFHLQRNAMSNLC-UHFFFAOYSA-N
# 7      JOOFLNOPMODRHL-PCZNLFPRSA-N
# ...                            ...
# 53850  MGEVBIDQMYTWFL-UHFFFAOYSA-N
# 53851  CHNHYOHQPDHUOP-QYOOZWMWSA-N
# 53852  RKMXNTQXGVOORY-UHFFFAOYSA-N
# 53853  HSWCABTYQVCNCT-UHFFFAOYSA-N
# 53858  QUIJNHUBAXPXFS-XLJNKUFUSA-N
#
# [33454 rows x 49 columns]

# %%
num_compounds_per_assay = better_units.groupby("Assay ChEMBL ID")["Molecule ChEMBL ID"].nunique()

# %%
num_compounds_per_assay
# Out:
# Assay ChEMBL ID
# CHEMBL1000505     4
# CHEMBL1000506     4
# CHEMBL1000805    19
# CHEMBL1001513    20
# CHEMBL1002238     5
#                  ..
# CHEMBL996822      6
# CHEMBL997024      1
# CHEMBL998722      1
# CHEMBL999263      3
# CHEMBL999389      8
# Name: Molecule ChEMBL ID, Length: 2500, dtype: int64

# %%
num_compounds_per_assay_df = pd.DataFrame(num_compounds_per_assay)
num_compounds_per_assay_df.rename(columns={"Molecule ChEMBL ID": "molecule_count"}, inplace=True)
num_compounds_per_assay_df
# Out:
#                  molecule_count
# Assay ChEMBL ID
# CHEMBL1000505                 4
# CHEMBL1000506                 4
# CHEMBL1000805                19
# CHEMBL1001513                20
# CHEMBL1002238                 5
# ...                         ...
# CHEMBL996822                  6
# CHEMBL997024                  1
# CHEMBL998722                  1
# CHEMBL999263                  3
# CHEMBL999389                  8
#
# [2500 rows x 1 columns]

# %%
combined = better_units.join(num_compounds_per_assay_df, on="Assay ChEMBL ID")
combined["molecule_count"].unique()
# Out:
# array([   1, 6472,   15,    2,   16,   19,   17,    6,   12,    3,   14,
#           7,   25,   42,    8,   28,   22,    4,  187,   18,    5,   10,
#          29,   21,   32,   46,   20,   13,   51,   30,   33,   11,   24,
#          38,   26,   35,    9,   43,   85, 8635,   34,   39,   23,   27,
#          48,   64,  165,   47,   37,   65])

# %%
N = 10 # assays must have more than N compounds in them

# %%
more_than_N_compounds = combined[combined["molecule_count"] > N]

# %%
more_than_N_compounds
# Out:
#       Molecule ChEMBL ID   Molecule Name  Molecule Max Phase  \
# 5             CHEMBL1109  SULFAPHENAZOLE                 4.0
# 6             CHEMBL8706      CLORGILINE                 2.0
# 7          CHEMBL1600586             NaN                 NaN
# 8          CHEMBL1417358             NaN                 NaN
# 9          CHEMBL1357941             NaN                 NaN
# ...                  ...             ...                 ...
# 53821      CHEMBL4594441   IFIDANCITINIB                 2.0
# 53834      CHEMBL5092411             NaN                 NaN
# 53835      CHEMBL5074449             NaN                 NaN
# 53844      CHEMBL5080846             NaN                 NaN
# 53846      CHEMBL5202370             NaN                 NaN
#
#        Molecular Weight  #RO5 Violations  AlogP Compound Key  \
# 5                314.37              0.0   2.26  SID26747662
# 6                272.18              0.0   3.33  SID11111452
# 7                417.46              0.0   0.36  SID26751076
# 8                486.57              0.0   4.19  SID17385348
# 9                522.56              2.0   5.16  SID11114057
# ...                 ...              ...    ...          ...
# 53821            395.39              0.0   4.16           33
# 53834            527.00              2.0   7.45           25
# 53835            510.82              1.0   4.65          64i
# 53844            582.73              2.0   6.08           17
# 53846            407.46              1.0   5.01           28
#
#                                                   Smiles Standard Type  \
# 5                  Nc1ccc(S(=O)(=O)Nc2ccnn2-c2ccccc2)cc1       Potency
# 6                             C#CCN(C)CCCOc1ccc(Cl)cc1Cl       Potency
# 7      COC(=O)C/C=C\[C@@H](C)[C@@H](/C=N\OC[C@@H](O)[...       Potency
# 8      COC(=O)[C@H](Cc1ccccc1)NC(=O)[C@H]1C[C@@H]1[C@...       Potency
# 9      CCOC(=O)C1=C(C)NC(c2ccccc2)=C(C(=O)OCc2ccc([N+...       Potency
# ...                                                  ...           ...
# 53821  COc1cc(Nc2ncc(C)c(Nc3ccc4oc(=O)[nH]c4c3)n2)cc(...          IC50
# 53834  CC1(n2cnc3cnc4cc(F)c(-c5ccc(Oc6ncccn6)cc5Cl)cc...          IC50
# 53835  C[C@@]1(c2cc(NC(=O)c3ncc(OC(F)F)cc3Cl)ccc2F)CO...          IC50
# 53844  C#CCCCCCCCCCCCCCCOCCCOP(=O)(O)CO[C@H](C)Cn1cnc...          IC50
# 53846  COC(=O)Nc1cc(-c2ccc(OC[C@@](C)(N)CC(C)C)c(C(F)...          IC50
#
#       Standard Relation  ...     Source Description   Document Journal  \
# 5                   '='  ...      PubChem BioAssays                NaN
# 6                   '='  ...      PubChem BioAssays                NaN
# 7                   '='  ...      PubChem BioAssays                NaN
# 8                   '='  ...      PubChem BioAssays                NaN
# 9                   '='  ...      PubChem BioAssays                NaN
# ...                 ...  ...                    ...                ...
# 53821               '>'  ...  Scientific Literature  ACS Med Chem Lett
# 53834               '<'  ...  Scientific Literature         J Med Chem
# 53835               '='  ...  Scientific Literature         J Med Chem
# 53844               '>'  ...  Scientific Literature         J Med Chem
# 53846               '>'  ...  Scientific Literature         J Med Chem
#
#        Document Year Cell ChEMBL ID        Properties Action Type  \
# 5                NaN            NaN               NaN         NaN
# 6                NaN            NaN               NaN         NaN
# 7                NaN            NaN               NaN         NaN
# 8                NaN            NaN               NaN         NaN
# 9                NaN            NaN               NaN         NaN
# ...              ...            ...               ...         ...
# 53821         2022.0            NaN               NaN         NaN
# 53834         2022.0            NaN               NaN   INHIBITOR
# 53835         2021.0            NaN  TIME = 0.1667 hr   INHIBITOR
# 53844         2021.0            NaN     TIME = 0.5 hr         NaN
# 53846         2022.0            NaN  TIME = 0.1667 hr         NaN
#
#        Standard Text Value                                   CANONICAL_SMILES  \
# 5                      NaN              Nc1ccc(S(=O)(=O)Nc2ccnn2-c2ccccc2)cc1
# 6                      NaN                         C#CCN(C)CCCOc1ccc(Cl)cc1Cl
# 7                      NaN  COC(=O)C/C=C\[C@@H](C)[C@@H](/C=N\OC[C@@H](O)[...
# 8                      NaN  COC(=O)C(Cc1ccccc1)NC(=O)C1C[C@@H]1[C@H](NC(=O...
# 9                      NaN  CCOC(=O)C1=C(C)N=C(c2ccccc2)C(C(=O)OCc2ccc([N+...
# ...                    ...                                                ...
# 53821                  NaN  COc1cc(Nc2ncc(C)c(Nc3ccc4oc(=O)[nH]c4c3)n2)cc(...
# 53834                  NaN  CC1(n2cnc3cnc4cc(F)c(-c5ccc(Oc6ncccn6)cc5Cl)cc...
# 53835                  NaN  C[C@@]1(c2cc(NC(=O)c3ncc(OC(F)F)cc3Cl)ccc2F)CO...
# 53844                  NaN  C#CCCCCCCCCCCCCCCOCCCOP(=O)(O)CO[C@H](C)Cn1cnc...
# 53846                  NaN  COC(=O)Nc1cc(-c2ccc(OC[C@@](C)(N)CC(C)C)c(C(F)...
#
#                           INCHIKEY  molecule_count
# 5      QWCJHSGMANYXCW-UHFFFAOYSA-N            6472
# 6      BTFHLQRNAMSNLC-UHFFFAOYSA-N            6472
# 7      JOOFLNOPMODRHL-PCZNLFPRSA-N            6472
# 8      OABRKEQNGZWBBC-LKIFIEJRSA-N            6472
# 9      LRTNJIWAQJAWGO-HSLSYKTRSA-N            6472
# ...                            ...             ...
# 53821  OYFMQDVLFYKOPZ-UHFFFAOYSA-N              11
# 53834  PWQUPCKLWZWJNL-UHFFFAOYSA-N              13
# 53835  WAZXJCCRJQZNHV-RBUKOAKNSA-N              12
# 53844  CRUTYLIWSTWAIE-RUZDIDTESA-N              16
# 53846  FXQJMZONPDKEJC-NRFANRHFSA-N              48
#
# [28157 rows x 50 columns]

# %%
more_than_N_compounds.INCHIKEY = more_than_N_compounds.INCHIKEY.astype(str)
# Out:
# /tmp/ipykernel_263338/3449044069.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   more_than_N_compounds.INCHIKEY = more_than_N_compounds.INCHIKEY.astype(str)

# %%
sns.histplot(data=more_than_N_compounds, x="pChEMBL Value", hue="Assay Type", kde=True)
# Out:
# <Axes: xlabel='pChEMBL Value', ylabel='Count'>

# %%
sns.histplot(data=more_than_N_compounds, x="Molecular Weight",  kde=True)
# Out:
# <Axes: xlabel='Molecular Weight', ylabel='Count'>

# %%
assays = more_than_N_compounds["Assay ChEMBL ID"].nunique()

# %%
assays
# Out:
# 264

# %%
more_than_N_compounds["Molecule ChEMBL ID"].nunique()
# Out:
# 15791

# %%
num_assays_per_compound_df = more_than_N_compounds.groupby(["INCHIKEY"])["Assay ChEMBL ID"].size().reset_index(name="assay_count")
num_assays_per_compound_df = num_assays_per_compound_df.set_index("INCHIKEY")
num_assays_per_compound_df
# Out:
#                              assay_count
# INCHIKEY
# AAALVYBICLMAMA-UHFFFAOYSA-N            2
# AAASNKNLMQBKFV-UHFFFAOYSA-N            2
# AABYLPRACHMDSN-BIWBPYCESA-N            3
# AABYLPRACHMDSN-REETXPBOSA-N            3
# AACPHNFEDMXRPQ-UHFFFAOYSA-N            2
# ...                                  ...
# ZZVXVMRMJNDKKA-UHFFFAOYSA-N            1
# ZZWKZQDOSJAGGF-WLNFFEQUSA-N            2
# ZZXHZVKGUYRZKM-UHFFFAOYSA-N            1
# ZZYHXFCSTOMZNZ-UHFFFAOYSA-N            1
# ZZZRUAITSXLWBH-FCNPUZOYSA-N            2
#
# [15665 rows x 1 columns]

# %%
sns.countplot(data=num_assays_per_compound_df, x="assay_count")
# Out:
# <Axes: xlabel='assay_count', ylabel='count'>

# %%
combined_2 = more_than_N_compounds.join(num_assays_per_compound_df, on="INCHIKEY")

# %%
combined_2.sort_values("assay_count", ascending=False, inplace=True)
combined_2["assay_count"] = combined_2["assay_count"].astype(int)

# %% [markdown]
# # Aggregate activity

# %%
compound_grouped_mean = combined_2.groupby("INCHIKEY")["pChEMBL Value"].mean()
compound_grouped_mean.reset_index()
# Out:
#                           INCHIKEY  pChEMBL Value
# 0      AAALVYBICLMAMA-UHFFFAOYSA-N           5.80
# 1      AAASNKNLMQBKFV-UHFFFAOYSA-N           5.60
# 2      AABYLPRACHMDSN-BIWBPYCESA-N           5.60
# 3      AABYLPRACHMDSN-REETXPBOSA-N           5.60
# 4      AACPHNFEDMXRPQ-UHFFFAOYSA-N            NaN
# ...                            ...            ...
# 15660  ZZVXVMRMJNDKKA-UHFFFAOYSA-N           6.45
# 15661  ZZWKZQDOSJAGGF-WLNFFEQUSA-N           5.40
# 15662  ZZXHZVKGUYRZKM-UHFFFAOYSA-N           4.95
# 15663  ZZYHXFCSTOMZNZ-UHFFFAOYSA-N           5.82
# 15664  ZZZRUAITSXLWBH-FCNPUZOYSA-N           6.20
#
# [15665 rows x 2 columns]

# %%
sns.histplot(data=compound_grouped_mean.reset_index(name="pChEMBL mean"),x="pChEMBL mean")
# Out:
# <Axes: xlabel='pChEMBL mean', ylabel='Count'>

# %%
# join 
cgm = compound_grouped_mean.reset_index(name="pChEMBL mean")
cgm = cgm.set_index("INCHIKEY")
combined_3 = combined_2.join(cgm, on="INCHIKEY")

# %%
compound_grouped_std = combined_2.groupby("INCHIKEY")["pChEMBL Value"].std()
compound_grouped_std.reset_index()
# Out:
#                           INCHIKEY  pChEMBL Value
# 0      AAALVYBICLMAMA-UHFFFAOYSA-N            0.0
# 1      AAASNKNLMQBKFV-UHFFFAOYSA-N            0.0
# 2      AABYLPRACHMDSN-BIWBPYCESA-N            0.0
# 3      AABYLPRACHMDSN-REETXPBOSA-N            0.0
# 4      AACPHNFEDMXRPQ-UHFFFAOYSA-N            NaN
# ...                            ...            ...
# 15660  ZZVXVMRMJNDKKA-UHFFFAOYSA-N            NaN
# 15661  ZZWKZQDOSJAGGF-WLNFFEQUSA-N            0.0
# 15662  ZZXHZVKGUYRZKM-UHFFFAOYSA-N            NaN
# 15663  ZZYHXFCSTOMZNZ-UHFFFAOYSA-N            NaN
# 15664  ZZZRUAITSXLWBH-FCNPUZOYSA-N            0.0
#
# [15665 rows x 2 columns]

# %%
sns.histplot(data=compound_grouped_std.reset_index(name="pChEMBL stdev"),x="pChEMBL stdev")
# Out:
# <Axes: xlabel='pChEMBL stdev', ylabel='Count'>

# %%
cgstd = compound_grouped_std.reset_index(name="pChEMBL std")
cgstd = cgstd.set_index("INCHIKEY")
combined_4 =  combined_3.join(cgstd, on="INCHIKEY")

# %%
combined_4
# Out:
#       Molecule ChEMBL ID      Molecule Name  Molecule Max Phase  \
# 1465        CHEMBL157101       KETOCONAZOLE                 4.0
# 36792      CHEMBL1474730                NaN                 NaN
# 2920       CHEMBL1169388                NaN                 NaN
# 38232          CHEMBL104       CLOTRIMAZOLE                 4.0
# 8287           CHEMBL786  TAMOXIFEN CITRATE                 4.0
# ...                  ...                ...                 ...
# 35644      CHEMBL1343900                NaN                 NaN
# 35645      CHEMBL1403617                NaN                 NaN
# 35646      CHEMBL1447245                NaN                 NaN
# 35652      CHEMBL1517652                NaN                 NaN
# 35667       CHEMBL562285                NaN                 NaN
#
#        Molecular Weight  #RO5 Violations  AlogP  Compound Key  \
# 1465             531.44              1.0   4.21  ketoconazole
# 36792            271.27              0.0   1.16   SID26748206
# 2920             309.33              0.0   4.44   SID11112803
# 38232            344.85              1.0   5.38  Clotrimazole
# 8287             563.65              1.0   6.00   SID17389724
# ...                 ...              ...    ...           ...
# 35644            421.50              0.0   4.19    SID4243947
# 35645            378.45              1.0   5.45   SID17415717
# 35646            342.47              0.0   4.84   SID14741980
# 35652            437.59              0.0   4.09   SID14741962
# 35667            548.61              2.0   5.53            27
#
#                                                   Smiles Standard Type  \
# 1465   CC(=O)N1CCN(c2ccc(OCC3COC(Cn4ccnc4)(c4ccc(Cl)c...          IC50
# 36792           CCC1C(=O)OC[C@H]1Cc1cncn1C.O=[N+]([O-])O       Potency
# 2920              CNCC[C@H](Oc1ccc(C(F)(F)F)cc1)c1ccccc1       Potency
# 38232             Clc1ccccc1C(c1ccccc1)(c1ccccc1)n1ccnc1          IC50
# 8287   CC/C(=C(\c1ccccc1)c1ccc(OCCN(C)C)cc1)c1ccccc1....          AC50
# ...                                                  ...           ...
# 35644  COc1cccc(N2C(=O)C(CC(=O)Nc3ccccc3)N(C3CCCCC3)C...          AC50
# 35645  Cc1cc(CSc2ccccc2)ccc1NC(=O)c1cccc([N+](=O)[O-])c1          AC50
# 35646          O=c1c2c(-c3cccs3)csc2[nH]c(=S)n1-c1ccccc1          AC50
# 35652  CC1(C)SC(=S)N(Cc2ccc3c(c2)OCO3)C1N(O)C(=O)NC1C...          AC50
# 35667  O=C(NC1CCN(Cc2ccn(-c3ccc(C(F)(F)F)cc3)c2)CC1)N...          IC50
#
#       Standard Relation  ...  Cell ChEMBL ID Properties  Action Type  \
# 1465                '='  ...             NaN        NaN          NaN
# 36792               '='  ...             NaN        NaN          NaN
# 2920                '='  ...             NaN        NaN          NaN
# 38232               '='  ...             NaN        NaN          NaN
# 8287                '='  ...             NaN        NaN          NaN
# ...                 ...  ...             ...        ...          ...
# 35644               '='  ...             NaN        NaN          NaN
# 35645               '='  ...             NaN        NaN          NaN
# 35646               '='  ...             NaN        NaN          NaN
# 35652               '='  ...             NaN        NaN          NaN
# 35667               '='  ...             NaN        NaN          NaN
#
#       Standard Text Value                                   CANONICAL_SMILES  \
# 1465                  NaN  CC(=O)N1CCN(c2ccc(OCC3COC(Cn4ccnc4)(c4ccc(Cl)c...
# 36792                 NaN                         CCC1C(=O)OC[C@H]1Cc1cncn1C
# 2920                  NaN             CNCC[C@H](Oc1ccc(C(F)(F)F)cc1)c1ccccc1
# 38232                 NaN             Clc1ccccc1C(c1ccccc1)(c1ccccc1)n1ccnc1
# 8287                  NaN      CC/C(=C(\c1ccccc1)c1ccc(OCCN(C)C)cc1)c1ccccc1
# ...                   ...                                                ...
# 35644                 NaN  COc1cccc(-n2c(O)c(CC(=O)Nc3ccccc3)n(C3CCCCC3)c...
# 35645                 NaN  Cc1cc(CSc2ccccc2)ccc1NC(=O)c1cccc([N+](=O)[O-])c1
# 35646                 NaN          O=c1c2c(-c3cccs3)csc2[nH]c(=S)n1-c1ccccc1
# 35652                 NaN  CC1(C)SC(=S)N(Cc2ccc3c(c2)OCO3)C1N(O)C(=O)NC1C...
# 35667                 NaN  O=C(NC1CCN(Cc2ccn(-c3ccc(C(F)(F)F)cc3)c2)CC1)N...
#
#                           INCHIKEY  molecule_count  assay_count  pChEMBL mean  \
# 1465   XMAYWYJOQHXEEK-UHFFFAOYSA-N              28           21      7.013500
# 36792  QCHFTSOMWOSFHM-HNHGDDPOSA-N            6472           17      5.052941
# 2920   RTHCYVBBDHJXIQ-INIZCTEOSA-N            6472           15      4.980000
# 38232  VNFPBHJOKIVQEB-UHFFFAOYSA-N              28           14      7.237692
# 8287   NKANXQFJJICGDU-QPLCGJKRSA-N            8635           14      4.846154
# ...                            ...             ...          ...           ...
# 35644  ZMHMFTIGSAREEO-UHFFFAOYSA-N            8635            1      5.300000
# 35645  CCTDFOABYYEBJZ-UHFFFAOYSA-N            8635            1      4.950000
# 35646  QPGZFTYZRQKKPE-UHFFFAOYSA-N            8635            1      4.850000
# 35652  OLZNOLMCUCLSGY-UHFFFAOYSA-N            8635            1      5.950000
# 35667  SCNLJQQVOVIBKB-UHFFFAOYSA-N              11            1      5.490000
#
#        pChEMBL std
# 1465      0.618796
# 36792     0.285302
# 2920      0.248424
# 38232     0.358798
# 8287      0.357341
# ...            ...
# 35644          NaN
# 35645          NaN
# 35646          NaN
# 35652          NaN
# 35667          NaN
#
# [15665 rows x 53 columns]

# %%
combined_4.drop_duplicates(subset="INCHIKEY", inplace=True)

# %%
combined_4
# Out:
#       Molecule ChEMBL ID      Molecule Name  Molecule Max Phase  \
# 1465        CHEMBL157101       KETOCONAZOLE                 4.0
# 36792      CHEMBL1474730                NaN                 NaN
# 2920       CHEMBL1169388                NaN                 NaN
# 38232          CHEMBL104       CLOTRIMAZOLE                 4.0
# 8287           CHEMBL786  TAMOXIFEN CITRATE                 4.0
# ...                  ...                ...                 ...
# 35644      CHEMBL1343900                NaN                 NaN
# 35645      CHEMBL1403617                NaN                 NaN
# 35646      CHEMBL1447245                NaN                 NaN
# 35652      CHEMBL1517652                NaN                 NaN
# 35667       CHEMBL562285                NaN                 NaN
#
#        Molecular Weight  #RO5 Violations  AlogP  Compound Key  \
# 1465             531.44              1.0   4.21  ketoconazole
# 36792            271.27              0.0   1.16   SID26748206
# 2920             309.33              0.0   4.44   SID11112803
# 38232            344.85              1.0   5.38  Clotrimazole
# 8287             563.65              1.0   6.00   SID17389724
# ...                 ...              ...    ...           ...
# 35644            421.50              0.0   4.19    SID4243947
# 35645            378.45              1.0   5.45   SID17415717
# 35646            342.47              0.0   4.84   SID14741980
# 35652            437.59              0.0   4.09   SID14741962
# 35667            548.61              2.0   5.53            27
#
#                                                   Smiles Standard Type  \
# 1465   CC(=O)N1CCN(c2ccc(OCC3COC(Cn4ccnc4)(c4ccc(Cl)c...          IC50
# 36792           CCC1C(=O)OC[C@H]1Cc1cncn1C.O=[N+]([O-])O       Potency
# 2920              CNCC[C@H](Oc1ccc(C(F)(F)F)cc1)c1ccccc1       Potency
# 38232             Clc1ccccc1C(c1ccccc1)(c1ccccc1)n1ccnc1          IC50
# 8287   CC/C(=C(\c1ccccc1)c1ccc(OCCN(C)C)cc1)c1ccccc1....          AC50
# ...                                                  ...           ...
# 35644  COc1cccc(N2C(=O)C(CC(=O)Nc3ccccc3)N(C3CCCCC3)C...          AC50
# 35645  Cc1cc(CSc2ccccc2)ccc1NC(=O)c1cccc([N+](=O)[O-])c1          AC50
# 35646          O=c1c2c(-c3cccs3)csc2[nH]c(=S)n1-c1ccccc1          AC50
# 35652  CC1(C)SC(=S)N(Cc2ccc3c(c2)OCO3)C1N(O)C(=O)NC1C...          AC50
# 35667  O=C(NC1CCN(Cc2ccn(-c3ccc(C(F)(F)F)cc3)c2)CC1)N...          IC50
#
#       Standard Relation  ...  Cell ChEMBL ID Properties  Action Type  \
# 1465                '='  ...             NaN        NaN          NaN
# 36792               '='  ...             NaN        NaN          NaN
# 2920                '='  ...             NaN        NaN          NaN
# 38232               '='  ...             NaN        NaN          NaN
# 8287                '='  ...             NaN        NaN          NaN
# ...                 ...  ...             ...        ...          ...
# 35644               '='  ...             NaN        NaN          NaN
# 35645               '='  ...             NaN        NaN          NaN
# 35646               '='  ...             NaN        NaN          NaN
# 35652               '='  ...             NaN        NaN          NaN
# 35667               '='  ...             NaN        NaN          NaN
#
#       Standard Text Value                                   CANONICAL_SMILES  \
# 1465                  NaN  CC(=O)N1CCN(c2ccc(OCC3COC(Cn4ccnc4)(c4ccc(Cl)c...
# 36792                 NaN                         CCC1C(=O)OC[C@H]1Cc1cncn1C
# 2920                  NaN             CNCC[C@H](Oc1ccc(C(F)(F)F)cc1)c1ccccc1
# 38232                 NaN             Clc1ccccc1C(c1ccccc1)(c1ccccc1)n1ccnc1
# 8287                  NaN      CC/C(=C(\c1ccccc1)c1ccc(OCCN(C)C)cc1)c1ccccc1
# ...                   ...                                                ...
# 35644                 NaN  COc1cccc(-n2c(O)c(CC(=O)Nc3ccccc3)n(C3CCCCC3)c...
# 35645                 NaN  Cc1cc(CSc2ccccc2)ccc1NC(=O)c1cccc([N+](=O)[O-])c1
# 35646                 NaN          O=c1c2c(-c3cccs3)csc2[nH]c(=S)n1-c1ccccc1
# 35652                 NaN  CC1(C)SC(=S)N(Cc2ccc3c(c2)OCO3)C1N(O)C(=O)NC1C...
# 35667                 NaN  O=C(NC1CCN(Cc2ccn(-c3ccc(C(F)(F)F)cc3)c2)CC1)N...
#
#                           INCHIKEY  molecule_count  assay_count  pChEMBL mean  \
# 1465   XMAYWYJOQHXEEK-UHFFFAOYSA-N              28           21      7.013500
# 36792  QCHFTSOMWOSFHM-HNHGDDPOSA-N            6472           17      5.052941
# 2920   RTHCYVBBDHJXIQ-INIZCTEOSA-N            6472           15      4.980000
# 38232  VNFPBHJOKIVQEB-UHFFFAOYSA-N              28           14      7.237692
# 8287   NKANXQFJJICGDU-QPLCGJKRSA-N            8635           14      4.846154
# ...                            ...             ...          ...           ...
# 35644  ZMHMFTIGSAREEO-UHFFFAOYSA-N            8635            1      5.300000
# 35645  CCTDFOABYYEBJZ-UHFFFAOYSA-N            8635            1      4.950000
# 35646  QPGZFTYZRQKKPE-UHFFFAOYSA-N            8635            1      4.850000
# 35652  OLZNOLMCUCLSGY-UHFFFAOYSA-N            8635            1      5.950000
# 35667  SCNLJQQVOVIBKB-UHFFFAOYSA-N              11            1      5.490000
#
#        pChEMBL std
# 1465      0.618796
# 36792     0.285302
# 2920      0.248424
# 38232     0.358798
# 8287      0.357341
# ...            ...
# 35644          NaN
# 35645          NaN
# 35646          NaN
# 35652          NaN
# 35667          NaN
#
# [15665 rows x 53 columns]

# %%
L = 3
more_than_eq_L_assay = combined_4[combined_4["assay_count"] >= L]

# %%
more_than_eq_L_assay.to_csv("./ChEMBL/chembl_processed.csv", index=False)
