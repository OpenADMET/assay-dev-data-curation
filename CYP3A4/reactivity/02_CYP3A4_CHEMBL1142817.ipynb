# %%
import pandas as pd
from rdkit import Chem
import seaborn as sns
from tqdm import tqdm
import numpy as np

# %%
tqdm.pandas()

# %%
df = pd.read_csv("./ChEMBL_doc_CHEMBL1142817/CHEMBL1142817.csv", sep=";")
df
# Out:
#    Molecule ChEMBL ID           Molecule Name  Molecule Max Phase  \
# 0           CHEMBL839               CARTEOLOL                 4.0
# 1          CHEMBL1423                PIMOZIDE                 4.0
# 2           CHEMBL114              SAQUINAVIR                 4.0
# 3        CHEMBL389621          HYDROCORTISONE                 4.0
# 4        CHEMBL328250              ADINAZOLAM                 2.0
# 5           CHEMBL108           CARBAMAZEPINE                 4.0
# 6           CHEMBL629           AMITRIPTYLINE                 4.0
# 7           CHEMBL549              CITALOPRAM                 4.0
# 8         CHEMBL24646              PIMOBENDAN                 2.0
# 9           CHEMBL115               INDINAVIR                 4.0
# 10          CHEMBL481              IRINOTECAN                 4.0
# 11      CHEMBL1276308            MIFEPRISTONE                 4.0
# 12         CHEMBL1064             SIMVASTATIN                 4.0
# 13          CHEMBL107              COLCHICINE                 4.0
# 14           CHEMBL11              IMIPRAMINE                 4.0
# 15       CHEMBL327624                     NaN                 NaN
# 16         CHEMBL1503              OMEPRAZOLE                 4.0
# 17       CHEMBL185878  TAUROCHENODEOXYCHOLATE                 NaN
# 18       CHEMBL428647              PACLITAXEL                 4.0
# 19       CHEMBL346231    BROMODICHLOROMETHANE                 NaN
# 20         CHEMBL1741          CLARITHROMYCIN                 4.0
# 21       CHEMBL238071               VINDESINE                 4.0
# 22       CHEMBL362153             SENECIONINE                 NaN
# 23          CHEMBL633              AMIODARONE                 4.0
# 24      CHEMBL3545252               DOCETAXEL                 4.0
# 25      CHEMBL1908373             ONAPRISTONE                 4.0
# 26          CHEMBL159             VINBLASTINE                 4.0
# 27          CHEMBL160            CYCLOSPORINE                 4.0
# 28       CHEMBL444633               RIFABUTIN                 4.0
# 29        CHEMBL17157             TERFENADINE                 4.0
# 30          CHEMBL532            ERYTHROMYCIN                 4.0
# 31           CHEMBL23               DILTIAZEM                 4.0
# 32           CHEMBL83               TAMOXIFEN                 4.0
# 33           CHEMBL42               CLOZAPINE                 4.0
# 34         CHEMBL1480              FELODIPINE                 4.0
# 35       CHEMBL269732    TACROLIMUS ANHYDROUS                 4.0
# 36           CHEMBL93                ZILEUTON                 4.0
# 37      CHEMBL1908329            LILOPRISTONE                 2.0
# 38       CHEMBL167395           1-NITROPYRENE                 NaN
# 39      CHEMBL1908330      TIRILAZAD MESYLATE                 NaN
# 40         CHEMBL1371           CHLORZOXAZONE                 4.0
# 41         CHEMBL1043                 DAPSONE                 4.0
# 42        CHEMBL44657               ETOPOSIDE                 4.0
# 43      CHEMBL2111147              ZATOSETRON                -1.0
# 44        CHEMBL13280           FLUNITRAZEPAM                 4.0
# 45          CHEMBL637             VENLAFAXINE                 4.0
# 46          CHEMBL170                 QUININE                 4.0
# 47          CHEMBL163               RITONAVIR                 4.0
# 48         CHEMBL1098             BUPIVACAINE                 4.0
# 49       CHEMBL187628                     NaN                 NaN
# 50          CHEMBL413               SIROLIMUS                 4.0
# 51          CHEMBL596                FENTANYL                 4.0
# 52       CHEMBL132991              TAZOFELONE                 2.0
# 53          CHEMBL408            TROGLITAZONE                 4.0
# 54          CHEMBL661              ALPRAZOLAM                 4.0
# 55       CHEMBL191528          ETHOXYCOUMARIN                 NaN
# 56           CHEMBL54             HALOPERIDOL                 4.0
# 57       CHEMBL384467           DEXAMETHASONE                 4.0
#
#     Molecular Weight  #RO5 Violations  AlogP                Compound Key  \
# 0             292.38              0.0   1.70                   Carteolol
# 1             461.56              1.0   5.86                 SID56422165
# 2             670.86              1.0   3.09                  Saquinavir
# 3             362.47              0.0   1.78                    Cortisol
# 4             351.84              0.0   3.33                  Adinazolam
# 5             236.27              0.0   3.39               Carbamazepine
# 6             277.41              0.0   4.17               Amitriptyline
# 7             324.40              0.0   3.81                  Citalopram
# 8             334.38              0.0   3.10                  Pimobendan
# 9             613.80              1.0   2.87                   Indinavir
# 10            586.69              1.0   4.09                           6
# 11            429.60              1.0   5.41                           1
# 12            418.57              0.0   4.59                 Simvastatin
# 13            399.44              0.0   2.87                  Colchicine
# 14            280.42              0.0   3.88                  Imipramine
# 15            561.70              1.0   3.74                        K 02
# 16            345.42              0.0   2.90                  Omeprazole
# 17            499.71              0.0   3.40  Taurochenodeoxycholic acid
# 18            853.92              2.0   3.74                       Taxol
# 19            163.83              0.0   2.14        Bromodichloromethane
# 20            747.96              2.0   2.44              clarithromycin
# 21            753.94              1.0   2.73                   Vindesine
# 22            335.40              0.0   1.19                 Senecionine
# 23            645.32              2.0   6.94                           2
# 24            861.94              2.0   3.26                    Taxotere
# 25            449.64              1.0   5.16                 Onapristone
# 26            810.99              2.0   3.99                 Vinblastine
# 27           1202.63              NaN    NaN                Cyclosporine
# 28            847.02              2.0   4.62                   Rifabutin
# 29            471.69              1.0   6.45                 Terfenadine
# 30            733.94              2.0   1.79                Erythromycin
# 31            414.53              0.0   3.37                   Diltiazem
# 32            371.52              1.0   6.00                   Tamoxifen
# 33            326.83              0.0   3.72                   Clozapine
# 34            384.26              0.0   3.96                  Felodipine
# 35            804.03              2.0   4.64                  Tacrolimus
# 36            236.30              0.0   2.73                    Zileuton
# 37            447.62              0.0   4.93                Lilopristone
# 38            247.25              0.0   4.49               1-Nitropyrene
# 39            720.98              2.0   5.46          Tirilazad mesylate
# 40            169.57              0.0   1.77               Chlorzoxazone
# 41            248.31              0.0   1.68                     Dapsone
# 42            588.56              2.0   1.34                   Etoposide
# 43            348.87              0.0   3.41                  Zatosetron
# 44            313.29              0.0   2.55               Flunitrazepam
# 45            277.41              0.0   3.04                 Venlafaxine
# 46            324.42              0.0   3.17                     Quinine
# 47            720.96              2.0   5.91                   Ritonavir
# 48            288.44              0.0   3.90                 Bupivacaine
# 49            452.64              1.0   6.11           Ezlopitant alkene
# 50            914.19              3.0   6.18                   Rapamycin
# 51            336.48              0.0   4.14                    Fentanyl
# 52            321.49              0.0   3.72                  Tazofelone
# 53            441.55              0.0   4.37                Troglitazone
# 54            308.77              0.0   3.58                  Alprazolam
# 55            190.20              0.0   2.19              Ethoxycoumarin
# 56            375.87              0.0   4.43                 Haloperidol
# 57            392.47              0.0   1.90               Dexamethasone
#
#                                                Smiles Standard Type  \
# 0                  CC(C)(C)NCC(O)COc1cccc2c1CCC(=O)N2      Log 1/Km
# 1   O=c1[nH]c2ccccc2n1C1CCN(CCCC(c2ccc(F)cc2)c2ccc...      Log 1/Km
# 2   CC(C)(C)NC(=O)[C@@H]1C[C@@H]2CCCC[C@@H]2CN1C[C...      Log 1/Km
# 3   C[C@]12CCC(=O)C=C1CC[C@@H]1[C@@H]2[C@@H](O)C[C...      Log 1/Km
# 4          CN(C)Cc1nnc2n1-c1ccc(Cl)cc1C(c1ccccc1)=NC2      Log 1/Km
# 5                        NC(=O)N1c2ccccc2C=Cc2ccccc21      Log 1/Km
# 6                      CN(C)CCC=C1c2ccccc2CCc2ccccc21      Log 1/Km
# 7             CN(C)CCCC1(c2ccc(F)cc2)OCc2cc(C#N)ccc21      Log 1/Km
# 8       COc1ccc(-c2nc3cc(C4=NNC(=O)CC4C)ccc3[nH]2)cc1      Log 1/Km
# 9   CC(C)(C)NC(=O)[C@@H]1CN(Cc2cccnc2)CCN1C[C@@H](...      Log 1/Km
# 10  CCc1c2c(nc3ccc(OC(=O)N4CCC(N5CCCCC5)CC4)cc13)-...      Log 1/Km
# 11  CC#C[C@]1(O)CC[C@H]2[C@@H]3CCC4=CC(=O)CCC4=C3[...      Log 1/Km
# 12  CCC(C)(C)C(=O)O[C@H]1C[C@@H](C)C=C2C=C[C@H](C)...      Log 1/Km
# 13  COc1cc2c(c(OC)c1OC)-c1ccc(OC)c(=O)cc1[C@@H](NC...      Log 1/Km
# 14                      CN(C)CCCN1c2ccccc2CCc2ccccc21      Log 1/Km
# 15  O=C(N[C@H](/C=C/S(=O)(=O)c1ccccc1)CCc1ccccc1)[...      Log 1/Km
# 16    COc1ccc2[nH]c([S+]([O-])Cc3ncc(C)c(OC)c3C)nc2c1      Log 1/Km
# 17  C[C@H](CCC(=O)NCCS(=O)(=O)O)[C@H]1CC[C@H]2[C@@...      Log 1/Km
# 18  CC(=O)O[C@H]1C(=O)[C@@]2(C)[C@H]([C@H](OC(=O)c...      Log 1/Km
# 19                                          ClC(Cl)Br      Log 1/Km
# 20  CC[C@H]1OC(=O)[C@H](C)[C@@H](O[C@H]2C[C@@](C)(...      Log 1/Km
# 21  CC[C@]1(O)C[C@@H]2CN(CCc3c([nH]c4ccccc34)[C@@]...      Log 1/Km
# 22  C/C=C1/C[C@@H](C)[C@@](C)(O)C(=O)OCC2=CCN3CC[C...      Log 1/Km
# 23   CCCCc1oc2ccccc2c1C(=O)c1cc(I)c(OCCN(CC)CC)c(I)c1      Log 1/Km
# 24  CC(=O)O[C@@]12CO[C@@H]1C[C@H](O)[C@@]1(C)C(=O)...      Log 1/Km
# 25  CN(C)c1ccc([C@H]2C[C@]3(C)[C@@H](CC[C@]3(O)CCC...      Log 1/Km
# 26  CC[C@]1(O)C[C@@H]2CN(CCc3c([nH]c4ccccc34)[C@@]...      Log 1/Km
# 27  C/C=C/C[C@@H](C)[C@@H](O)[C@H]1C(=O)N[C@@H](CC...      Log 1/Km
# 28  CO[C@H]1/C=C/O[C@@]2(C)Oc3c(C)c(O)c4c(c3C2=O)C...      Log 1/Km
# 29  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...      Log 1/Km
# 30  CC[C@H]1OC(=O)[C@H](C)[C@@H](O[C@H]2C[C@@](C)(...      Log 1/Km
# 31  COc1ccc([C@@H]2Sc3ccccc3N(CCN(C)C)C(=O)[C@@H]2...      Log 1/Km
# 32      CC/C(=C(\c1ccccc1)c1ccc(OCCN(C)C)cc1)c1ccccc1      Log 1/Km
# 33              CN1CCN(C2=Nc3cc(Cl)ccc3Nc3ccccc32)CC1      Log 1/Km
# 34    CCOC(=O)C1=C(C)NC(C)=C(C(=O)OC)C1c1cccc(Cl)c1Cl      Log 1/Km
# 35  C=CC[C@@H]1/C=C(\C)C[C@H](C)C[C@H](OC)[C@H]2O[...      Log 1/Km
# 36                        CC(c1cc2ccccc2s1)N(O)C(N)=O      Log 1/Km
# 37  CN(C)c1ccc([C@H]2C[C@@]3(C)[C@@H](CC[C@@]3(O)/...      Log 1/Km
# 38               O=[N+]([O-])c1ccc2ccc3cccc4ccc1c2c34      Log 1/Km
# 39  CC1C[C@H]2[C@@H]3CCC4=CC(=O)C=C[C@]4(C)C3=CC[C...      Log 1/Km
# 40                             O=c1[nH]c2cc(Cl)ccc2o1      Log 1/Km
# 41                    Nc1ccc(S(=O)(=O)c2ccc(N)cc2)cc1      Log 1/Km
# 42  COc1cc([C@@H]2c3cc4c(cc3[C@@H](O[C@@H]3O[C@@H]...      Log 1/Km
# 43  CN1[C@@H]2CC[C@H]1C[C@@H](NC(=O)c1cc(Cl)cc3c1O...      Log 1/Km
# 44     CN1C(=O)CN=C(c2ccccc2F)c2cc([N+](=O)[O-])ccc21      Log 1/Km
# 45                   COc1ccc(C(CN(C)C)C2(O)CCCCC2)cc1      Log 1/Km
# 46  C=C[C@H]1CN2CC[C@H]1C[C@H]2[C@H](O)c1ccnc2ccc(...      Log 1/Km
# 47  CC(C)c1nc(CN(C)C(=O)N[C@H](C(=O)N[C@@H](Cc2ccc...      Log 1/Km
# 48                     CCCCN1CCCCC1C(=O)Nc1c(C)cccc1C      Log 1/Km
# 49  C/C=C/c1ccc(OC)c(CN[C@H]2C3CCN(CC3)[C@H]2C(c2c...      Log 1/Km
# 50  CO[C@H]1C[C@@H]2CC[C@@H](C)[C@@](O)(O2)C(=O)C(...      Log 1/Km
# 51             CCC(=O)N(c1ccccc1)C1CCN(CCc2ccccc2)CC1      Log 1/Km
# 52            CC(C)(C)c1cc(CC2SCNC2=O)cc(C(C)(C)C)c1O      Log 1/Km
# 53  Cc1c(C)c2c(c(C)c1O)CCC(C)(COc1ccc(CC3SC(=O)NC3...      Log 1/Km
# 54              Cc1nnc2n1-c1ccc(Cl)cc1C(c1ccccc1)=NC2      Log 1/Km
# 55                              CCOc1ccc2ccc(=O)oc2c1      Log 1/Km
# 56       O=C(CCCN1CCC(O)(c2ccc(Cl)cc2)CC1)c1ccc(F)cc1      Log 1/Km
# 57  C[C@@H]1C[C@H]2[C@@H]3CCC4=CC(=O)C=C[C@]4(C)[C...      Log 1/Km
#
#    Standard Relation  ...     Target Type  Document ChEMBL ID  Source ID  \
# 0                '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 1                '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 2                '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 3                '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 4                '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 5                '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 6                '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 7                '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 8                '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 9                '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 10               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 11               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 12               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 13               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 14               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 15               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 16               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 17               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 18               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 19               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 20               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 21               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 22               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 23               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 24               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 25               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 26               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 27               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 28               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 29               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 30               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 31               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 32               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 33               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 34               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 35               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 36               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 37               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 38               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 39               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 40               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 41               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 42               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 43               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 44               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 45               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 46               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 47               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 48               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 49               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 50               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 51               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 52               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 53               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 54               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 55               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 56               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
# 57               '='  ...  SINGLE PROTEIN       CHEMBL1142817          1
#
#        Source Description      Document Journal  Document Year  \
# 0   Scientific Literature  Bioorg Med Chem Lett           2005
# 1   Scientific Literature  Bioorg Med Chem Lett           2005
# 2   Scientific Literature  Bioorg Med Chem Lett           2005
# 3   Scientific Literature  Bioorg Med Chem Lett           2005
# 4   Scientific Literature  Bioorg Med Chem Lett           2005
# 5   Scientific Literature  Bioorg Med Chem Lett           2005
# 6   Scientific Literature  Bioorg Med Chem Lett           2005
# 7   Scientific Literature  Bioorg Med Chem Lett           2005
# 8   Scientific Literature  Bioorg Med Chem Lett           2005
# 9   Scientific Literature  Bioorg Med Chem Lett           2005
# 10  Scientific Literature  Bioorg Med Chem Lett           2005
# 11  Scientific Literature  Bioorg Med Chem Lett           2005
# 12  Scientific Literature  Bioorg Med Chem Lett           2005
# 13  Scientific Literature  Bioorg Med Chem Lett           2005
# 14  Scientific Literature  Bioorg Med Chem Lett           2005
# 15  Scientific Literature  Bioorg Med Chem Lett           2005
# 16  Scientific Literature  Bioorg Med Chem Lett           2005
# 17  Scientific Literature  Bioorg Med Chem Lett           2005
# 18  Scientific Literature  Bioorg Med Chem Lett           2005
# 19  Scientific Literature  Bioorg Med Chem Lett           2005
# 20  Scientific Literature  Bioorg Med Chem Lett           2005
# 21  Scientific Literature  Bioorg Med Chem Lett           2005
# 22  Scientific Literature  Bioorg Med Chem Lett           2005
# 23  Scientific Literature  Bioorg Med Chem Lett           2005
# 24  Scientific Literature  Bioorg Med Chem Lett           2005
# 25  Scientific Literature  Bioorg Med Chem Lett           2005
# 26  Scientific Literature  Bioorg Med Chem Lett           2005
# 27  Scientific Literature  Bioorg Med Chem Lett           2005
# 28  Scientific Literature  Bioorg Med Chem Lett           2005
# 29  Scientific Literature  Bioorg Med Chem Lett           2005
# 30  Scientific Literature  Bioorg Med Chem Lett           2005
# 31  Scientific Literature  Bioorg Med Chem Lett           2005
# 32  Scientific Literature  Bioorg Med Chem Lett           2005
# 33  Scientific Literature  Bioorg Med Chem Lett           2005
# 34  Scientific Literature  Bioorg Med Chem Lett           2005
# 35  Scientific Literature  Bioorg Med Chem Lett           2005
# 36  Scientific Literature  Bioorg Med Chem Lett           2005
# 37  Scientific Literature  Bioorg Med Chem Lett           2005
# 38  Scientific Literature  Bioorg Med Chem Lett           2005
# 39  Scientific Literature  Bioorg Med Chem Lett           2005
# 40  Scientific Literature  Bioorg Med Chem Lett           2005
# 41  Scientific Literature  Bioorg Med Chem Lett           2005
# 42  Scientific Literature  Bioorg Med Chem Lett           2005
# 43  Scientific Literature  Bioorg Med Chem Lett           2005
# 44  Scientific Literature  Bioorg Med Chem Lett           2005
# 45  Scientific Literature  Bioorg Med Chem Lett           2005
# 46  Scientific Literature  Bioorg Med Chem Lett           2005
# 47  Scientific Literature  Bioorg Med Chem Lett           2005
# 48  Scientific Literature  Bioorg Med Chem Lett           2005
# 49  Scientific Literature  Bioorg Med Chem Lett           2005
# 50  Scientific Literature  Bioorg Med Chem Lett           2005
# 51  Scientific Literature  Bioorg Med Chem Lett           2005
# 52  Scientific Literature  Bioorg Med Chem Lett           2005
# 53  Scientific Literature  Bioorg Med Chem Lett           2005
# 54  Scientific Literature  Bioorg Med Chem Lett           2005
# 55  Scientific Literature  Bioorg Med Chem Lett           2005
# 56  Scientific Literature  Bioorg Med Chem Lett           2005
# 57  Scientific Literature  Bioorg Med Chem Lett           2005
#
#     Cell ChEMBL ID  Properties  Action Type  Standard Text Value
# 0              NaN         NaN          NaN                  NaN
# 1              NaN         NaN          NaN                  NaN
# 2              NaN         NaN          NaN                  NaN
# 3              NaN         NaN          NaN                  NaN
# 4              NaN         NaN          NaN                  NaN
# 5              NaN         NaN          NaN                  NaN
# 6              NaN         NaN          NaN                  NaN
# 7              NaN         NaN          NaN                  NaN
# 8              NaN         NaN          NaN                  NaN
# 9              NaN         NaN          NaN                  NaN
# 10             NaN         NaN          NaN                  NaN
# 11             NaN         NaN          NaN                  NaN
# 12             NaN         NaN          NaN                  NaN
# 13             NaN         NaN          NaN                  NaN
# 14             NaN         NaN          NaN                  NaN
# 15             NaN         NaN          NaN                  NaN
# 16             NaN         NaN          NaN                  NaN
# 17             NaN         NaN          NaN                  NaN
# 18             NaN         NaN          NaN                  NaN
# 19             NaN         NaN          NaN                  NaN
# 20             NaN         NaN          NaN                  NaN
# 21             NaN         NaN          NaN                  NaN
# 22             NaN         NaN          NaN                  NaN
# 23             NaN         NaN          NaN                  NaN
# 24             NaN         NaN          NaN                  NaN
# 25             NaN         NaN          NaN                  NaN
# 26             NaN         NaN          NaN                  NaN
# 27             NaN         NaN          NaN                  NaN
# 28             NaN         NaN          NaN                  NaN
# 29             NaN         NaN          NaN                  NaN
# 30             NaN         NaN          NaN                  NaN
# 31             NaN         NaN          NaN                  NaN
# 32             NaN         NaN          NaN                  NaN
# 33             NaN         NaN          NaN                  NaN
# 34             NaN         NaN          NaN                  NaN
# 35             NaN         NaN          NaN                  NaN
# 36             NaN         NaN          NaN                  NaN
# 37             NaN         NaN          NaN                  NaN
# 38             NaN         NaN          NaN                  NaN
# 39             NaN         NaN          NaN                  NaN
# 40             NaN         NaN          NaN                  NaN
# 41             NaN         NaN          NaN                  NaN
# 42             NaN         NaN          NaN                  NaN
# 43             NaN         NaN          NaN                  NaN
# 44             NaN         NaN          NaN                  NaN
# 45             NaN         NaN          NaN                  NaN
# 46             NaN         NaN          NaN                  NaN
# 47             NaN         NaN          NaN                  NaN
# 48             NaN         NaN          NaN                  NaN
# 49             NaN         NaN          NaN                  NaN
# 50             NaN         NaN          NaN                  NaN
# 51             NaN         NaN          NaN                  NaN
# 52             NaN         NaN          NaN                  NaN
# 53             NaN         NaN          NaN                  NaN
# 54             NaN         NaN          NaN                  NaN
# 55             NaN         NaN          NaN                  NaN
# 56             NaN         NaN          NaN                  NaN
# 57             NaN         NaN          NaN                  NaN
#
# [58 rows x 47 columns]

# %%
# standardisation of SMILES
from rdkit import Chem
from rdkit.Chem.MolStandardize import rdMolStandardize
from rdkit.rdBase import BlockLogs
import mols2grid

# %%
# from Pat Walters method
def standardize_smiles(smiles):
    try:
        # follows the steps in
        # https://github.com/greglandrum/RSC_OpenScience_Standardization_202104/blob/main/MolStandardize%20pieces.ipynb
        # as described **excellently** (by Greg) in
        # https://www.youtube.com/watch?v=eWTApNX8dJQ
        mol = Chem.MolFromSmiles(smiles)
    
        # removeHs, disconnect metal atoms, normalize the molecule, reionize the molecule
        clean_mol = rdMolStandardize.Cleanup(mol)
    
        # if many fragments, get the "parent" (the actual mol we are interested in) 
        parent_clean_mol = rdMolStandardize.FragmentParent(clean_mol)
    
        # try to neutralize molecule
        uncharger = rdMolStandardize.Uncharger()  # annoying, but necessary as no convenience method exists
        uncharged_parent_clean_mol = uncharger.uncharge(parent_clean_mol)
    
        # note that no attempt is made at reionization at this step
        # nor at ionization at some pH (rdkit has no pKa caculator)
        # the main aim to represent all molecules from different sources
        # in a (single) standard way, for use in ML, catalogue, etc.
    
        te = rdMolStandardize.TautomerEnumerator()  # idem
        taut_uncharged_parent_clean_mol = te.Canonicalize(uncharged_parent_clean_mol)
    
        return Chem.MolToSmiles(taut_uncharged_parent_clean_mol)
    except:
        return pd.NA

# %%
with BlockLogs():
    df["CANONICAL_SMILES"] = df["Smiles"].progress_apply(lambda x: standardize_smiles(x))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 58/58 [00:01<00:00, 37.82it/s]

# %%
def smi_to_inchikey(smiles):
    try:
        mol = Chem.MolFromSmiles(smiles)
        return Chem.MolToInchiKey(mol)
    except:
        return pd.NA

# %%
# compute inchikeys
with BlockLogs():
    df["INCHIKEY"] = df["CANONICAL_SMILES"].progress_apply(lambda x: smi_to_inchikey(x))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 58/58 [00:00<00:00, 3008.34it/s]

# %%
# not much more to do really
df["dataset"] = "CHEMBL1142817"
df["data_type"] = "assay" # going to assume assay
df["action_type"] = "substrate"

# %%
df.to_csv("processed/CHEMBL1142817.csv", index=False)
