# %%
import pandas as pd
from rdkit import Chem
import seaborn as sns
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Combining data
#
# Combining datasets

# %%
# drop the rest 
keep_cols_all = ["CANONICAL_SMILES", "INCHIKEY", "active", "dataset", "common_name", "action_type"]

# %% [markdown]
# # DrugBank

# %%
drugbank = pd.read_csv("./processed/drugbank.csv")

# %%
drugbank = drugbank[keep_cols_all]
drugbank
# Out:
#                                     CANONICAL_SMILES  \
# 0  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 1  CCCCc1oc2ccc(NS(C)(=O)=O)cc2c1C(=O)c1ccc(OCCCN...
# 2   CCCCc1oc2ccccc2c1C(=O)c1cc(I)c(OCCN(CC)CC)c(I)c1
# 3  CCCCCc1cc(O)c2c(c1)OC(C)(C)[C@@H]1CCC(C)=C[C@@...
# 4     C=C(C)[C@@H]1CCC(C)=C[C@H]1c1c(O)cc(CCCCC)cc1O
# 5           CCCCCc1cc(O)c2c(c1)OC(C)(C)c1ccc(C)cc1-2
#
#                       INCHIKEY  active   dataset  common_name action_type
# 0  GUGOEEXESWIERI-UHFFFAOYSA-N    True  drugbank  Terfenadine   inhibitor
# 1  ZQTNQVWKHCQYLQ-UHFFFAOYSA-N    True  drugbank  Dronedarone   inhibitor
# 2  IYIKLHRQXLHMJQ-UHFFFAOYSA-N    True  drugbank   Amiodarone   inhibitor
# 3  CYQFCXCEBYINGO-IAGOWNOFSA-N    True  drugbank   Dronabinol   inhibitor
# 4  QHMBSVQNZZTUGM-ZWKOTPCHSA-N    True  drugbank  Cannabidiol   inhibitor
# 5  VBGLYOIFKLUMQG-UHFFFAOYSA-N    True  drugbank   Cannabinol   inhibitor

# %% [markdown]
# # Karkhanis 2017

# %%
karkhanis = pd.read_csv("./processed/karkhanis2017.csv")

# %%
karkhanis = karkhanis[keep_cols_all]
karkhanis
# Out:
#                                     CANONICAL_SMILES  \
# 0   CCCCc1oc2ccccc2c1C(=O)c1cc(I)c(OCCN(CC)CC)c(I)c1
# 1  COc1ccc(CCN2CCC(Nc3nc4ccccc4n3Cc3ccc(F)cc3)CC2...
# 2  C#C[C@]1(O)CC[C@H]2[C@@H]3CCC4=Cc5oncc5C[C@]4(...
# 3      CC/C(=C(\c1ccccc1)c1ccc(OCCN(C)C)cc1)c1ccccc1
# 4  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 5  CCCCc1oc2ccc(NS(C)(=O)=O)cc2c1C(=O)c1ccc(OCCCN...
# 6   CCCCc1oc2ccccc2c1C(=O)c1cc(I)c(OCCN(CC)CC)c(I)c1
# 7  CC(C)c1nc(CN(C)C(=O)NC(C(=O)N[C@@H](Cc2ccccc2)...
#
#                       INCHIKEY  active        dataset  common_name action_type
# 0  IYIKLHRQXLHMJQ-UHFFFAOYSA-N    True  karkhanis2017   amiodarone   inhibitor
# 1  GXDALQBWZGODGZ-UHFFFAOYSA-N    True  karkhanis2017   astemizole   inhibitor
# 2  POZRVZJJTULAOH-LHZXLZLDSA-N    True  karkhanis2017      danazol   inhibitor
# 3  NKANXQFJJICGDU-QPLCGJKRSA-N    True  karkhanis2017    tamoxifen   inhibitor
# 4  GUGOEEXESWIERI-UHFFFAOYSA-N    True  karkhanis2017  terfenadine   inhibitor
# 5  ZQTNQVWKHCQYLQ-UHFFFAOYSA-N    True  karkhanis2017  dronedarone   inhibitor
# 6  IYIKLHRQXLHMJQ-UHFFFAOYSA-N    True  karkhanis2017   amiodarone   inhibitor
# 7  NCDNCNXCDXHOMX-BWGGSIGWSA-N    True  karkhanis2017    ritonavir   inhibitor

# %% [markdown]
# # Leow2023

# %%
leow2023 = pd.read_csv("./processed/leow2023.csv")

# %%
leow2023 = leow2023[keep_cols_all]
leow2023
# Out:
#                                      CANONICAL_SMILES  \
# 0             CC(C)COCC(CN(Cc1ccccc1)c1ccccc1)N1CCCC1
# 1       COc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCC1CCN(C)CC1
# 2   COc1cc(N)c(Cl)cc1C(=O)N[C@@H]1CCN(CCCOc2ccc(F)...
# 3   CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 4                   Cc1nccn1CC1CCc2c(c3ccccc3n2C)C1=O
# 5   O=c1[nH]c2ccccc2n1CCCN1CCC(n2c(=O)[nH]c3cc(Cl)...
# 6   O=C(CCCN1CC=C(n2c(=O)[nH]c3ccccc32)CC1)c1ccc(F...
# 7   O=c1[nH]c2ccccc2n1C1CCN(CCCC(c2ccc(F)cc2)c2ccc...
# 8   COc1ccc(CCN2CCC(Nc3nc4ccccc4n3Cc3ccc(F)cc3)CC2...
# 9               CN1CCN(C2=Nc3cc(Cl)ccc3Nc3ccccc32)CC1
# 10  Cc1nc2n(c(=O)c1CCN1CCC(c3noc4cc(F)ccc34)CC1)CCCC2
#
#                        INCHIKEY  active   dataset  common_name action_type
# 0   UIEATEWHFDRYRU-UHFFFAOYSA-N    True  leow2023     Bepridil   inhibitor
# 1   UHTHHESEBZOYNR-UHFFFAOYSA-N    True  leow2023   Vandetanib   inhibitor
# 2   DCSUBABJRXZOMT-IRLDBZIGSA-N    True  leow2023    Cisapride   inhibitor
# 3   GUGOEEXESWIERI-UHFFFAOYSA-N    True  leow2023  Terfenadine   inhibitor
# 4   FELGMEQIXOGIFQ-UHFFFAOYSA-N    True  leow2023  Ondansetron   inhibitor
# 5   FGXWKSZFVQUSTL-UHFFFAOYSA-N    True  leow2023  Domperidone   inhibitor
# 6   RMEDXOLNCUSCGS-UHFFFAOYSA-N    True  leow2023   Droperidol   inhibitor
# 7   YVUQSNJEYSNKRX-UHFFFAOYSA-N    True  leow2023     Pimozide   inhibitor
# 8   GXDALQBWZGODGZ-UHFFFAOYSA-N    True  leow2023   Astemizole   inhibitor
# 9   QZUDBNBUXVUHMW-UHFFFAOYSA-N    True  leow2023    Clozapine   inhibitor
# 10  RAPZEAPATHNIPO-UHFFFAOYSA-N    True  leow2023  Risperidone   inhibitor

# %% [markdown]
# # Chembl
#
# The chembl data is an aggregation for CYP2J2

# %%
chembl_actives = pd.read_csv("processed/chembl_active_selected.csv")
chembl_actives
# Out:
#                                      CANONICAL_SMILES  \
# 0   CCCc1nc2c(C)cc(-c3nc4ccccc4n3C)cc2n1Cc1ccc(-c2...
# 1   Fc1ccc(C(c2ccc(F)cc2)N2CCN(C/C=C/c3ccccc3)CC2)cc1
# 2            O=C(NCc1ccc(Cl)cc1Cl)N1CCC(Oc2ncccn2)CC1
# 3   CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 4         Clc1ccc(COC(Cn2ccnc2)c2ccc(Cl)cc2Cl)c(Cl)c1
# 5   CCCc1ccc(C(=O)CCCN2CCC(C(O)(c3ccccc3)c3ccccc3)...
# 6    O=C(O)c1ccc(OC2CCN(C(=O)NCc3ccc(Cl)cc3Cl)CC2)cc1
# 7           O=C(NCc1ccccc1OC(F)(F)F)N1CCC(c2ccncc2)C1
# 8            O=C(NCc1ccc(Cl)cc1Cl)N1CCC(Oc2ccccc2)CC1
# 9   CC(C)(C)c1ccc(C(=O)CCCN2CCC(C(O)(c3ccccc3)c3cc...
# 10  COc1ccc(CCN(C)CCCC(C#N)(c2ccc(OC)c(OC)c2)C(C)C...
# 11  C[C@]12C=CC(=O)C=C1CC[C@H]1[C@@H]3C[C@@H](O)[C...
# 12  COC(=O)C1=C(C)N=C(C)C(C(=O)OCCN(C)Cc2ccccc2)C1...
# 13  COC(=O)C1=C(C)N=C(C)C(C(=O)OC)C1c1ccccc1[N+](=...
# 14  COCCOC(=O)C1=C(C)N=C(C)C(C(=O)OC(C)C)C1c1cccc(...
# 15          CCn1cc(C(=O)O)c(=O)c2cc(F)c(N3CCNCC3)cc21
# 16           OCCN1CCN(CCCN2c3ccccc3Sc3ccc(Cl)cc32)CC1
# 17        CN[C@H]1CC[C@@H](c2ccc(Cl)c(Cl)c2)c2ccccc21
# 18                           Clc1ccccc1CN1CCc2sccc2C1
# 19                        COCCc1ccc(OCC(O)CNC(C)C)cc1
# 20  CON=C(C(=O)NC1C(=O)N2C(C(=O)O)=C(CSc3nc(=O)c(=...
# 21                   CN(C)CCCN1c2ccccc2Sc2ccc(Cl)cc21
# 22              CN1CCN(C2=Nc3cc(Cl)ccc3Nc3ccccc32)CC1
# 23       O=C(CCCN1CCC(O)(c2ccc(Cl)cc2)CC1)c1ccc(F)cc1
# 24  COCC(=O)O[C@]1(CCN(C)CCCc2nc3ccccc3[nH]2)CCc2c...
# 25             CCN(CC)Cc1cc(Nc2ccnc3cc(Cl)ccc23)ccc1O
# 26            CC(C)COCC(CN(Cc1ccccc1)c1ccccc1)N1CCCC1
# 27            CCc1oc2ccccc2c1C(=O)c1cc(Br)c(O)c(Br)c1
# 28  O=C(CCCN1CCC(C(O)(c2ccccc2)c2ccccc2)CC1)c1ccc(...
# 29  C=CCc1ccc(C(=O)CCCN2CCC(C(O)(c3ccccc3)c3ccccc3...
# 30        O=C(NCc1ccccc1OC(F)(F)F)N1CCC(Oc2ccncc2)CC1
# 31  O=C(CCCN1CCC(C(O)(c2ccccc2)c2ccccc2)CC1)c1ccc(...
# 32        O=C(NCc1ccccc1OC(F)(F)F)N1CCC(Oc2ncccn2)CC1
# 33           O=C(NCc1ccc(Cl)cc1Cl)N1CCC(Oc2ccncc2)CC1
# 34  CC(=O)OCCCc1ccc(C(=O)CCCN2CCC(C(O)(c3ccccc3)c3...
# 35  CCCCc1ccc(C(=O)CCCN2CCC(C(O)(c3ccccc3)c3ccccc3...
# 36  COc1ccc(C(=O)CCCN2CCC(C(O)(c3ccccc3)c3ccccc3)C...
# 37  CCc1ccc(C(=O)CCCN2CCC(C(O)(c3ccccc3)c3ccccc3)C...
# 38  Cc1ccc(C(=O)CCCN2CCC(C(O)(c3ccccc3)c3ccccc3)CC...
# 39  O=C(CCCN1CCC(C(O)(c2ccccc2)c2ccccc2)CC1)c1ccc2...
# 40  O=C(NCCC(c1ccc(F)cc1)c1ccc(F)cc1)c1ccc(OCC(F)(...
# 41  O=C(CCCN1CCC(C(O)(c2ccccc2)c2ccccc2)CC1)c1ccc(...
# 42  O=C(CCCN1CCC(C(O)(c2ccccc2)c2ccccc2)CC1)c1ccc(...
# 43  CS(=O)(=O)c1ccc(C(CCNC(=O)c2ccc(C#N)cc2)c2ccc(...
#
#                        INCHIKEY  pChEMBL mean  pChEMBL std     common_name  \
# 0   RMMXLENWKUUMAY-UHFFFAOYSA-N      6.480000     0.350523     TELMISARTAN
# 1   SMANXXCATUTDDT-QPJJXVBHSA-N      6.292500     0.473806     FLUNARIZINE
# 2   UZEPPAOAIDTLTK-UHFFFAOYSA-N      4.700000     0.000000             NaN
# 3   GUGOEEXESWIERI-UHFFFAOYSA-N      5.593333     0.448367     TERFENADINE
# 4   BYBLEWFAAKGYCD-UHFFFAOYSA-N      6.215000     0.035355      MICONAZOLE
# 5   PBIBEWTURATALQ-UHFFFAOYSA-N      6.600000     0.282843             NaN
# 6   SJFWZPJFJSGSAB-UHFFFAOYSA-N      4.700000     0.000000             NaN
# 7   QCMYNIHAZUWGBC-UHFFFAOYSA-N      5.000000          NaN             NaN
# 8   GNYKLFXXXBPLNY-UHFFFAOYSA-N      5.850000     0.000000             NaN
# 9   YCADFOXVGUGHRV-UHFFFAOYSA-N      6.160000          NaN     TERFENADONE
# 10  SGTNSNPWRIOYBX-UHFFFAOYSA-N      4.660000          NaN       VERAPAMIL
# 11  GFNANZIMVAIWHM-OBYCQNJPSA-N      5.020000          NaN   TRIAMCINOLONE
# 12  UXVSDVSUISWXKD-UHFFFAOYSA-N      5.770000          NaN     NICARDIPINE
# 13  OSUCQKNXQBPLDG-UHFFFAOYSA-N      5.510000          NaN      NIFEDIPINE
# 14  SVMHYHIZWOJKDL-UHFFFAOYSA-N      5.470000          NaN      NIMODIPINE
# 15  OGJPXUAPXNRGGI-UHFFFAOYSA-N      5.590000          NaN     NORFLOXACIN
# 16  RGCVKNLCSQQDEP-UHFFFAOYSA-N      4.970000          NaN    PERPHENAZINE
# 17  VGKDLMBJGBXTGI-SJCJKPOMSA-N      4.730000          NaN      SERTRALINE
# 18  PHWBOXQYWZNQIN-UHFFFAOYSA-N      4.660000          NaN     TICLOPIDINE
# 19  IUBSYMUCCVWXPE-UHFFFAOYSA-N      5.310000          NaN      METOPROLOL
# 20  VAAUVRVFOQPIGI-NZDRZINCSA-N      4.560000          NaN     CEFTRIAXONE
# 21  ZPEIMTDSQAKGNT-UHFFFAOYSA-N      4.610000          NaN  CHLORPROMAZINE
# 22  QZUDBNBUXVUHMW-UHFFFAOYSA-N      4.850000          NaN       CLOZAPINE
# 23  LNEPOXFFQSENCJ-UHFFFAOYSA-N      5.330000          NaN     HALOPERIDOL
# 24  HBNPJJILLOYFJU-VMPREFPWSA-N      5.670000          NaN      MIBEFRADIL
# 25  OVCDSSHSILBFBN-UHFFFAOYSA-N      6.000000          NaN     AMODIAQUINE
# 26  UIEATEWHFDRYRU-UHFFFAOYSA-N      4.940000          NaN        BEPRIDIL
# 27  WHQCHUCQKNIQEC-UHFFFAOYSA-N      5.370000          NaN   BENZBROMARONE
# 28  AOVFGEQZHDTSQA-UHFFFAOYSA-N      5.890000          NaN             NaN
# 29  SJXXIFKOMSEXRL-UHFFFAOYSA-N      6.400000          NaN             NaN
# 30  VIVYDKNMRZTMHS-UHFFFAOYSA-N      5.000000          NaN             NaN
# 31  IYAIWXMTHZPRGI-UHFFFAOYSA-N      5.720000          NaN             NaN
# 32  PMWQIIOHOWIEAH-UHFFFAOYSA-N      5.700000          NaN             NaN
# 33  XBXUBZLJPGESQU-UHFFFAOYSA-N      5.570000          NaN             NaN
# 34  FSWBIKQBUVIPHY-UHFFFAOYSA-N      5.600000          NaN             NaN
# 35  QGDPYJHGPFUYJB-UHFFFAOYSA-N      6.160000          NaN             NaN
# 36  TWIPPDALRSWINY-UHFFFAOYSA-N      5.120000          NaN             NaN
# 37  PUNWCEDDQDAMTK-UHFFFAOYSA-N      6.220000          NaN             NaN
# 38  ASQUTXZYOFTTDB-UHFFFAOYSA-N      6.160000          NaN             NaN
# 39  GTVHXLDACMVUIE-UHFFFAOYSA-N      5.170000          NaN             NaN
# 40  WRWGDCFFHDPTMW-UHFFFAOYSA-N      5.700000          NaN             NaN
# 41  YMMLGNYBWKPZNI-UHFFFAOYSA-N      5.660000          NaN             NaN
# 42  TWYCNBQSLNYJIC-UHFFFAOYSA-N      5.380000          NaN             NaN
# 43  OXJGQTIVCHEXQS-UHFFFAOYSA-N      5.520000          NaN             NaN
#
#     appears_in_N_ChEMBL_assays  action_type         dataset  active
# 0                            4          NaN  ChEMBL_curated    True
# 1                            4          NaN  ChEMBL_curated    True
# 2                            3          NaN  ChEMBL_curated    True
# 3                            3          NaN  ChEMBL_curated    True
# 4                            2          NaN  ChEMBL_curated    True
# 5                            2          NaN  ChEMBL_curated    True
# 6                            2          NaN  ChEMBL_curated    True
# 7                            2          NaN  ChEMBL_curated    True
# 8                            2          NaN  ChEMBL_curated    True
# 9                            1          NaN  ChEMBL_curated    True
# 10                           1          NaN  ChEMBL_curated    True
# 11                           1          NaN  ChEMBL_curated    True
# 12                           1          NaN  ChEMBL_curated    True
# 13                           1          NaN  ChEMBL_curated    True
# 14                           1          NaN  ChEMBL_curated    True
# 15                           1          NaN  ChEMBL_curated    True
# 16                           1          NaN  ChEMBL_curated    True
# 17                           1          NaN  ChEMBL_curated    True
# 18                           1          NaN  ChEMBL_curated    True
# 19                           1          NaN  ChEMBL_curated    True
# 20                           1          NaN  ChEMBL_curated    True
# 21                           1          NaN  ChEMBL_curated    True
# 22                           1          NaN  ChEMBL_curated    True
# 23                           1          NaN  ChEMBL_curated    True
# 24                           1          NaN  ChEMBL_curated    True
# 25                           1          NaN  ChEMBL_curated    True
# 26                           1          NaN  ChEMBL_curated    True
# 27                           1          NaN  ChEMBL_curated    True
# 28                           1          NaN  ChEMBL_curated    True
# 29                           1          NaN  ChEMBL_curated    True
# 30                           1          NaN  ChEMBL_curated    True
# 31                           1          NaN  ChEMBL_curated    True
# 32                           1          NaN  ChEMBL_curated    True
# 33                           1          NaN  ChEMBL_curated    True
# 34                           1          NaN  ChEMBL_curated    True
# 35                           1          NaN  ChEMBL_curated    True
# 36                           1          NaN  ChEMBL_curated    True
# 37                           1          NaN  ChEMBL_curated    True
# 38                           1          NaN  ChEMBL_curated    True
# 39                           1          NaN  ChEMBL_curated    True
# 40                           1          NaN  ChEMBL_curated    True
# 41                           1          NaN  ChEMBL_curated    True
# 42                           1          NaN  ChEMBL_curated    True
# 43                           1          NaN  ChEMBL_curated    True

# %% [markdown]
# # Combine everything
#
#
# ## NOTE
#
# common name being blank is not that these compounds do not have a common name, but that they need to be pulled from pubchem

# %%
combined_literature = pd.concat([drugbank, karkhanis, leow2023])

# %%
combined_literature.INCHIKEY.duplicated().sum()  # close same result with SMILES
# Out:
# np.int64(6)

# %%
combined_literature.dropna(subset="INCHIKEY", inplace=True)

# %%
combined_literature_chembl = pd.concat([combined_literature, chembl_actives])

# %%
combined_literature_chembl
# Out:
#                                      CANONICAL_SMILES  \
# 0   CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 1   CCCCc1oc2ccc(NS(C)(=O)=O)cc2c1C(=O)c1ccc(OCCCN...
# 2    CCCCc1oc2ccccc2c1C(=O)c1cc(I)c(OCCN(CC)CC)c(I)c1
# 3   CCCCCc1cc(O)c2c(c1)OC(C)(C)[C@@H]1CCC(C)=C[C@@...
# 4      C=C(C)[C@@H]1CCC(C)=C[C@H]1c1c(O)cc(CCCCC)cc1O
# ..                                                ...
# 39  O=C(CCCN1CCC(C(O)(c2ccccc2)c2ccccc2)CC1)c1ccc2...
# 40  O=C(NCCC(c1ccc(F)cc1)c1ccc(F)cc1)c1ccc(OCC(F)(...
# 41  O=C(CCCN1CCC(C(O)(c2ccccc2)c2ccccc2)CC1)c1ccc(...
# 42  O=C(CCCN1CCC(C(O)(c2ccccc2)c2ccccc2)CC1)c1ccc(...
# 43  CS(=O)(=O)c1ccc(C(CCNC(=O)c2ccc(C#N)cc2)c2ccc(...
#
#                        INCHIKEY  active         dataset  common_name  \
# 0   GUGOEEXESWIERI-UHFFFAOYSA-N    True        drugbank  Terfenadine
# 1   ZQTNQVWKHCQYLQ-UHFFFAOYSA-N    True        drugbank  Dronedarone
# 2   IYIKLHRQXLHMJQ-UHFFFAOYSA-N    True        drugbank   Amiodarone
# 3   CYQFCXCEBYINGO-IAGOWNOFSA-N    True        drugbank   Dronabinol
# 4   QHMBSVQNZZTUGM-ZWKOTPCHSA-N    True        drugbank  Cannabidiol
# ..                          ...     ...             ...          ...
# 39  GTVHXLDACMVUIE-UHFFFAOYSA-N    True  ChEMBL_curated          NaN
# 40  WRWGDCFFHDPTMW-UHFFFAOYSA-N    True  ChEMBL_curated          NaN
# 41  YMMLGNYBWKPZNI-UHFFFAOYSA-N    True  ChEMBL_curated          NaN
# 42  TWYCNBQSLNYJIC-UHFFFAOYSA-N    True  ChEMBL_curated          NaN
# 43  OXJGQTIVCHEXQS-UHFFFAOYSA-N    True  ChEMBL_curated          NaN
#
#    action_type  pChEMBL mean  pChEMBL std  appears_in_N_ChEMBL_assays
# 0    inhibitor           NaN          NaN                         NaN
# 1    inhibitor           NaN          NaN                         NaN
# 2    inhibitor           NaN          NaN                         NaN
# 3    inhibitor           NaN          NaN                         NaN
# 4    inhibitor           NaN          NaN                         NaN
# ..         ...           ...          ...                         ...
# 39         NaN          5.17          NaN                         1.0
# 40         NaN          5.70          NaN                         1.0
# 41         NaN          5.66          NaN                         1.0
# 42         NaN          5.38          NaN                         1.0
# 43         NaN          5.52          NaN                         1.0
#
# [69 rows x 9 columns]

# %%
combined_literature_chembl
# Out:
#                                      CANONICAL_SMILES  \
# 0   CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 1   CCCCc1oc2ccc(NS(C)(=O)=O)cc2c1C(=O)c1ccc(OCCCN...
# 2    CCCCc1oc2ccccc2c1C(=O)c1cc(I)c(OCCN(CC)CC)c(I)c1
# 3   CCCCCc1cc(O)c2c(c1)OC(C)(C)[C@@H]1CCC(C)=C[C@@...
# 4      C=C(C)[C@@H]1CCC(C)=C[C@H]1c1c(O)cc(CCCCC)cc1O
# ..                                                ...
# 39  O=C(CCCN1CCC(C(O)(c2ccccc2)c2ccccc2)CC1)c1ccc2...
# 40  O=C(NCCC(c1ccc(F)cc1)c1ccc(F)cc1)c1ccc(OCC(F)(...
# 41  O=C(CCCN1CCC(C(O)(c2ccccc2)c2ccccc2)CC1)c1ccc(...
# 42  O=C(CCCN1CCC(C(O)(c2ccccc2)c2ccccc2)CC1)c1ccc(...
# 43  CS(=O)(=O)c1ccc(C(CCNC(=O)c2ccc(C#N)cc2)c2ccc(...
#
#                        INCHIKEY  active         dataset  common_name  \
# 0   GUGOEEXESWIERI-UHFFFAOYSA-N    True        drugbank  Terfenadine
# 1   ZQTNQVWKHCQYLQ-UHFFFAOYSA-N    True        drugbank  Dronedarone
# 2   IYIKLHRQXLHMJQ-UHFFFAOYSA-N    True        drugbank   Amiodarone
# 3   CYQFCXCEBYINGO-IAGOWNOFSA-N    True        drugbank   Dronabinol
# 4   QHMBSVQNZZTUGM-ZWKOTPCHSA-N    True        drugbank  Cannabidiol
# ..                          ...     ...             ...          ...
# 39  GTVHXLDACMVUIE-UHFFFAOYSA-N    True  ChEMBL_curated          NaN
# 40  WRWGDCFFHDPTMW-UHFFFAOYSA-N    True  ChEMBL_curated          NaN
# 41  YMMLGNYBWKPZNI-UHFFFAOYSA-N    True  ChEMBL_curated          NaN
# 42  TWYCNBQSLNYJIC-UHFFFAOYSA-N    True  ChEMBL_curated          NaN
# 43  OXJGQTIVCHEXQS-UHFFFAOYSA-N    True  ChEMBL_curated          NaN
#
#    action_type  pChEMBL mean  pChEMBL std  appears_in_N_ChEMBL_assays
# 0    inhibitor           NaN          NaN                         NaN
# 1    inhibitor           NaN          NaN                         NaN
# 2    inhibitor           NaN          NaN                         NaN
# 3    inhibitor           NaN          NaN                         NaN
# 4    inhibitor           NaN          NaN                         NaN
# ..         ...           ...          ...                         ...
# 39         NaN          5.17          NaN                         1.0
# 40         NaN          5.70          NaN                         1.0
# 41         NaN          5.66          NaN                         1.0
# 42         NaN          5.38          NaN                         1.0
# 43         NaN          5.52          NaN                         1.0
#
# [69 rows x 9 columns]

# %%
combined_literature_chembl.dataset.value_counts()
# Out:
# dataset
# ChEMBL_curated    44
# leow2023          11
# karkhanis2017      8
# drugbank           6
# Name: count, dtype: int64

# %%
combined_literature_chembl.INCHIKEY.duplicated().sum()
# Out:
# np.int64(9)

# %%
combined_literature_chembl.INCHIKEY.isna().sum()
# Out:
# np.int64(0)

# %%
combined_literature_chembl
# Out:
#                                      CANONICAL_SMILES  \
# 0   CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 1   CCCCc1oc2ccc(NS(C)(=O)=O)cc2c1C(=O)c1ccc(OCCCN...
# 2    CCCCc1oc2ccccc2c1C(=O)c1cc(I)c(OCCN(CC)CC)c(I)c1
# 3   CCCCCc1cc(O)c2c(c1)OC(C)(C)[C@@H]1CCC(C)=C[C@@...
# 4      C=C(C)[C@@H]1CCC(C)=C[C@H]1c1c(O)cc(CCCCC)cc1O
# ..                                                ...
# 39  O=C(CCCN1CCC(C(O)(c2ccccc2)c2ccccc2)CC1)c1ccc2...
# 40  O=C(NCCC(c1ccc(F)cc1)c1ccc(F)cc1)c1ccc(OCC(F)(...
# 41  O=C(CCCN1CCC(C(O)(c2ccccc2)c2ccccc2)CC1)c1ccc(...
# 42  O=C(CCCN1CCC(C(O)(c2ccccc2)c2ccccc2)CC1)c1ccc(...
# 43  CS(=O)(=O)c1ccc(C(CCNC(=O)c2ccc(C#N)cc2)c2ccc(...
#
#                        INCHIKEY  active         dataset  common_name  \
# 0   GUGOEEXESWIERI-UHFFFAOYSA-N    True        drugbank  Terfenadine
# 1   ZQTNQVWKHCQYLQ-UHFFFAOYSA-N    True        drugbank  Dronedarone
# 2   IYIKLHRQXLHMJQ-UHFFFAOYSA-N    True        drugbank   Amiodarone
# 3   CYQFCXCEBYINGO-IAGOWNOFSA-N    True        drugbank   Dronabinol
# 4   QHMBSVQNZZTUGM-ZWKOTPCHSA-N    True        drugbank  Cannabidiol
# ..                          ...     ...             ...          ...
# 39  GTVHXLDACMVUIE-UHFFFAOYSA-N    True  ChEMBL_curated          NaN
# 40  WRWGDCFFHDPTMW-UHFFFAOYSA-N    True  ChEMBL_curated          NaN
# 41  YMMLGNYBWKPZNI-UHFFFAOYSA-N    True  ChEMBL_curated          NaN
# 42  TWYCNBQSLNYJIC-UHFFFAOYSA-N    True  ChEMBL_curated          NaN
# 43  OXJGQTIVCHEXQS-UHFFFAOYSA-N    True  ChEMBL_curated          NaN
#
#    action_type  pChEMBL mean  pChEMBL std  appears_in_N_ChEMBL_assays
# 0    inhibitor           NaN          NaN                         NaN
# 1    inhibitor           NaN          NaN                         NaN
# 2    inhibitor           NaN          NaN                         NaN
# 3    inhibitor           NaN          NaN                         NaN
# 4    inhibitor           NaN          NaN                         NaN
# ..         ...           ...          ...                         ...
# 39         NaN          5.17          NaN                         1.0
# 40         NaN          5.70          NaN                         1.0
# 41         NaN          5.66          NaN                         1.0
# 42         NaN          5.38          NaN                         1.0
# 43         NaN          5.52          NaN                         1.0
#
# [69 rows x 9 columns]

# %%
appears = combined_literature_chembl.groupby("INCHIKEY")["dataset"].nunique().reset_index(name="appears_in_N_datasets")
appears.set_index("INCHIKEY")
# Out:
#                              appears_in_N_datasets
# INCHIKEY
# AOVFGEQZHDTSQA-UHFFFAOYSA-N                      1
# ASQUTXZYOFTTDB-UHFFFAOYSA-N                      1
# BYBLEWFAAKGYCD-UHFFFAOYSA-N                      1
# CYQFCXCEBYINGO-IAGOWNOFSA-N                      1
# DCSUBABJRXZOMT-IRLDBZIGSA-N                      1
# FELGMEQIXOGIFQ-UHFFFAOYSA-N                      1
# FGXWKSZFVQUSTL-UHFFFAOYSA-N                      1
# FSWBIKQBUVIPHY-UHFFFAOYSA-N                      1
# GFNANZIMVAIWHM-OBYCQNJPSA-N                      1
# GNYKLFXXXBPLNY-UHFFFAOYSA-N                      1
# GTVHXLDACMVUIE-UHFFFAOYSA-N                      1
# GUGOEEXESWIERI-UHFFFAOYSA-N                      4
# GXDALQBWZGODGZ-UHFFFAOYSA-N                      2
# HBNPJJILLOYFJU-VMPREFPWSA-N                      1
# IUBSYMUCCVWXPE-UHFFFAOYSA-N                      1
# IYAIWXMTHZPRGI-UHFFFAOYSA-N                      1
# IYIKLHRQXLHMJQ-UHFFFAOYSA-N                      2
# LNEPOXFFQSENCJ-UHFFFAOYSA-N                      1
# NCDNCNXCDXHOMX-BWGGSIGWSA-N                      1
# NKANXQFJJICGDU-QPLCGJKRSA-N                      1
# OGJPXUAPXNRGGI-UHFFFAOYSA-N                      1
# OSUCQKNXQBPLDG-UHFFFAOYSA-N                      1
# OVCDSSHSILBFBN-UHFFFAOYSA-N                      1
# OXJGQTIVCHEXQS-UHFFFAOYSA-N                      1
# PBIBEWTURATALQ-UHFFFAOYSA-N                      1
# PHWBOXQYWZNQIN-UHFFFAOYSA-N                      1
# PMWQIIOHOWIEAH-UHFFFAOYSA-N                      1
# POZRVZJJTULAOH-LHZXLZLDSA-N                      1
# PUNWCEDDQDAMTK-UHFFFAOYSA-N                      1
# QCMYNIHAZUWGBC-UHFFFAOYSA-N                      1
# QGDPYJHGPFUYJB-UHFFFAOYSA-N                      1
# QHMBSVQNZZTUGM-ZWKOTPCHSA-N                      1
# QZUDBNBUXVUHMW-UHFFFAOYSA-N                      2
# RAPZEAPATHNIPO-UHFFFAOYSA-N                      1
# RGCVKNLCSQQDEP-UHFFFAOYSA-N                      1
# RMEDXOLNCUSCGS-UHFFFAOYSA-N                      1
# RMMXLENWKUUMAY-UHFFFAOYSA-N                      1
# SGTNSNPWRIOYBX-UHFFFAOYSA-N                      1
# SJFWZPJFJSGSAB-UHFFFAOYSA-N                      1
# SJXXIFKOMSEXRL-UHFFFAOYSA-N                      1
# SMANXXCATUTDDT-QPJJXVBHSA-N                      1
# SVMHYHIZWOJKDL-UHFFFAOYSA-N                      1
# TWIPPDALRSWINY-UHFFFAOYSA-N                      1
# TWYCNBQSLNYJIC-UHFFFAOYSA-N                      1
# UHTHHESEBZOYNR-UHFFFAOYSA-N                      1
# UIEATEWHFDRYRU-UHFFFAOYSA-N                      2
# UXVSDVSUISWXKD-UHFFFAOYSA-N                      1
# UZEPPAOAIDTLTK-UHFFFAOYSA-N                      1
# VAAUVRVFOQPIGI-NZDRZINCSA-N                      1
# VBGLYOIFKLUMQG-UHFFFAOYSA-N                      1
# VGKDLMBJGBXTGI-SJCJKPOMSA-N                      1
# VIVYDKNMRZTMHS-UHFFFAOYSA-N                      1
# WHQCHUCQKNIQEC-UHFFFAOYSA-N                      1
# WRWGDCFFHDPTMW-UHFFFAOYSA-N                      1
# XBXUBZLJPGESQU-UHFFFAOYSA-N                      1
# YCADFOXVGUGHRV-UHFFFAOYSA-N                      1
# YMMLGNYBWKPZNI-UHFFFAOYSA-N                      1
# YVUQSNJEYSNKRX-UHFFFAOYSA-N                      1
# ZPEIMTDSQAKGNT-UHFFFAOYSA-N                      1
# ZQTNQVWKHCQYLQ-UHFFFAOYSA-N                      2

# %%
appears.isna().sum()
# Out:
# INCHIKEY                 0
# appears_in_N_datasets    0
# dtype: int64

# %%
sns.countplot(data=appears, x="appears_in_N_datasets")
# Out:
# <Axes: xlabel='appears_in_N_datasets', ylabel='count'>

# %%
combined_literature_chembl_w_counts = combined_literature_chembl.merge(appears, on="INCHIKEY")
combined_literature_chembl_w_counts
# Out:
#                                      CANONICAL_SMILES  \
# 0   CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 1   CCCCc1oc2ccc(NS(C)(=O)=O)cc2c1C(=O)c1ccc(OCCCN...
# 2    CCCCc1oc2ccccc2c1C(=O)c1cc(I)c(OCCN(CC)CC)c(I)c1
# 3   CCCCCc1cc(O)c2c(c1)OC(C)(C)[C@@H]1CCC(C)=C[C@@...
# 4      C=C(C)[C@@H]1CCC(C)=C[C@H]1c1c(O)cc(CCCCC)cc1O
# ..                                                ...
# 64  O=C(CCCN1CCC(C(O)(c2ccccc2)c2ccccc2)CC1)c1ccc2...
# 65  O=C(NCCC(c1ccc(F)cc1)c1ccc(F)cc1)c1ccc(OCC(F)(...
# 66  O=C(CCCN1CCC(C(O)(c2ccccc2)c2ccccc2)CC1)c1ccc(...
# 67  O=C(CCCN1CCC(C(O)(c2ccccc2)c2ccccc2)CC1)c1ccc(...
# 68  CS(=O)(=O)c1ccc(C(CCNC(=O)c2ccc(C#N)cc2)c2ccc(...
#
#                        INCHIKEY  active         dataset  common_name  \
# 0   GUGOEEXESWIERI-UHFFFAOYSA-N    True        drugbank  Terfenadine
# 1   ZQTNQVWKHCQYLQ-UHFFFAOYSA-N    True        drugbank  Dronedarone
# 2   IYIKLHRQXLHMJQ-UHFFFAOYSA-N    True        drugbank   Amiodarone
# 3   CYQFCXCEBYINGO-IAGOWNOFSA-N    True        drugbank   Dronabinol
# 4   QHMBSVQNZZTUGM-ZWKOTPCHSA-N    True        drugbank  Cannabidiol
# ..                          ...     ...             ...          ...
# 64  GTVHXLDACMVUIE-UHFFFAOYSA-N    True  ChEMBL_curated          NaN
# 65  WRWGDCFFHDPTMW-UHFFFAOYSA-N    True  ChEMBL_curated          NaN
# 66  YMMLGNYBWKPZNI-UHFFFAOYSA-N    True  ChEMBL_curated          NaN
# 67  TWYCNBQSLNYJIC-UHFFFAOYSA-N    True  ChEMBL_curated          NaN
# 68  OXJGQTIVCHEXQS-UHFFFAOYSA-N    True  ChEMBL_curated          NaN
#
#    action_type  pChEMBL mean  pChEMBL std  appears_in_N_ChEMBL_assays  \
# 0    inhibitor           NaN          NaN                         NaN
# 1    inhibitor           NaN          NaN                         NaN
# 2    inhibitor           NaN          NaN                         NaN
# 3    inhibitor           NaN          NaN                         NaN
# 4    inhibitor           NaN          NaN                         NaN
# ..         ...           ...          ...                         ...
# 64         NaN          5.17          NaN                         1.0
# 65         NaN          5.70          NaN                         1.0
# 66         NaN          5.66          NaN                         1.0
# 67         NaN          5.38          NaN                         1.0
# 68         NaN          5.52          NaN                         1.0
#
#     appears_in_N_datasets
# 0                       4
# 1                       2
# 2                       2
# 3                       1
# 4                       1
# ..                    ...
# 64                      1
# 65                      1
# 66                      1
# 67                      1
# 68                      1
#
# [69 rows x 10 columns]

# %%
df_dummies = pd.get_dummies(combined_literature_chembl_w_counts['dataset'], prefix='dataset').join(combined_literature_chembl_w_counts["INCHIKEY"])
df_dummies
# Out:
#     dataset_ChEMBL_curated  dataset_drugbank  dataset_karkhanis2017  \
# 0                    False              True                  False
# 1                    False              True                  False
# 2                    False              True                  False
# 3                    False              True                  False
# 4                    False              True                  False
# ..                     ...               ...                    ...
# 64                    True             False                  False
# 65                    True             False                  False
# 66                    True             False                  False
# 67                    True             False                  False
# 68                    True             False                  False
#
#     dataset_leow2023                     INCHIKEY
# 0              False  GUGOEEXESWIERI-UHFFFAOYSA-N
# 1              False  ZQTNQVWKHCQYLQ-UHFFFAOYSA-N
# 2              False  IYIKLHRQXLHMJQ-UHFFFAOYSA-N
# 3              False  CYQFCXCEBYINGO-IAGOWNOFSA-N
# 4              False  QHMBSVQNZZTUGM-ZWKOTPCHSA-N
# ..               ...                          ...
# 64             False  GTVHXLDACMVUIE-UHFFFAOYSA-N
# 65             False  WRWGDCFFHDPTMW-UHFFFAOYSA-N
# 66             False  YMMLGNYBWKPZNI-UHFFFAOYSA-N
# 67             False  TWYCNBQSLNYJIC-UHFFFAOYSA-N
# 68             False  OXJGQTIVCHEXQS-UHFFFAOYSA-N
#
# [69 rows x 5 columns]

# %%
df_result = df_dummies.groupby('INCHIKEY').max().reset_index()
df_result = df_result.set_index("INCHIKEY")

# %%
# cat_dataname = combined_literature_chembl.groupby("INCHIKEY")["dataset"].apply(lambda x: "_+_".join(x)).reset_index(name="dataset_comb").set_index("INCHIKEY")
# cat_dataname

# %%
combined_literature_chembl_w_counts = combined_literature_chembl_w_counts.merge(df_result, on="INCHIKEY")
combined_literature_chembl_w_counts
# Out:
#                                      CANONICAL_SMILES  \
# 0   CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 1   CCCCc1oc2ccc(NS(C)(=O)=O)cc2c1C(=O)c1ccc(OCCCN...
# 2    CCCCc1oc2ccccc2c1C(=O)c1cc(I)c(OCCN(CC)CC)c(I)c1
# 3   CCCCCc1cc(O)c2c(c1)OC(C)(C)[C@@H]1CCC(C)=C[C@@...
# 4      C=C(C)[C@@H]1CCC(C)=C[C@H]1c1c(O)cc(CCCCC)cc1O
# ..                                                ...
# 64  O=C(CCCN1CCC(C(O)(c2ccccc2)c2ccccc2)CC1)c1ccc2...
# 65  O=C(NCCC(c1ccc(F)cc1)c1ccc(F)cc1)c1ccc(OCC(F)(...
# 66  O=C(CCCN1CCC(C(O)(c2ccccc2)c2ccccc2)CC1)c1ccc(...
# 67  O=C(CCCN1CCC(C(O)(c2ccccc2)c2ccccc2)CC1)c1ccc(...
# 68  CS(=O)(=O)c1ccc(C(CCNC(=O)c2ccc(C#N)cc2)c2ccc(...
#
#                        INCHIKEY  active         dataset  common_name  \
# 0   GUGOEEXESWIERI-UHFFFAOYSA-N    True        drugbank  Terfenadine
# 1   ZQTNQVWKHCQYLQ-UHFFFAOYSA-N    True        drugbank  Dronedarone
# 2   IYIKLHRQXLHMJQ-UHFFFAOYSA-N    True        drugbank   Amiodarone
# 3   CYQFCXCEBYINGO-IAGOWNOFSA-N    True        drugbank   Dronabinol
# 4   QHMBSVQNZZTUGM-ZWKOTPCHSA-N    True        drugbank  Cannabidiol
# ..                          ...     ...             ...          ...
# 64  GTVHXLDACMVUIE-UHFFFAOYSA-N    True  ChEMBL_curated          NaN
# 65  WRWGDCFFHDPTMW-UHFFFAOYSA-N    True  ChEMBL_curated          NaN
# 66  YMMLGNYBWKPZNI-UHFFFAOYSA-N    True  ChEMBL_curated          NaN
# 67  TWYCNBQSLNYJIC-UHFFFAOYSA-N    True  ChEMBL_curated          NaN
# 68  OXJGQTIVCHEXQS-UHFFFAOYSA-N    True  ChEMBL_curated          NaN
#
#    action_type  pChEMBL mean  pChEMBL std  appears_in_N_ChEMBL_assays  \
# 0    inhibitor           NaN          NaN                         NaN
# 1    inhibitor           NaN          NaN                         NaN
# 2    inhibitor           NaN          NaN                         NaN
# 3    inhibitor           NaN          NaN                         NaN
# 4    inhibitor           NaN          NaN                         NaN
# ..         ...           ...          ...                         ...
# 64         NaN          5.17          NaN                         1.0
# 65         NaN          5.70          NaN                         1.0
# 66         NaN          5.66          NaN                         1.0
# 67         NaN          5.38          NaN                         1.0
# 68         NaN          5.52          NaN                         1.0
#
#     appears_in_N_datasets  dataset_ChEMBL_curated  dataset_drugbank  \
# 0                       4                    True              True
# 1                       2                   False              True
# 2                       2                   False              True
# 3                       1                   False              True
# 4                       1                   False              True
# ..                    ...                     ...               ...
# 64                      1                    True             False
# 65                      1                    True             False
# 66                      1                    True             False
# 67                      1                    True             False
# 68                      1                    True             False
#
#     dataset_karkhanis2017  dataset_leow2023
# 0                    True              True
# 1                    True             False
# 2                    True             False
# 3                   False             False
# 4                   False             False
# ..                    ...               ...
# 64                  False             False
# 65                  False             False
# 66                  False             False
# 67                  False             False
# 68                  False             False
#
# [69 rows x 14 columns]

# %%
combined_literature_chembl_w_counts.action_type.value_counts()
# Out:
# action_type
# inhibitor    25
# Name: count, dtype: int64

# %%
combined_literature_chembl_w_counts.INCHIKEY.nunique()
# Out:
# 60

# %%
combined_literature_chembl_w_counts['common_name'].isna().sum()
# Out:
# np.int64(21)

# %%
# we can just sort by appears_in_N_ChEMBL_assays to get all the chembl data at the top, then uniquify on INCHIKEY

combined_literature_chembl_w_counts.sort_values(["appears_in_N_ChEMBL_assays", "appears_in_N_datasets"], ascending=[False,False],  inplace=True)

# %%
# fill common name from gropupby 
combined_literature_chembl_w_counts['common_name'] = combined_literature_chembl_w_counts.groupby('INCHIKEY')['common_name'].transform(lambda x: x.fillna(method='ffill').fillna(method='bfill'))
# Out:
# /tmp/ipykernel_129696/1877288904.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_literature_chembl_w_counts['common_name'] = combined_literature_chembl_w_counts.groupby('INCHIKEY')['common_name'].transform(lambda x: x.fillna(method='ffill').fillna(method='bfill'))
# /tmp/ipykernel_129696/1877288904.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   combined_literature_chembl_w_counts['common_name'] = combined_literature_chembl_w_counts.groupby('INCHIKEY')['common_name'].transform(lambda x: x.fillna(method='ffill').fillna(method='bfill'))

# %%
combined_literature_chembl_w_counts['common_name'].isna().sum()
# Out:
# np.int64(21)

# %%
combined_literature_chembl_w_counts.head()
# Out:
#                                      CANONICAL_SMILES  \
# 25  CCCc1nc2c(C)cc(-c3nc4ccccc4n3C)cc2n1Cc1ccc(-c2...
# 26  Fc1ccc(C(c2ccc(F)cc2)N2CCN(C/C=C/c3ccccc3)CC2)cc1
# 28  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 27           O=C(NCc1ccc(Cl)cc1Cl)N1CCC(Oc2ncccn2)CC1
# 29        Clc1ccc(COC(Cn2ccnc2)c2ccc(Cl)cc2Cl)c(Cl)c1
#
#                        INCHIKEY  active         dataset  common_name  \
# 25  RMMXLENWKUUMAY-UHFFFAOYSA-N    True  ChEMBL_curated  TELMISARTAN
# 26  SMANXXCATUTDDT-QPJJXVBHSA-N    True  ChEMBL_curated  FLUNARIZINE
# 28  GUGOEEXESWIERI-UHFFFAOYSA-N    True  ChEMBL_curated  TERFENADINE
# 27  UZEPPAOAIDTLTK-UHFFFAOYSA-N    True  ChEMBL_curated          NaN
# 29  BYBLEWFAAKGYCD-UHFFFAOYSA-N    True  ChEMBL_curated   MICONAZOLE
#
#    action_type  pChEMBL mean  pChEMBL std  appears_in_N_ChEMBL_assays  \
# 25         NaN      6.480000     0.350523                         4.0
# 26         NaN      6.292500     0.473806                         4.0
# 28         NaN      5.593333     0.448367                         3.0
# 27         NaN      4.700000     0.000000                         3.0
# 29         NaN      6.215000     0.035355                         2.0
#
#     appears_in_N_datasets  dataset_ChEMBL_curated  dataset_drugbank  \
# 25                      1                    True             False
# 26                      1                    True             False
# 28                      4                    True              True
# 27                      1                    True             False
# 29                      1                    True             False
#
#     dataset_karkhanis2017  dataset_leow2023
# 25                  False             False
# 26                  False             False
# 28                   True              True
# 27                  False             False
# 29                  False             False

# %%
combined_literature_chembl_w_counts.drop_duplicates(subset="INCHIKEY", inplace=True)

# %%
combined_literature_chembl_w_counts["action_type"] = combined_literature_chembl_w_counts["action_type"].fillna("inhibitor")

# %%
combined_literature_chembl_w_counts["inclusion_score"] = combined_literature_chembl_w_counts["appears_in_N_ChEMBL_assays"].fillna(0) + combined_literature_chembl_w_counts["appears_in_N_datasets"].fillna(0)

# %%
combined_literature_chembl_w_counts.drop(columns="dataset", inplace=True)

# %%
combined_literature_chembl_w_counts.sort_values("inclusion_score", ascending=False, inplace=True)

# %%
combined_literature_chembl_w_counts.to_csv("final/actives_final.csv", index=False)

# %%
combined_literature_chembl_w_counts
# Out:
#                                      CANONICAL_SMILES  \
# 28  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 25  CCCc1nc2c(C)cc(-c3nc4ccccc4n3C)cc2n1Cc1ccc(-c2...
# 26  Fc1ccc(C(c2ccc(F)cc2)N2CCN(C/C=C/c3ccccc3)CC2)cc1
# 27           O=C(NCc1ccc(Cl)cc1Cl)N1CCC(Oc2ncccn2)CC1
# 29        Clc1ccc(COC(Cn2ccnc2)c2ccc(Cl)cc2Cl)c(Cl)c1
# 30  CCCc1ccc(C(=O)CCCN2CCC(C(O)(c3ccccc3)c3ccccc3)...
# 31   O=C(O)c1ccc(OC2CCN(C(=O)NCc3ccc(Cl)cc3Cl)CC2)cc1
# 32          O=C(NCc1ccccc1OC(F)(F)F)N1CCC(c2ccncc2)C1
# 33           O=C(NCc1ccc(Cl)cc1Cl)N1CCC(Oc2ccccc2)CC1
# 47              CN1CCN(C2=Nc3cc(Cl)ccc3Nc3ccccc32)CC1
# 51            CC(C)COCC(CN(Cc1ccccc1)c1ccccc1)N1CCCC1
# 34  CC(C)(C)c1ccc(C(=O)CCCN2CCC(C(O)(c3ccccc3)c3cc...
# 35  COc1ccc(CCN(C)CCCC(C#N)(c2ccc(OC)c(OC)c2)C(C)C...
# 36  C[C@]12C=CC(=O)C=C1CC[C@H]1[C@@H]3C[C@@H](O)[C...
# 37  COC(=O)C1=C(C)N=C(C)C(C(=O)OCCN(C)Cc2ccccc2)C1...
# 38  COC(=O)C1=C(C)N=C(C)C(C(=O)OC)C1c1ccccc1[N+](=...
# 39  COCCOC(=O)C1=C(C)N=C(C)C(C(=O)OC(C)C)C1c1cccc(...
# 40          CCn1cc(C(=O)O)c(=O)c2cc(F)c(N3CCNCC3)cc21
# 41           OCCN1CCN(CCCN2c3ccccc3Sc3ccc(Cl)cc32)CC1
# 42        CN[C@H]1CC[C@@H](c2ccc(Cl)c(Cl)c2)c2ccccc21
# 43                           Clc1ccccc1CN1CCc2sccc2C1
# 44                        COCCc1ccc(OCC(O)CNC(C)C)cc1
# 45  CON=C(C(=O)NC1C(=O)N2C(C(=O)O)=C(CSc3nc(=O)c(=...
# 46                   CN(C)CCCN1c2ccccc2Sc2ccc(Cl)cc21
# 48       O=C(CCCN1CCC(O)(c2ccc(Cl)cc2)CC1)c1ccc(F)cc1
# 49  COCC(=O)O[C@]1(CCN(C)CCCc2nc3ccccc3[nH]2)CCc2c...
# 50             CCN(CC)Cc1cc(Nc2ccnc3cc(Cl)ccc23)ccc1O
# 52            CCc1oc2ccccc2c1C(=O)c1cc(Br)c(O)c(Br)c1
# 53  O=C(CCCN1CCC(C(O)(c2ccccc2)c2ccccc2)CC1)c1ccc(...
# 54  C=CCc1ccc(C(=O)CCCN2CCC(C(O)(c3ccccc3)c3ccccc3...
# 55        O=C(NCc1ccccc1OC(F)(F)F)N1CCC(Oc2ccncc2)CC1
# 56  O=C(CCCN1CCC(C(O)(c2ccccc2)c2ccccc2)CC1)c1ccc(...
# 57        O=C(NCc1ccccc1OC(F)(F)F)N1CCC(Oc2ncccn2)CC1
# 58           O=C(NCc1ccc(Cl)cc1Cl)N1CCC(Oc2ccncc2)CC1
# 59  CC(=O)OCCCc1ccc(C(=O)CCCN2CCC(C(O)(c3ccccc3)c3...
# 60  CCCCc1ccc(C(=O)CCCN2CCC(C(O)(c3ccccc3)c3ccccc3...
# 61  COc1ccc(C(=O)CCCN2CCC(C(O)(c3ccccc3)c3ccccc3)C...
# 62  CCc1ccc(C(=O)CCCN2CCC(C(O)(c3ccccc3)c3ccccc3)C...
# 63  Cc1ccc(C(=O)CCCN2CCC(C(O)(c3ccccc3)c3ccccc3)CC...
# 64  O=C(CCCN1CCC(C(O)(c2ccccc2)c2ccccc2)CC1)c1ccc2...
# 65  O=C(NCCC(c1ccc(F)cc1)c1ccc(F)cc1)c1ccc(OCC(F)(...
# 66  O=C(CCCN1CCC(C(O)(c2ccccc2)c2ccccc2)CC1)c1ccc(...
# 67  O=C(CCCN1CCC(C(O)(c2ccccc2)c2ccccc2)CC1)c1ccc(...
# 68  CS(=O)(=O)c1ccc(C(CCNC(=O)c2ccc(C#N)cc2)c2ccc(...
# 1   CCCCc1oc2ccc(NS(C)(=O)=O)cc2c1C(=O)c1ccc(OCCCN...
# 2    CCCCc1oc2ccccc2c1C(=O)c1cc(I)c(OCCN(CC)CC)c(I)c1
# 7   COc1ccc(CCN2CCC(Nc3nc4ccccc4n3Cc3ccc(F)cc3)CC2...
# 3   CCCCCc1cc(O)c2c(c1)OC(C)(C)[C@@H]1CCC(C)=C[C@@...
# 4      C=C(C)[C@@H]1CCC(C)=C[C@H]1c1c(O)cc(CCCCC)cc1O
# 5            CCCCCc1cc(O)c2c(c1)OC(C)(C)c1ccc(C)cc1-2
# 8   C#C[C@]1(O)CC[C@H]2[C@@H]3CCC4=Cc5oncc5C[C@]4(...
# 9       CC/C(=C(\c1ccccc1)c1ccc(OCCN(C)C)cc1)c1ccccc1
# 13  CC(C)c1nc(CN(C)C(=O)NC(C(=O)N[C@@H](Cc2ccccc2)...
# 15      COc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCC1CCN(C)CC1
# 16  COc1cc(N)c(Cl)cc1C(=O)N[C@@H]1CCN(CCCOc2ccc(F)...
# 18                  Cc1nccn1CC1CCc2c(c3ccccc3n2C)C1=O
# 19  O=c1[nH]c2ccccc2n1CCCN1CCC(n2c(=O)[nH]c3cc(Cl)...
# 20  O=C(CCCN1CC=C(n2c(=O)[nH]c3ccccc32)CC1)c1ccc(F...
# 21  O=c1[nH]c2ccccc2n1C1CCN(CCCC(c2ccc(F)cc2)c2ccc...
# 24  Cc1nc2n(c(=O)c1CCN1CCC(c3noc4cc(F)ccc34)CC1)CCCC2
#
#                        INCHIKEY  active     common_name action_type  \
# 28  GUGOEEXESWIERI-UHFFFAOYSA-N    True     TERFENADINE   inhibitor
# 25  RMMXLENWKUUMAY-UHFFFAOYSA-N    True     TELMISARTAN   inhibitor
# 26  SMANXXCATUTDDT-QPJJXVBHSA-N    True     FLUNARIZINE   inhibitor
# 27  UZEPPAOAIDTLTK-UHFFFAOYSA-N    True             NaN   inhibitor
# 29  BYBLEWFAAKGYCD-UHFFFAOYSA-N    True      MICONAZOLE   inhibitor
# 30  PBIBEWTURATALQ-UHFFFAOYSA-N    True             NaN   inhibitor
# 31  SJFWZPJFJSGSAB-UHFFFAOYSA-N    True             NaN   inhibitor
# 32  QCMYNIHAZUWGBC-UHFFFAOYSA-N    True             NaN   inhibitor
# 33  GNYKLFXXXBPLNY-UHFFFAOYSA-N    True             NaN   inhibitor
# 47  QZUDBNBUXVUHMW-UHFFFAOYSA-N    True       CLOZAPINE   inhibitor
# 51  UIEATEWHFDRYRU-UHFFFAOYSA-N    True        BEPRIDIL   inhibitor
# 34  YCADFOXVGUGHRV-UHFFFAOYSA-N    True     TERFENADONE   inhibitor
# 35  SGTNSNPWRIOYBX-UHFFFAOYSA-N    True       VERAPAMIL   inhibitor
# 36  GFNANZIMVAIWHM-OBYCQNJPSA-N    True   TRIAMCINOLONE   inhibitor
# 37  UXVSDVSUISWXKD-UHFFFAOYSA-N    True     NICARDIPINE   inhibitor
# 38  OSUCQKNXQBPLDG-UHFFFAOYSA-N    True      NIFEDIPINE   inhibitor
# 39  SVMHYHIZWOJKDL-UHFFFAOYSA-N    True      NIMODIPINE   inhibitor
# 40  OGJPXUAPXNRGGI-UHFFFAOYSA-N    True     NORFLOXACIN   inhibitor
# 41  RGCVKNLCSQQDEP-UHFFFAOYSA-N    True    PERPHENAZINE   inhibitor
# 42  VGKDLMBJGBXTGI-SJCJKPOMSA-N    True      SERTRALINE   inhibitor
# 43  PHWBOXQYWZNQIN-UHFFFAOYSA-N    True     TICLOPIDINE   inhibitor
# 44  IUBSYMUCCVWXPE-UHFFFAOYSA-N    True      METOPROLOL   inhibitor
# 45  VAAUVRVFOQPIGI-NZDRZINCSA-N    True     CEFTRIAXONE   inhibitor
# 46  ZPEIMTDSQAKGNT-UHFFFAOYSA-N    True  CHLORPROMAZINE   inhibitor
# 48  LNEPOXFFQSENCJ-UHFFFAOYSA-N    True     HALOPERIDOL   inhibitor
# 49  HBNPJJILLOYFJU-VMPREFPWSA-N    True      MIBEFRADIL   inhibitor
# 50  OVCDSSHSILBFBN-UHFFFAOYSA-N    True     AMODIAQUINE   inhibitor
# 52  WHQCHUCQKNIQEC-UHFFFAOYSA-N    True   BENZBROMARONE   inhibitor
# 53  AOVFGEQZHDTSQA-UHFFFAOYSA-N    True             NaN   inhibitor
# 54  SJXXIFKOMSEXRL-UHFFFAOYSA-N    True             NaN   inhibitor
# 55  VIVYDKNMRZTMHS-UHFFFAOYSA-N    True             NaN   inhibitor
# 56  IYAIWXMTHZPRGI-UHFFFAOYSA-N    True             NaN   inhibitor
# 57  PMWQIIOHOWIEAH-UHFFFAOYSA-N    True             NaN   inhibitor
# 58  XBXUBZLJPGESQU-UHFFFAOYSA-N    True             NaN   inhibitor
# 59  FSWBIKQBUVIPHY-UHFFFAOYSA-N    True             NaN   inhibitor
# 60  QGDPYJHGPFUYJB-UHFFFAOYSA-N    True             NaN   inhibitor
# 61  TWIPPDALRSWINY-UHFFFAOYSA-N    True             NaN   inhibitor
# 62  PUNWCEDDQDAMTK-UHFFFAOYSA-N    True             NaN   inhibitor
# 63  ASQUTXZYOFTTDB-UHFFFAOYSA-N    True             NaN   inhibitor
# 64  GTVHXLDACMVUIE-UHFFFAOYSA-N    True             NaN   inhibitor
# 65  WRWGDCFFHDPTMW-UHFFFAOYSA-N    True             NaN   inhibitor
# 66  YMMLGNYBWKPZNI-UHFFFAOYSA-N    True             NaN   inhibitor
# 67  TWYCNBQSLNYJIC-UHFFFAOYSA-N    True             NaN   inhibitor
# 68  OXJGQTIVCHEXQS-UHFFFAOYSA-N    True             NaN   inhibitor
# 1   ZQTNQVWKHCQYLQ-UHFFFAOYSA-N    True     Dronedarone   inhibitor
# 2   IYIKLHRQXLHMJQ-UHFFFAOYSA-N    True      Amiodarone   inhibitor
# 7   GXDALQBWZGODGZ-UHFFFAOYSA-N    True      astemizole   inhibitor
# 3   CYQFCXCEBYINGO-IAGOWNOFSA-N    True      Dronabinol   inhibitor
# 4   QHMBSVQNZZTUGM-ZWKOTPCHSA-N    True     Cannabidiol   inhibitor
# 5   VBGLYOIFKLUMQG-UHFFFAOYSA-N    True      Cannabinol   inhibitor
# 8   POZRVZJJTULAOH-LHZXLZLDSA-N    True         danazol   inhibitor
# 9   NKANXQFJJICGDU-QPLCGJKRSA-N    True       tamoxifen   inhibitor
# 13  NCDNCNXCDXHOMX-BWGGSIGWSA-N    True       ritonavir   inhibitor
# 15  UHTHHESEBZOYNR-UHFFFAOYSA-N    True      Vandetanib   inhibitor
# 16  DCSUBABJRXZOMT-IRLDBZIGSA-N    True       Cisapride   inhibitor
# 18  FELGMEQIXOGIFQ-UHFFFAOYSA-N    True     Ondansetron   inhibitor
# 19  FGXWKSZFVQUSTL-UHFFFAOYSA-N    True     Domperidone   inhibitor
# 20  RMEDXOLNCUSCGS-UHFFFAOYSA-N    True      Droperidol   inhibitor
# 21  YVUQSNJEYSNKRX-UHFFFAOYSA-N    True        Pimozide   inhibitor
# 24  RAPZEAPATHNIPO-UHFFFAOYSA-N    True     Risperidone   inhibitor
#
#     pChEMBL mean  pChEMBL std  appears_in_N_ChEMBL_assays  \
# 28      5.593333     0.448367                         3.0
# 25      6.480000     0.350523                         4.0
# 26      6.292500     0.473806                         4.0
# 27      4.700000     0.000000                         3.0
# 29      6.215000     0.035355                         2.0
# 30      6.600000     0.282843                         2.0
# 31      4.700000     0.000000                         2.0
# 32      5.000000          NaN                         2.0
# 33      5.850000     0.000000                         2.0
# 47      4.850000          NaN                         1.0
# 51      4.940000          NaN                         1.0
# 34      6.160000          NaN                         1.0
# 35      4.660000          NaN                         1.0
# 36      5.020000          NaN                         1.0
# 37      5.770000          NaN                         1.0
# 38      5.510000          NaN                         1.0
# 39      5.470000          NaN                         1.0
# 40      5.590000          NaN                         1.0
# 41      4.970000          NaN                         1.0
# 42      4.730000          NaN                         1.0
# 43      4.660000          NaN                         1.0
# 44      5.310000          NaN                         1.0
# 45      4.560000          NaN                         1.0
# 46      4.610000          NaN                         1.0
# 48      5.330000          NaN                         1.0
# 49      5.670000          NaN                         1.0
# 50      6.000000          NaN                         1.0
# 52      5.370000          NaN                         1.0
# 53      5.890000          NaN                         1.0
# 54      6.400000          NaN                         1.0
# 55      5.000000          NaN                         1.0
# 56      5.720000          NaN                         1.0
# 57      5.700000          NaN                         1.0
# 58      5.570000          NaN                         1.0
# 59      5.600000          NaN                         1.0
# 60      6.160000          NaN                         1.0
# 61      5.120000          NaN                         1.0
# 62      6.220000          NaN                         1.0
# 63      6.160000          NaN                         1.0
# 64      5.170000          NaN                         1.0
# 65      5.700000          NaN                         1.0
# 66      5.660000          NaN                         1.0
# 67      5.380000          NaN                         1.0
# 68      5.520000          NaN                         1.0
# 1            NaN          NaN                         NaN
# 2            NaN          NaN                         NaN
# 7            NaN          NaN                         NaN
# 3            NaN          NaN                         NaN
# 4            NaN          NaN                         NaN
# 5            NaN          NaN                         NaN
# 8            NaN          NaN                         NaN
# 9            NaN          NaN                         NaN
# 13           NaN          NaN                         NaN
# 15           NaN          NaN                         NaN
# 16           NaN          NaN                         NaN
# 18           NaN          NaN                         NaN
# 19           NaN          NaN                         NaN
# 20           NaN          NaN                         NaN
# 21           NaN          NaN                         NaN
# 24           NaN          NaN                         NaN
#
#     appears_in_N_datasets  dataset_ChEMBL_curated  dataset_drugbank  \
# 28                      4                    True              True
# 25                      1                    True             False
# 26                      1                    True             False
# 27                      1                    True             False
# 29                      1                    True             False
# 30                      1                    True             False
# 31                      1                    True             False
# 32                      1                    True             False
# 33                      1                    True             False
# 47                      2                    True             False
# 51                      2                    True             False
# 34                      1                    True             False
# 35                      1                    True             False
# 36                      1                    True             False
# 37                      1                    True             False
# 38                      1                    True             False
# 39                      1                    True             False
# 40                      1                    True             False
# 41                      1                    True             False
# 42                      1                    True             False
# 43                      1                    True             False
# 44                      1                    True             False
# 45                      1                    True             False
# 46                      1                    True             False
# 48                      1                    True             False
# 49                      1                    True             False
# 50                      1                    True             False
# 52                      1                    True             False
# 53                      1                    True             False
# 54                      1                    True             False
# 55                      1                    True             False
# 56                      1                    True             False
# 57                      1                    True             False
# 58                      1                    True             False
# 59                      1                    True             False
# 60                      1                    True             False
# 61                      1                    True             False
# 62                      1                    True             False
# 63                      1                    True             False
# 64                      1                    True             False
# 65                      1                    True             False
# 66                      1                    True             False
# 67                      1                    True             False
# 68                      1                    True             False
# 1                       2                   False              True
# 2                       2                   False              True
# 7                       2                   False             False
# 3                       1                   False              True
# 4                       1                   False              True
# 5                       1                   False              True
# 8                       1                   False             False
# 9                       1                   False             False
# 13                      1                   False             False
# 15                      1                   False             False
# 16                      1                   False             False
# 18                      1                   False             False
# 19                      1                   False             False
# 20                      1                   False             False
# 21                      1                   False             False
# 24                      1                   False             False
#
#     dataset_karkhanis2017  dataset_leow2023  inclusion_score
# 28                   True              True              7.0
# 25                  False             False              5.0
# 26                  False             False              5.0
# 27                  False             False              4.0
# 29                  False             False              3.0
# 30                  False             False              3.0
# 31                  False             False              3.0
# 32                  False             False              3.0
# 33                  False             False              3.0
# 47                  False              True              3.0
# 51                  False              True              3.0
# 34                  False             False              2.0
# 35                  False             False              2.0
# 36                  False             False              2.0
# 37                  False             False              2.0
# 38                  False             False              2.0
# 39                  False             False              2.0
# 40                  False             False              2.0
# 41                  False             False              2.0
# 42                  False             False              2.0
# 43                  False             False              2.0
# 44                  False             False              2.0
# 45                  False             False              2.0
# 46                  False             False              2.0
# 48                  False             False              2.0
# 49                  False             False              2.0
# 50                  False             False              2.0
# 52                  False             False              2.0
# 53                  False             False              2.0
# 54                  False             False              2.0
# 55                  False             False              2.0
# 56                  False             False              2.0
# 57                  False             False              2.0
# 58                  False             False              2.0
# 59                  False             False              2.0
# 60                  False             False              2.0
# 61                  False             False              2.0
# 62                  False             False              2.0
# 63                  False             False              2.0
# 64                  False             False              2.0
# 65                  False             False              2.0
# 66                  False             False              2.0
# 67                  False             False              2.0
# 68                  False             False              2.0
# 1                    True             False              2.0
# 2                    True             False              2.0
# 7                    True              True              2.0
# 3                   False             False              1.0
# 4                   False             False              1.0
# 5                   False             False              1.0
# 8                    True             False              1.0
# 9                    True             False              1.0
# 13                   True             False              1.0
# 15                  False              True              1.0
# 16                  False              True              1.0
# 18                  False              True              1.0
# 19                  False              True              1.0
# 20                  False              True              1.0
# 21                  False              True              1.0
# 24                  False              True              1.0

# %%
combined_literature_chembl_w_counts["inclusion_score"] = combined_literature_chembl_w_counts["inclusion_score"].astype(int)

# %%
sns.countplot(combined_literature_chembl_w_counts, x="inclusion_score")
# Out:
# <Axes: xlabel='inclusion_score', ylabel='count'>

# %%
sns.histplot(combined_literature_chembl_w_counts, x="pChEMBL mean")
# Out:
# <Axes: xlabel='pChEMBL mean', ylabel='Count'>
